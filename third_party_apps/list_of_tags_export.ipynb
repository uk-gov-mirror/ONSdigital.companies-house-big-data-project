# %% [markdown]
# <a id='section1'></a>
# <div style="
#     width: 100%;
#     height: 100px;
#     border:none;
#     background:linear-gradient(-45deg, #d84227, #ce3587);
#     text-align: center;
#     position: relative;
# ">
#   <span style="
#       font-size: 40px;
#       padding: 0 10px;
#       color: white;
#       margin: 0;
#       position: absolute;
#       top: 50%;
#       left: 50%;
#       -ms-transform: translate(-50%, -50%);
#       transform: translate(-50%, -50%);
#       font-weight: bold;
#   ">
#     XBRL PARSER <!--Padding is optional-->
#   </span>
# </div><a id='section1'></a>

# %%
"""
Martin Wood - Office for National Statistics
martin.wood@ons.gov.uk
23/07/2018
XBRL parser
Contains functions that scrape and clean an XBRL document's content
and variables, returning a dict ready for dumping into
MongoDB.
"""

import os
import re

import numpy as np
import pandas as pd

from datetime import datetime
from dateutil import parser
from bs4 import BeautifulSoup as BS  # Can parse xml or html docs

# Table of variables and values that indicate consolidated status
consolidation_var_table = {
    "includedinconsolidationsubsidiary": True,
    "investmententityrequiredtoapplyexceptionfromconsolidationtruefalse": True,
    "subsidiaryunconsolidatedtruefalse": False,
    "descriptionreasonwhyentityhasnotpreparedconsolidatedfinancialstatements": "exist",
    "consolidationpolicy": "exist"
}


def clean_value(string):
    """
    Take a value that's stored as a string,
    clean it and convert to numeric.

    If it's just a dash, it's taken to mean
    zero.
    """
    if string.strip() == "-":
        return (0.0)

    try:
        return float(string.strip().replace(",", "").replace(" ", ""))
    except:
        pass

    return (string)


def retrieve_from_context(soup, contextref):
    """
    Used where an element of the document contained no data, only a
    reference to a context element.
    Finds the relevant context element and retrieves the relevant data.

    Returns a text string

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    contextref -- the id of the context element to be raided
    """

    try:
        context = soup.find("xbrli:context", id=contextref)
        contents = context.find("xbrldi:explicitmember").get_text().split(":")[-1].strip()

    except:
        contents = ""

    return (contents)


def retrieve_accounting_standard(soup):
    """
    Gets the account reporting standard in use in a document by hunting
    down the link to the schema reference sheet that always appears to
    be in the document, and extracting the format and standard date from
    the string of the url itself.
    WARNING - That means that there's a lot of implicity hardcoded info
    on the way these links are formated and referenced, within this
    function.  Might need changing someday.

    Returns a 3-tuple (standard, date, original url)

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    """

    # Find the relevant link by its unique attribute
    link_obj = soup.find("link:schemaref")

    # If we didn't find anything it's an xml doc using a different
    # element name:
    if link_obj == None:
        link_obj = soup.find("schemaref")

    # extract the name of the .xsd schema file, which contains format
    # and date information
    text = link_obj['xlink:href'].split("/")[-1].split(".")[0]

    # Split the extracted text into format and date, return values
    return (text[:-10].strip("-"), text[-10:], link_obj['xlink:href'])


def retrieve_unit(soup, each):
    """
    Gets the reporting unit by trying to chase a unitref to
    its source, alternatively uses element attribute unitref
    if it's not a reference to another element.

    Returns the unit

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    each -- element of BeautifulSoup souped object
    """

    # If not, try to discover the unit string in the
    # soup object
    try:
        unit_str = soup.find(id=each['unitref']).get_text()

    except:
        # Or if not, in the attributes of the element
        try:
            unit_str = each.attrs['unitref']

        except:
            return ("NA")

    return (unit_str.strip())


def retrieve_date(soup, each):
    """
    Gets the reporting date by trying to chase a contextref
    to its source and extract its period, alternatively uses
    element attribute contextref if it's not a reference
    to another element.
    Returns the date

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    each -- element of BeautifulSoup souped object
    """

    # Try to find a date tag within the contextref element,
    # starting with the most specific tags, and starting with
    # those for ixbrl docs as it's the most common file.
    date_tag_list = ["xbrli:enddate",
                     "xbrli:instant",
                     "xbrli:period",
                     "enddate",
                     "instant",
                     "period"]

    for tag in date_tag_list:
        try:
            date_str = each['contextref']
            date_val = parser.parse(soup.find(id=each['contextref']).find(tag).get_text()). \
                date(). \
                isoformat()
            return (date_val)
        except:
            pass

    try:
        date_str = each.attrs['contextref']
        date_val = parser.parse(each.attrs['contextref']). \
            date(). \
            isoformat()
        return (date_val)
    except:
        pass

    return ("NA")


def parse_element(soup, element):
    """
    For a discovered XBRL tagged element, go through, retrieve its name
    and value and associated metadata.

    Keyword arguments:
    soup -- BeautifulSoup object of accounts document
    element -- soup object of discovered tagged element
    """

    if "contextref" not in element.attrs:
        return ({})

    element_dict = {}

    # Basic name and value
    try:
        # Method for XBRLi docs first
        element_dict['name'] = element.attrs['name'].lower().split(":")[-1]
    except:
        # Method for XBRL docs second
        element_dict['name'] = element.name.lower().split(":")[-1]

    element_dict['value'] = element.get_text()
    element_dict['unit'] = retrieve_unit(soup, element)
    element_dict['date'] = retrieve_date(soup, element)

    # If there's no value retrieved, try raiding the associated context data
    if element_dict['value'] == "":
        element_dict['value'] = retrieve_from_context(soup, element.attrs['contextref'])

    # If the value has a defined unit (eg a currency) convert to numeric	
    if element_dict['unit'] != "NA":
        element_dict['value'] = clean_value(element_dict['value'])

    # Retrieve sign of element if exists
    try:
        element_dict['sign'] = element.attrs['sign']

        # if it's negative, convert the value then and there
        if element_dict['sign'].strip() == "-":
            element_dict['value'] = 0.0 - element_dict['value']
    except:
        pass

    return (element_dict)


def parse_elements(element_set, soup):
    """
    For a set of discovered elements within a document, try to parse
    them.  Only keep valid results (test is whether field "name"
    exists).

    Keyword arguments:
    element_set -- BeautifulSoup iterable search result object
    soup -- BeautifulSoup object of accounts document
    """
    elements = []
    for each in element_set:
        element_dict = parse_element(soup, each)
        if 'name' in element_dict:
            elements.append(element_dict)
    return (elements)


def summarise_by_sum(doc, variable_names):
    """
    Takes a document (dict) after extraction, and tries to extract
    a summary variable relating to the financial state of the enterprise
    by summing all those named that exist.  Returns dict.

    Keyword arguments:
    doc -- an extracted document dict, with "elements" entry as created
           by the 'scrape_clean_elements' functions.
    variable_names - variables to find and sum if they exist
    """

    # Convert elements to pandas df
    df = pd.DataFrame(doc['elements'])

    # Subset to most recent (latest dated)
    df = df[df['date'] == doc['doc_balancesheetdate']]

    total_assets = 0.0
    unit = "NA"

    # Find the total assets by summing components
    for each in variable_names:

        # Fault-tolerant, will skip whatever isn't numeric
        try:
            total_assets = total_assets + df[df['name'] == each].iloc[0]['value']

            # Retrieve reporting unit if exists
            unit = df[df['name'] == each].iloc[0]['unit']

        except:
            pass

    return ({"total_assets": total_assets, "unit": unit})


def summarise_by_priority(doc, variable_names):
    """
    Takes a document (dict) after extraction, and tries to extract
    a summary variable relating to the financial state of the enterprise
    by looking for each named, in order.  Returns dict.

    Keyword arguments:
    doc -- an extracted document dict, with "elements" entry as created
           by the 'scrape_clean_elements' functions.
    variable_names - variables to find and check if they exist.
    """

    # Convert elements to pandas df
    df = pd.DataFrame(doc['elements'])

    # Subset to most recent (latest dated)
    df = df[df['date'] == doc['doc_balancesheetdate']]

    primary_assets = 0.0
    unit = "NA"

    # Find the net asset/liability variable by hunting names in order
    for each in variable_names:
        try:

            # Fault tolerant, will skip whatever isn't numeric
            primary_assets = df[df['name'] == each].iloc[0]['value']

            # Retrieve reporting unit if it exists
            unit = df[df['name'] == each].iloc[0]['unit']
            break

        except:
            pass

    return ({"primary_assets": primary_assets, "unit": unit})


def summarise_set(doc, variable_names):
    """
    Takes a document (dict) after extraction, and tries to extract
    summary variables relating to the financial state of the enterprise
    by returning all those named that exist.  Returns dict.

    Keyword arguments:
    doc -- an extracted document dict, with "elements" entry as created
           by the 'scrape_clean_elements' functions.
    variable_names - variables to find and return if they exist.
    """
    results = {}

    # Convert elements to pandas df
    df = pd.DataFrame(doc['elements'])

    # Subset to most recent (latest dated)
    df = df[df['date'] == doc['doc_balancesheetdate']]

    # Find all the variables of interest should they exist
    for each in variable_names:
        try:
            results[each] = df[df['name'] == each].iloc[0]['value']

        except:
            pass

    # Send the variables back to be appended
    return (results)


def scrape_elements(soup, filepath):
    """
    Parses an XBRL (xml) company accounts file
    for all labelled content and extracts the
    content (and metadata, eg; unitref) of each
    element found to a dictionary 

    params: filepath (str)
    output: list of dicts
    """

    # Try multiple methods of retrieving data, I think only the first is
    # now needed though.  The rest will be removed after testing this
    # but should not affect execution speed.
    try:
        element_set = soup.find_all()
        elements = parse_elements(element_set, soup)
        if len(elements) <= 5:
            raise Exception("Elements should be gte 5, was {}".format(len(elements)))
        return (elements)
    except:
        pass

    return (0)


def flatten_data(doc):
    """
    Takes the data returned by process account, with its tree-like
    structure and reorganises it into a long-thin format table structure
    suitable for SQL applications.
    """

    # Need to drop components later, so need copy in function
    doc2 = doc.copy()
    doc_df = pd.DataFrame()

    # Pandas should create series, then columns, from dicts when called
    # like this
    for element in doc2['elements']:
        doc_df = doc_df.append(element, ignore_index=True)

    # Dump the "elements" entry in the doc dict
    doc2.pop("elements")

    # Create uniform columns for all other properties
    for key in doc2:
        doc_df[key] = doc2[key]

    return (doc_df)


def process_account(filepath):
    """
    Scrape all of the relevant information from
    an iXBRL (html) file, upload the elements
    and some metadata to a mongodb.

    Named arguments:
    filepath -- complete filepath (string) from drive root
    """
    doc = {}

    # Some metadata, doc name, upload date/time, archive file it came from
    doc['doc_name'] = filepath.split("/")[-1]
    doc['doc_type'] = filepath.split(".")[-1].lower()
    doc['doc_upload_date'] = str(datetime.now())
    doc['arc_name'] = filepath.split("/")[-2]
    doc['parsed'] = True

    # Complicated ones
    sheet_date = filepath.split("/")[-1].split(".")[0].split("_")[-1]
    doc['doc_balancesheetdate'] = datetime.strptime(sheet_date, "%Y%m%d").date().isoformat()

    doc['doc_companieshouseregisterednumber'] = filepath.split("/")[-1].split(".")[0].split("_")[-2]

#     print(filepath)

    try:
        soup = BS(open(filepath, "rb"), "html.parser")
    except:
        print("Failed to open: " + filepath)
        return (1)

    # Get metadata about the accounting standard used
    try:
        doc['doc_standard_type'], doc['doc_standard_date'], doc['doc_standard_link'] = retrieve_accounting_standard(
            soup)
    except:
        doc['doc_standard_type'], doc['doc_standard_date'], doc['doc_standard_link'] = (0, 0, 0)

    # Fetch all the marked elements of the document
    try:
        doc['elements'] = scrape_elements(soup, filepath)
    except Exception as e:
        doc['parsed'] = False
        doc['Error'] = e

    try:
        return (doc)
    except Exception as e:
        return (e)

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br>
# <a id='section1'></a>
# <div style="
#     width: 100%;
#     height: 100px;
#     border:none;
#     background:linear-gradient(-45deg, #d84227, #ce3587);
#     text-align: center;
#     position: relative;
# ">
#   <span style="
#       font-size: 40px;
#       padding: 0 10px;
#       color: white;
#       margin: 0;
#       position: absolute;
#       top: 50%;
#       left: 50%;
#       -ms-transform: translate(-50%, -50%);
#       transform: translate(-50%, -50%);
#       font-weight: bold;
#   ">
#     EXTRACTION <!--Padding is optional-->
#   </span>
# </div><a id='section1'></a>

# %%
import os
import numpy as np
import pandas as pd
import importlib

def get_filepaths(directory):

    """ Helper function - 
    Get all of the filenames in a directory that
    end in htm* or xml.
    Under the assumption that all files within
    the folder are financial records. """

    files = [directory + "/" + filename
                for filename in os.listdir(directory)
                    if (("htm" in filename.lower()) or ("xml" in filename.lower()))]
    return(files)

# %%
# Get all the filenames from the example folder
files = get_filepaths("D:\Project_3 - Image_Processing\example_data_XBRL_iXBRL")

# D:\Project_3 - Image_Processing\cha_pipeline\data

# There's 379 examples currently
files[0:3]
# Out:
# ['D:\\Project_3 - Image_Processing\\example_data_XBRL_iXBRL/Prod223_2125_09102728_20170630.html',
#  'D:\\Project_3 - Image_Processing\\example_data_XBRL_iXBRL/Prod223_2125_09110532_20170831.html',
#  'D:\\Project_3 - Image_Processing\\example_data_XBRL_iXBRL/Prod223_2125_09113928_20161231.html']

# %%
doc = process_account(files[0])

# display for fun
doc
# Out:
# {'arc_name': 'D:\\Project_3 - Image_Processing\\example_data_XBRL_iXBRL',
#  'doc_balancesheetdate': '2017-06-30',
#  'doc_companieshouseregisterednumber': '09102728',
#  'doc_name': 'Prod223_2125_09102728_20170630.html',
#  'doc_standard_date': '2009-09-01',
#  'doc_standard_link': 'http://www.xbrl.org/uk/gaap/core/2009-09-01/uk-gaap-full-2009-09-01.xsd',
#  'doc_standard_type': 'uk-gaap-full',
#  'doc_type': 'html',
#  'doc_upload_date': '2020-06-10 10:37:03.182895',
#  'elements': [{'date': '2017-06-30',
#    'name': 'ukcompanieshouseregisterednumber',
#    'unit': 'NA',
#    'value': '09102728'},
#   {'date': '2017-06-30',
#    'name': 'entitycurrentlegalorregisteredname',
#    'unit': 'NA',
#    'value': 'SQUARE ONE PROPERTY CONSULTANTS LIMITED'},
#   {'date': '2017-06-30',
#    'name': 'balancesheetdate',
#    'unit': 'NA',
#    'value': '2017-06-30'},
#   {'date': '2017-06-30',
#    'name': 'namedirectorsigningaccounts',
#    'unit': 'NA',
#    'value': ''},
#   {'date': '2017-06-30',
#    'name': 'namedirectorsigningaccounts',
#    'unit': 'NA',
#    'value': ''},
#   {'date': '2017-06-30',
#    'name': 'entitydormant',
#    'unit': 'NA',
#    'value': 'false'},
#   {'date': '2017-06-30',
#    'name': 'startdateforperiodcoveredbyreport',
#    'unit': 'NA',
#    'value': '2016-07-01'},
#   {'date': '2017-06-30',
#    'name': 'enddateforperiodcoveredbyreport',
#    'unit': 'NA',
#    'value': '2017-06-30'},
#   {'date': '2017-06-30',
#    'name': 'entitytrading',
#    'unit': 'NA',
#    'value': 'true'},
#   {'date': '2017-06-30',
#    'name': 'calledupsharecapitalnotpaidnotexpressedascurrentasset',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2016-06-30',
#    'name': 'calledupsharecapitalnotpaidnotexpressedascurrentasset',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2017-06-30',
#    'name': 'fixedassets',
#    'unit': 'iso4217:GBP',
#    'value': 500.0},
#   {'date': '2016-06-30',
#    'name': 'fixedassets',
#    'unit': 'iso4217:GBP',
#    'value': 500.0},
#   {'date': '2017-06-30',
#    'name': 'currentassets',
#    'unit': 'iso4217:GBP',
#    'value': 500.0},
#   {'date': '2016-06-30',
#    'name': 'currentassets',
#    'unit': 'iso4217:GBP',
#    'value': 500.0},
#   {'date': '2017-06-30',
#    'name': 'prepaymentsaccruedincomenotexpressedwithincurrentassetsubtotal',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2016-06-30',
#    'name': 'prepaymentsaccruedincomenotexpressedwithincurrentassetsubtotal',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2017-06-30',
#    'name': 'creditorsduewithinoneyear',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2016-06-30',
#    'name': 'creditorsduewithinoneyear',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2017-06-30',
#    'name': 'netcurrentassetsliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 500.0},
#   {'date': '2016-06-30',
#    'name': 'netcurrentassetsliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 500.0},
#   {'date': '2017-06-30',
#    'name': 'totalassetslesscurrentliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 1000.0},
#   {'date': '2016-06-30',
#    'name': 'totalassetslesscurrentliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 1000.0},
#   {'date': '2017-06-30',
#    'name': 'creditorsdueafteroneyear',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2016-06-30',
#    'name': 'creditorsdueafteroneyear',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2017-06-30',
#    'name': 'provisionsforliabilitiescharges',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2016-06-30',
#    'name': 'provisionsforliabilitiescharges',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2017-06-30',
#    'name': 'accrualsdeferredincome',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2016-06-30',
#    'name': 'accrualsdeferredincome',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2017-06-30',
#    'name': 'netassetsliabilitiesincludingpensionassetliability',
#    'unit': 'iso4217:GBP',
#    'value': 1000.0},
#   {'date': '2016-06-30',
#    'name': 'netassetsliabilitiesincludingpensionassetliability',
#    'unit': 'iso4217:GBP',
#    'value': 1000.0},
#   {'date': '2017-06-30',
#    'name': 'shareholderfunds',
#    'unit': 'iso4217:GBP',
#    'value': 1000.0},
#   {'date': '2016-06-30',
#    'name': 'shareholderfunds',
#    'unit': 'iso4217:GBP',
#    'value': 1000.0},
#   {'date': '2017-06-30',
#    'name': 'companyentitledtoexemptionundersection477companiesact2006',
#    'unit': 'NA',
#    'value': 'For the year ending 30 June 2017 the company was entitled to exemption under section 477 of the Companies Act 2006 relating to small companies.'},
#   {'date': '2017-06-30',
#    'name': 'membershavenotrequiredcompanytoobtainanaudit',
#    'unit': 'NA',
#    'value': 'The members have not required the company to obtain an audit in accordance with section 476 of the Companies Act 2006.'},
#   {'date': '2017-06-30',
#    'name': 'directorsacknowledgetheirresponsibilitiesundercompaniesact',
#    'unit': 'NA',
#    'value': 'The directors acknowledge their responsibilities for complying with the requirements of the Companies Act 2006 with respect to accounting records and the preparation of accounts.'},
#   {'date': '2017-06-30',
#    'name': 'accountsareinaccordancewithspecialprovisionscompaniesactrelatingtosmallcompanies',
#    'unit': 'NA',
#    'value': 'The accounts have been prepared in accordance with the micro-entity provisions and delivered in accordance with the provisions applicable to companies subject to the small companies regime.'},
#   {'date': '2017-06-30',
#    'name': 'dateapprovalaccounts',
#    'unit': 'NA',
#    'value': '2 May 2018'},
#   {'date': '2017-06-30',
#    'name': 'nameentityofficer',
#    'unit': 'NA',
#    'value': 'Robert Anderson'}],
#  'parsed': True}

# %%
doc['elements']
# Out:
# [{'date': '2017-06-30',
#   'name': 'ukcompanieshouseregisterednumber',
#   'unit': 'NA',
#   'value': '09102728'},
#  {'date': '2017-06-30',
#   'name': 'entitycurrentlegalorregisteredname',
#   'unit': 'NA',
#   'value': 'SQUARE ONE PROPERTY CONSULTANTS LIMITED'},
#  {'date': '2017-06-30',
#   'name': 'balancesheetdate',
#   'unit': 'NA',
#   'value': '2017-06-30'},
#  {'date': '2017-06-30',
#   'name': 'namedirectorsigningaccounts',
#   'unit': 'NA',
#   'value': ''},
#  {'date': '2017-06-30',
#   'name': 'namedirectorsigningaccounts',
#   'unit': 'NA',
#   'value': ''},
#  {'date': '2017-06-30',
#   'name': 'entitydormant',
#   'unit': 'NA',
#   'value': 'false'},
#  {'date': '2017-06-30',
#   'name': 'startdateforperiodcoveredbyreport',
#   'unit': 'NA',
#   'value': '2016-07-01'},
#  {'date': '2017-06-30',
#   'name': 'enddateforperiodcoveredbyreport',
#   'unit': 'NA',
#   'value': '2017-06-30'},
#  {'date': '2017-06-30',
#   'name': 'entitytrading',
#   'unit': 'NA',
#   'value': 'true'},
#  {'date': '2017-06-30',
#   'name': 'calledupsharecapitalnotpaidnotexpressedascurrentasset',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2016-06-30',
#   'name': 'calledupsharecapitalnotpaidnotexpressedascurrentasset',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2017-06-30',
#   'name': 'fixedassets',
#   'unit': 'iso4217:GBP',
#   'value': 500.0},
#  {'date': '2016-06-30',
#   'name': 'fixedassets',
#   'unit': 'iso4217:GBP',
#   'value': 500.0},
#  {'date': '2017-06-30',
#   'name': 'currentassets',
#   'unit': 'iso4217:GBP',
#   'value': 500.0},
#  {'date': '2016-06-30',
#   'name': 'currentassets',
#   'unit': 'iso4217:GBP',
#   'value': 500.0},
#  {'date': '2017-06-30',
#   'name': 'prepaymentsaccruedincomenotexpressedwithincurrentassetsubtotal',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2016-06-30',
#   'name': 'prepaymentsaccruedincomenotexpressedwithincurrentassetsubtotal',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2017-06-30',
#   'name': 'creditorsduewithinoneyear',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2016-06-30',
#   'name': 'creditorsduewithinoneyear',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2017-06-30',
#   'name': 'netcurrentassetsliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 500.0},
#  {'date': '2016-06-30',
#   'name': 'netcurrentassetsliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 500.0},
#  {'date': '2017-06-30',
#   'name': 'totalassetslesscurrentliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 1000.0},
#  {'date': '2016-06-30',
#   'name': 'totalassetslesscurrentliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 1000.0},
#  {'date': '2017-06-30',
#   'name': 'creditorsdueafteroneyear',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2016-06-30',
#   'name': 'creditorsdueafteroneyear',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2017-06-30',
#   'name': 'provisionsforliabilitiescharges',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2016-06-30',
#   'name': 'provisionsforliabilitiescharges',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2017-06-30',
#   'name': 'accrualsdeferredincome',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2016-06-30',
#   'name': 'accrualsdeferredincome',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2017-06-30',
#   'name': 'netassetsliabilitiesincludingpensionassetliability',
#   'unit': 'iso4217:GBP',
#   'value': 1000.0},
#  {'date': '2016-06-30',
#   'name': 'netassetsliabilitiesincludingpensionassetliability',
#   'unit': 'iso4217:GBP',
#   'value': 1000.0},
#  {'date': '2017-06-30',
#   'name': 'shareholderfunds',
#   'unit': 'iso4217:GBP',
#   'value': 1000.0},
#  {'date': '2016-06-30',
#   'name': 'shareholderfunds',
#   'unit': 'iso4217:GBP',
#   'value': 1000.0},
#  {'date': '2017-06-30',
#   'name': 'companyentitledtoexemptionundersection477companiesact2006',
#   'unit': 'NA',
#   'value': 'For the year ending 30 June 2017 the company was entitled to exemption under section 477 of the Companies Act 2006 relating to small companies.'},
#  {'date': '2017-06-30',
#   'name': 'membershavenotrequiredcompanytoobtainanaudit',
#   'unit': 'NA',
#   'value': 'The members have not required the company to obtain an audit in accordance with section 476 of the Companies Act 2006.'},
#  {'date': '2017-06-30',
#   'name': 'directorsacknowledgetheirresponsibilitiesundercompaniesact',
#   'unit': 'NA',
#   'value': 'The directors acknowledge their responsibilities for complying with the requirements of the Companies Act 2006 with respect to accounting records and the preparation of accounts.'},
#  {'date': '2017-06-30',
#   'name': 'accountsareinaccordancewithspecialprovisionscompaniesactrelatingtosmallcompanies',
#   'unit': 'NA',
#   'value': 'The accounts have been prepared in accordance with the micro-entity provisions and delivered in accordance with the provisions applicable to companies subject to the small companies regime.'},
#  {'date': '2017-06-30',
#   'name': 'dateapprovalaccounts',
#   'unit': 'NA',
#   'value': '2 May 2018'},
#  {'date': '2017-06-30',
#   'name': 'nameentityofficer',
#   'unit': 'NA',
#   'value': 'Robert Anderson'}]

# %%
# Loop through the document, retrieving any element with a matching name
for element in doc['elements']:
    if element['name'] == 'balancesheetdate':
        print(element)
# Out:
# {'name': 'balancesheetdate', 'value': '2017-06-30', 'unit': 'NA', 'date': '2017-06-30'}

# %%
# Extract the all the data to long-thin table format for use with SQL
# Note, tables from docs should be appendable to one another to create
# tables of all data
flatten_data(doc).head(15)
# Out:
#           date                                               name  \
# 0   2017-06-30                   ukcompanieshouseregisterednumber
# 1   2017-06-30                 entitycurrentlegalorregisteredname
# 2   2017-06-30                                   balancesheetdate
# 3   2017-06-30                        namedirectorsigningaccounts
# 4   2017-06-30                        namedirectorsigningaccounts
# 5   2017-06-30                                      entitydormant
# 6   2017-06-30                  startdateforperiodcoveredbyreport
# 7   2017-06-30                    enddateforperiodcoveredbyreport
# 8   2017-06-30                                      entitytrading
# 9   2017-06-30  calledupsharecapitalnotpaidnotexpressedascurre...
# 10  2016-06-30  calledupsharecapitalnotpaidnotexpressedascurre...
# 11  2017-06-30                                        fixedassets
# 12  2016-06-30                                        fixedassets
# 13  2017-06-30                                      currentassets
# 14  2016-06-30                                      currentassets
#
#            unit                                    value  \
# 0            NA                                 09102728
# 1            NA  SQUARE ONE PROPERTY CONSULTANTS LIMITED
# 2            NA                               2017-06-30
# 3            NA
# 4            NA
# 5            NA                                    false
# 6            NA                               2016-07-01
# 7            NA                               2017-06-30
# 8            NA                                     true
# 9   iso4217:GBP                                        0
# 10  iso4217:GBP                                        0
# 11  iso4217:GBP                                      500
# 12  iso4217:GBP                                      500
# 13  iso4217:GBP                                      500
# 14  iso4217:GBP                                      500
#
#                                doc_name doc_type             doc_upload_date  \
# 0   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 1   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 2   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 3   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 4   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 5   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 6   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 7   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 8   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 9   Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 10  Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 11  Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 12  Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 13  Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
# 14  Prod223_2125_09102728_20170630.html     html  2020-06-10 10:37:03.182895
#
#                                              arc_name  parsed  \
# 0   D:\Project_3 - Image_Processing\example_data_X...    True
# 1   D:\Project_3 - Image_Processing\example_data_X...    True
# 2   D:\Project_3 - Image_Processing\example_data_X...    True
# 3   D:\Project_3 - Image_Processing\example_data_X...    True
# 4   D:\Project_3 - Image_Processing\example_data_X...    True
# 5   D:\Project_3 - Image_Processing\example_data_X...    True
# 6   D:\Project_3 - Image_Processing\example_data_X...    True
# 7   D:\Project_3 - Image_Processing\example_data_X...    True
# 8   D:\Project_3 - Image_Processing\example_data_X...    True
# 9   D:\Project_3 - Image_Processing\example_data_X...    True
# 10  D:\Project_3 - Image_Processing\example_data_X...    True
# 11  D:\Project_3 - Image_Processing\example_data_X...    True
# 12  D:\Project_3 - Image_Processing\example_data_X...    True
# 13  D:\Project_3 - Image_Processing\example_data_X...    True
# 14  D:\Project_3 - Image_Processing\example_data_X...    True
#
#    doc_balancesheetdate doc_companieshouseregisterednumber doc_standard_type  \
# 0            2017-06-30                           09102728      uk-gaap-full
# 1            2017-06-30                           09102728      uk-gaap-full
# 2            2017-06-30                           09102728      uk-gaap-full
# 3            2017-06-30                           09102728      uk-gaap-full
# 4            2017-06-30                           09102728      uk-gaap-full
# 5            2017-06-30                           09102728      uk-gaap-full
# 6            2017-06-30                           09102728      uk-gaap-full
# 7            2017-06-30                           09102728      uk-gaap-full
# 8            2017-06-30                           09102728      uk-gaap-full
# 9            2017-06-30                           09102728      uk-gaap-full
# 10           2017-06-30                           09102728      uk-gaap-full
# 11           2017-06-30                           09102728      uk-gaap-full
# 12           2017-06-30                           09102728      uk-gaap-full
# 13           2017-06-30                           09102728      uk-gaap-full
# 14           2017-06-30                           09102728      uk-gaap-full
#
#    doc_standard_date                                  doc_standard_link
# 0         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 1         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 2         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 3         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 4         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 5         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 6         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 7         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 8         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 9         2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 10        2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 11        2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 12        2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 13        2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...
# 14        2009-09-01  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...

# %%
import time

print(len(files))
# Out:
# 378

# %%
import sys

def progressBar(name, value, endvalue, bar_length = 50, width = 20):
        percent = float(value) / endvalue
        arrow = '-' * int(round(percent*bar_length) - 1) + '>'
        spaces = ' ' * (bar_length - len(arrow))
        sys.stdout.write(
            "\r{0: <{1}} : [{2}]{3}%   ({4} / {5})".format(
                name,
                width,
                arrow + spaces,
                int(round(percent*100)),
                value,
                endvalue
            )
        )
        sys.stdout.flush()
        if value == endvalue:     
             sys.stdout.write('\n\n')

# %%
# Finally, build a table of all variables from all example (digital) documents
# This can take a while

# Empty table awaiting results
results = pd.DataFrame()

COUNT = 0

# For every file
for file in files:
    
    COUNT += 1
    
    # Read the file
    doc = process_account(file)
    
    # tabulate the results
    doc_df = flatten_data(doc)
    
    # append to table
    results = results.append(doc_df)
    
    progressBar("XBRL Accounts Parsed", COUNT, len(files), bar_length = 50, width = 20)
# Out:
# XBRL Accounts Parsed : [------------------------------------------------->]100%\s\s\s(378 / 378)
#
# XBRL Accounts Parsed : [------------------------------------------------->]100%\s\s\s(379 / 378)

# %%
results.head(50)
# Out:
#                                              arc_name        date  \
# 0   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 1   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 2   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 3   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 4   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 5   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 6   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 7   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 8   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 9   D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 10  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 11  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 12  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 13  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 14  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 15  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 16  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 17  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 18  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 19  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 20  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 21  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 22  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 23  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 24  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 25  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 26  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 27  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 28  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 29  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 30  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 31  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 32  D:\Project_3 - Image_Processing\example_data_X...  2016-06-30
# 33  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 34  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 35  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 36  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 37  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 38  D:\Project_3 - Image_Processing\example_data_X...  2017-06-30
# 0   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 1   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 2   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 3   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 4   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 5   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 6   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 7   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 8   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 9   D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
# 10  D:\Project_3 - Image_Processing\example_data_X...  2017-08-31
#
#    doc_balancesheetdate doc_companieshouseregisterednumber  \
# 0            2017-06-30                           09102728
# 1            2017-06-30                           09102728
# 2            2017-06-30                           09102728
# 3            2017-06-30                           09102728
# 4            2017-06-30                           09102728
# 5            2017-06-30                           09102728
# 6            2017-06-30                           09102728
# 7            2017-06-30                           09102728
# 8            2017-06-30                           09102728
# 9            2017-06-30                           09102728
# 10           2017-06-30                           09102728
# 11           2017-06-30                           09102728
# 12           2017-06-30                           09102728
# 13           2017-06-30                           09102728
# 14           2017-06-30                           09102728
# 15           2017-06-30                           09102728
# 16           2017-06-30                           09102728
# 17           2017-06-30                           09102728
# 18           2017-06-30                           09102728
# 19           2017-06-30                           09102728
# 20           2017-06-30                           09102728
# 21           2017-06-30                           09102728
# 22           2017-06-30                           09102728
# 23           2017-06-30                           09102728
# 24           2017-06-30                           09102728
# 25           2017-06-30                           09102728
# 26           2017-06-30                           09102728
# 27           2017-06-30                           09102728
# 28           2017-06-30                           09102728
# 29           2017-06-30                           09102728
# 30           2017-06-30                           09102728
# 31           2017-06-30                           09102728
# 32           2017-06-30                           09102728
# 33           2017-06-30                           09102728
# 34           2017-06-30                           09102728
# 35           2017-06-30                           09102728
# 36           2017-06-30                           09102728
# 37           2017-06-30                           09102728
# 38           2017-06-30                           09102728
# 0            2017-08-31                           09110532
# 1            2017-08-31                           09110532
# 2            2017-08-31                           09110532
# 3            2017-08-31                           09110532
# 4            2017-08-31                           09110532
# 5            2017-08-31                           09110532
# 6            2017-08-31                           09110532
# 7            2017-08-31                           09110532
# 8            2017-08-31                           09110532
# 9            2017-08-31                           09110532
# 10           2017-08-31                           09110532
#
#                                doc_name doc_standard_date  \
# 0   Prod223_2125_09102728_20170630.html        2009-09-01
# 1   Prod223_2125_09102728_20170630.html        2009-09-01
# 2   Prod223_2125_09102728_20170630.html        2009-09-01
# 3   Prod223_2125_09102728_20170630.html        2009-09-01
# 4   Prod223_2125_09102728_20170630.html        2009-09-01
# 5   Prod223_2125_09102728_20170630.html        2009-09-01
# 6   Prod223_2125_09102728_20170630.html        2009-09-01
# 7   Prod223_2125_09102728_20170630.html        2009-09-01
# 8   Prod223_2125_09102728_20170630.html        2009-09-01
# 9   Prod223_2125_09102728_20170630.html        2009-09-01
# 10  Prod223_2125_09102728_20170630.html        2009-09-01
# 11  Prod223_2125_09102728_20170630.html        2009-09-01
# 12  Prod223_2125_09102728_20170630.html        2009-09-01
# 13  Prod223_2125_09102728_20170630.html        2009-09-01
# 14  Prod223_2125_09102728_20170630.html        2009-09-01
# 15  Prod223_2125_09102728_20170630.html        2009-09-01
# 16  Prod223_2125_09102728_20170630.html        2009-09-01
# 17  Prod223_2125_09102728_20170630.html        2009-09-01
# 18  Prod223_2125_09102728_20170630.html        2009-09-01
# 19  Prod223_2125_09102728_20170630.html        2009-09-01
# 20  Prod223_2125_09102728_20170630.html        2009-09-01
# 21  Prod223_2125_09102728_20170630.html        2009-09-01
# 22  Prod223_2125_09102728_20170630.html        2009-09-01
# 23  Prod223_2125_09102728_20170630.html        2009-09-01
# 24  Prod223_2125_09102728_20170630.html        2009-09-01
# 25  Prod223_2125_09102728_20170630.html        2009-09-01
# 26  Prod223_2125_09102728_20170630.html        2009-09-01
# 27  Prod223_2125_09102728_20170630.html        2009-09-01
# 28  Prod223_2125_09102728_20170630.html        2009-09-01
# 29  Prod223_2125_09102728_20170630.html        2009-09-01
# 30  Prod223_2125_09102728_20170630.html        2009-09-01
# 31  Prod223_2125_09102728_20170630.html        2009-09-01
# 32  Prod223_2125_09102728_20170630.html        2009-09-01
# 33  Prod223_2125_09102728_20170630.html        2009-09-01
# 34  Prod223_2125_09102728_20170630.html        2009-09-01
# 35  Prod223_2125_09102728_20170630.html        2009-09-01
# 36  Prod223_2125_09102728_20170630.html        2009-09-01
# 37  Prod223_2125_09102728_20170630.html        2009-09-01
# 38  Prod223_2125_09102728_20170630.html        2009-09-01
# 0   Prod223_2125_09110532_20170831.html        2014-09-01
# 1   Prod223_2125_09110532_20170831.html        2014-09-01
# 2   Prod223_2125_09110532_20170831.html        2014-09-01
# 3   Prod223_2125_09110532_20170831.html        2014-09-01
# 4   Prod223_2125_09110532_20170831.html        2014-09-01
# 5   Prod223_2125_09110532_20170831.html        2014-09-01
# 6   Prod223_2125_09110532_20170831.html        2014-09-01
# 7   Prod223_2125_09110532_20170831.html        2014-09-01
# 8   Prod223_2125_09110532_20170831.html        2014-09-01
# 9   Prod223_2125_09110532_20170831.html        2014-09-01
# 10  Prod223_2125_09110532_20170831.html        2014-09-01
#
#                                     doc_standard_link doc_standard_type  \
# 0   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 1   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 2   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 3   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 4   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 5   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 6   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 7   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 8   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 9   http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 10  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 11  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 12  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 13  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 14  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 15  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 16  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 17  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 18  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 19  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 20  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 21  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 22  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 23  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 24  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 25  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 26  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 27  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 28  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 29  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 30  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 31  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 32  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 33  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 34  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 35  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 36  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 37  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 38  http://www.xbrl.org/uk/gaap/core/2009-09-01/uk...      uk-gaap-full
# 0   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 1   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 2   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 3   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 4   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 5   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 6   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 7   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 8   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 9   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 10  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
#
#    doc_type             doc_upload_date  \
# 0      html  2020-06-10 10:37:03.665896
# 1      html  2020-06-10 10:37:03.665896
# 2      html  2020-06-10 10:37:03.665896
# 3      html  2020-06-10 10:37:03.665896
# 4      html  2020-06-10 10:37:03.665896
# 5      html  2020-06-10 10:37:03.665896
# 6      html  2020-06-10 10:37:03.665896
# 7      html  2020-06-10 10:37:03.665896
# 8      html  2020-06-10 10:37:03.665896
# 9      html  2020-06-10 10:37:03.665896
# 10     html  2020-06-10 10:37:03.665896
# 11     html  2020-06-10 10:37:03.665896
# 12     html  2020-06-10 10:37:03.665896
# 13     html  2020-06-10 10:37:03.665896
# 14     html  2020-06-10 10:37:03.665896
# 15     html  2020-06-10 10:37:03.665896
# 16     html  2020-06-10 10:37:03.665896
# 17     html  2020-06-10 10:37:03.665896
# 18     html  2020-06-10 10:37:03.665896
# 19     html  2020-06-10 10:37:03.665896
# 20     html  2020-06-10 10:37:03.665896
# 21     html  2020-06-10 10:37:03.665896
# 22     html  2020-06-10 10:37:03.665896
# 23     html  2020-06-10 10:37:03.665896
# 24     html  2020-06-10 10:37:03.665896
# 25     html  2020-06-10 10:37:03.665896
# 26     html  2020-06-10 10:37:03.665896
# 27     html  2020-06-10 10:37:03.665896
# 28     html  2020-06-10 10:37:03.665896
# 29     html  2020-06-10 10:37:03.665896
# 30     html  2020-06-10 10:37:03.665896
# 31     html  2020-06-10 10:37:03.665896
# 32     html  2020-06-10 10:37:03.665896
# 33     html  2020-06-10 10:37:03.665896
# 34     html  2020-06-10 10:37:03.665896
# 35     html  2020-06-10 10:37:03.665896
# 36     html  2020-06-10 10:37:03.665896
# 37     html  2020-06-10 10:37:03.665896
# 38     html  2020-06-10 10:37:03.665896
# 0      html  2020-06-10 10:37:03.934896
# 1      html  2020-06-10 10:37:03.934896
# 2      html  2020-06-10 10:37:03.934896
# 3      html  2020-06-10 10:37:03.934896
# 4      html  2020-06-10 10:37:03.934896
# 5      html  2020-06-10 10:37:03.934896
# 6      html  2020-06-10 10:37:03.934896
# 7      html  2020-06-10 10:37:03.934896
# 8      html  2020-06-10 10:37:03.934896
# 9      html  2020-06-10 10:37:03.934896
# 10     html  2020-06-10 10:37:03.934896
#
#                                                  name  parsed sign  \
# 0                    ukcompanieshouseregisterednumber    True  NaN
# 1                  entitycurrentlegalorregisteredname    True  NaN
# 2                                    balancesheetdate    True  NaN
# 3                         namedirectorsigningaccounts    True  NaN
# 4                         namedirectorsigningaccounts    True  NaN
# 5                                       entitydormant    True  NaN
# 6                   startdateforperiodcoveredbyreport    True  NaN
# 7                     enddateforperiodcoveredbyreport    True  NaN
# 8                                       entitytrading    True  NaN
# 9   calledupsharecapitalnotpaidnotexpressedascurre...    True  NaN
# 10  calledupsharecapitalnotpaidnotexpressedascurre...    True  NaN
# 11                                        fixedassets    True  NaN
# 12                                        fixedassets    True  NaN
# 13                                      currentassets    True  NaN
# 14                                      currentassets    True  NaN
# 15  prepaymentsaccruedincomenotexpressedwithincurr...    True  NaN
# 16  prepaymentsaccruedincomenotexpressedwithincurr...    True  NaN
# 17                          creditorsduewithinoneyear    True  NaN
# 18                          creditorsduewithinoneyear    True  NaN
# 19                        netcurrentassetsliabilities    True  NaN
# 20                        netcurrentassetsliabilities    True  NaN
# 21                  totalassetslesscurrentliabilities    True  NaN
# 22                  totalassetslesscurrentliabilities    True  NaN
# 23                           creditorsdueafteroneyear    True  NaN
# 24                           creditorsdueafteroneyear    True  NaN
# 25                    provisionsforliabilitiescharges    True  NaN
# 26                    provisionsforliabilitiescharges    True  NaN
# 27                             accrualsdeferredincome    True  NaN
# 28                             accrualsdeferredincome    True  NaN
# 29  netassetsliabilitiesincludingpensionassetliabi...    True  NaN
# 30  netassetsliabilitiesincludingpensionassetliabi...    True  NaN
# 31                                   shareholderfunds    True  NaN
# 32                                   shareholderfunds    True  NaN
# 33  companyentitledtoexemptionundersection477compa...    True  NaN
# 34       membershavenotrequiredcompanytoobtainanaudit    True  NaN
# 35  directorsacknowledgetheirresponsibilitiesunder...    True  NaN
# 36  accountsareinaccordancewithspecialprovisionsco...    True  NaN
# 37                               dateapprovalaccounts    True  NaN
# 38                                  nameentityofficer    True  NaN
# 0                              nameproductionsoftware    True  NaN
# 1                           versionproductionsoftware    True  NaN
# 2                    ukcompanieshouseregisterednumber    True  NaN
# 3                     countryformationorincorporation    True  NaN
# 4               principalcurrencyusedinbusinessreport    True  NaN
# 5                  directorsigningfinancialstatements    True  NaN
# 6       descriptionbodyauthorisingfinancialstatements    True  NaN
# 7                   startdateforperiodcoveredbyreport    True  NaN
# 8                     enddateforperiodcoveredbyreport    True  NaN
# 9                                    balancesheetdate    True  NaN
# 10                                      scopeaccounts    True  NaN
#
#            unit                                              value
# 0            NA                                           09102728
# 1            NA            SQUARE ONE PROPERTY CONSULTANTS LIMITED
# 2            NA                                         2017-06-30
# 3            NA
# 4            NA
# 5            NA                                              false
# 6            NA                                         2016-07-01
# 7            NA                                         2017-06-30
# 8            NA                                               true
# 9   iso4217:GBP                                                  0
# 10  iso4217:GBP                                                  0
# 11  iso4217:GBP                                                500
# 12  iso4217:GBP                                                500
# 13  iso4217:GBP                                                500
# 14  iso4217:GBP                                                500
# 15  iso4217:GBP                                                  0
# 16  iso4217:GBP                                                  0
# 17  iso4217:GBP                                                  0
# 18  iso4217:GBP                                                  0
# 19  iso4217:GBP                                                500
# 20  iso4217:GBP                                                500
# 21  iso4217:GBP                                               1000
# 22  iso4217:GBP                                               1000
# 23  iso4217:GBP                                                  0
# 24  iso4217:GBP                                                  0
# 25  iso4217:GBP                                                  0
# 26  iso4217:GBP                                                  0
# 27  iso4217:GBP                                                  0
# 28  iso4217:GBP                                                  0
# 29  iso4217:GBP                                               1000
# 30  iso4217:GBP                                               1000
# 31  iso4217:GBP                                               1000
# 32  iso4217:GBP                                               1000
# 33           NA  For the year ending 30 June 2017 the company w...
# 34           NA  The members have not required the company to o...
# 35           NA  The directors acknowledge their responsibiliti...
# 36           NA  The accounts have been prepared in accordance ...
# 37           NA                                         2 May 2018
# 38           NA                                    Robert Anderson
# 0            NA                            PTP Accounts Production
# 1            NA                                        v18.1.0.976
# 2            NA                                           09110532
# 3            NA                                       EnglandWales
# 4            NA                                      PoundSterling
# 5            NA                                          Director1
# 6            NA                                 Board of Directors
# 7            NA                                             1.9.16
# 8            NA                                            31.8.17
# 9            NA                                            31.8.17
# 10           NA

# %%
list_of_tags = results['name'].tolist()

list_of_tags_unique = list(set(list_of_tags))

list_of_tags_unique
# Out:
# ['recoverablevalue-addedtax',
#  'tangiblefixedassetsdepreciationdecreaseincreaseondisposals',
#  'addressline2',
#  'statementthatdirectorsacknowledgetheirresponsibilitiesundercompaniesact',
#  'reportprincipallanguage',
#  'startdateforperiodcoveredbyreport',
#  'typenonequityshare',
#  'landbuildingsdepreciationchargeforperiod',
#  'advancescreditsrepaidinperioddirectors',
#  'profitlossaccountreserve',
#  'bankborrowingsoverdrafts',
#  'creditorsdueafteroneyeartotalnoncurrentliabilities',
#  'dividendspaid',
#  'provisionspolicy',
#  'ukcompanieshouseregisterednumber',
#  'dividendpolicy',
#  'amountspecificadvanceorcreditmadeinperioddirectors',
#  'functionalpresentationcurrencypolicy',
#  'dateaccountsreceived',
#  'lesseepolicy',
#  'landbuildings',
#  'entityhasclaimedexemptionfromreportingcomparativeinformationoncertainitemssharecapitalinlinewithfrs1021.12atruefalse',
#  'calledupsharecapitalnotpaidnotexpressedascurrentasset',
#  'addressline1',
#  'descriptionfinancialcommitmentsotherthancapitalcommitments',
#  'intangibleassets',
#  'nameindividualauditor',
#  'creditorsduewithinoneyeartotalcurrentliabilities',
#  'financeincomecostspolicy',
#  'dateauditorsreport',
#  'otheraggregatereserves',
#  'entitytradingstatus',
#  'financialinstrumentsclassificationpolicy',
#  'descriptionsharetype',
#  'nameauthor',
#  'generaldescriptionchangesinaccountingpolicies',
#  'provisionsforliabilitiesbalancesheetsubtotal',
#  'entitytradingname',
#  'entitycurrentlegalorregisteredname',
#  'companyentitledtoexemptionundersection477companiesact2006',
#  'tangiblefixedassetsincreasedecreasefromrevaluations',
#  'lessoroperatingleasepolicy',
#  'costsales',
#  'staffcostsemployeebenefitsexpense',
#  'calledupsharecapital',
#  'intangiblefixedassets',
#  'accountingstandardsapplied',
#  'employeebenefitspolicy',
#  'tangiblefixedassetsadditions',
#  'nameentityauditors',
#  'taxationincludingdeferredtaxationbalancesheetsubtotal',
#  'tangiblefixedassetsdisposals',
#  'enddateforperiodcoveredbyreport',
#  'statementthataccountshavebeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#  'secureddebts',
#  'prepaymentsaccruedincome',
#  'entitydormanttruefalse',
#  'otheroperatingexpensesformat2',
#  'reportincludeslistsubsidiariestruefalse',
#  'fixturesfittingstoolsequipmentcostorvaluation',
#  'statementonscopeaccountantsreport',
#  'corporationtaxrecoverable',
#  'nominalvalueallottedsharecapital',
#  'nameparententity',
#  'tangiblefixedassets',
#  'parvalueshare',
#  'amountspecificadvanceorcreditdirectors',
#  'totalfixedassetsdepreciation',
#  'furtheritemcreditorscomponenttotalcreditors',
#  'statementthatcompanyentitledtoexemptionfromauditundersection480companiesact2006relatingtodormantcompanies',
#  'countyregion',
#  'companynotdormant',
#  'reportanamendedrevisedversionpreviouslyfiledreporttruefalse',
#  'reportaninterimfinancialstatementfrompubliclylistedentitytruefalse',
#  'typeordinaryshare',
#  'independentvaluerwasinvolvedinrevaluationpropertyplantequipmenttruefalse',
#  'tradedebtorstradereceivables',
#  'depreciationamortisationimpairmentexpense',
#  'titleaccountingpolicy',
#  'statementthatmembershavenotrequiredcompanytoobtainanaudit',
#  'nameentityaccountants',
#  'tangiblefixedassetsdepreciation',
#  'currentassets',
#  'advancescreditsmadeinperioddirectors',
#  'stocksinventory',
#  'totalnominalvalue',
#  'directororexecutivesname',
#  'entityhasclaimedexemptionfromfrs102chapters1112disclosurerequirementsinlinewithfrs1021.12ctruefalse',
#  'turnoverpolicy',
#  'othertaxationsocialsecuritypayable',
#  'advancescreditsdirectors',
#  'accrualsdeferredincome',
#  'generaldescriptionbasismeasurementusedinpreparingfinancialstatements',
#  'directorsadvancescreditguaranteesfree-textcomment',
#  'businessreportname',
#  'administrativeexpenses',
#  'valueordinarysharesauthorised',
#  'versionproductionsoftware',
#  'bankborrowings',
#  'dateapproval',
#  'statementthatmembershaveagreedtopreparationabridgedaccountsundersection444companiesact2006',
#  'reportaninitialfinancialstatementfrompubliclylistedentitytruefalse',
#  'totalfixedassetsadditions',
#  'bankloansoverdraftsafteroneyear',
#  'propertyplantequipmentfree-textcomment',
#  'disposalspropertyplantequipment',
#  'generaldescriptioncriticalestimatesjudgements',
#  'sharecapitalpolicy',
#  'companyhasactedasanagentduringperiodtruefalse',
#  'investmententityrequiredtoapplyexceptionfromconsolidationtruefalse',
#  'sharecapitalallottedcalleduppaid',
#  'entityhasclaimedexemptionfromreportingcertaininformationonsharebasedpaymentsinlinewithfrs1021.12dtruefalse',
#  'investmentsfixedassetsfreetextnote',
#  'otheroperatingincomeformat2',
#  'nameultimatecontrollingpartyifnotultimateparent',
#  'reportperiod',
#  'addressline3',
#  'numbersharesissuedinperiod-gross',
#  'entityhastakenexemptionundercompaniesactinnotpublishingitsownprofitlossaccounttruefalse',
#  'loansfromdirectors',
#  'scopeaccounts',
#  'directorsacknowledgetheirresponsibilitiesundercompaniesact',
#  'propertyplantequipmentpolicy',
#  'creditors',
#  'companyhasactedasanagentduringperiod',
#  'propertyplantequipmentgrosscost',
#  'totaladditionsincludingfrombusinesscombinationspropertyplantequipment',
#  'profitloss',
#  'comprehensiveincomeexpense',
#  'accruedliabilitiesdeferredincome',
#  'generaldescriptionadvancescreditstodirectorsincludingtermsinterestrates',
#  'taxtaxcreditonprofitorlossonordinaryactivities',
#  'investmentpropertyfairvaluemodel',
#  'reporttitle',
#  'numbersharesallotted',
#  'descriptionprincipalactivities',
#  'accumulateddepreciationnotincludingimpairmentpropertyplantequipment',
#  'positionadditionalapprovingperson',
#  'otherdisposalspropertyplantequipment',
#  'descriptionspecificadvanceorcredititsconditionsindicativeinterestratedirectors',
#  'depreciationexpensepropertyplantequipment',
#  'descriptionmeasurementbasisforpropertyplantequipment',
#  'disposalsdecreaseindepreciationimpairmentpropertyplantequipment',
#  'shareholderfunds',
#  'derivativespolicy',
#  'dateauthorisationfinancialstatementsforissue',
#  'totalfixedassetinvestmentsdisposals',
#  'netassetsliabilitiesincludingpensionassetliability',
#  'directorsigningdirectorsreport',
#  'namedirectorsigningaccounts',
#  'landbuildingscostorvaluation',
#  'tangiblefixedassetscostorvaluation',
#  'numbernonequitysharesallotted',
#  'totalnumbersharesissued',
#  'numbersharesissuedfullypaid',
#  'categoryitem',
#  'intangiblefixedassetscostorvaluation',
#  'nominalvaluesharesissuedinperiod',
#  'leasespolicy',
#  'contentadditionalnote',
#  'tangiblefixedassetsdepreciationchargedinperiod',
#  'nameentitybankers',
#  'typedepreciation',
#  'nameentityofficer',
#  'companydormant',
#  'revenuerecognitionpolicy',
#  'landbuildingsdepreciation',
#  'valueordinarysharesallotted',
#  'currentincometaxpolicy',
#  'postalcodezip',
#  'numberordinarysharesauthorised',
#  'descriptiondepreciationmethodforpropertyplantequipment',
#  'descriptionspecificguaranteeitstermsdirectors',
#  'othercreditorsduewithinoneyear',
#  'bankoverdrafts',
#  'investmentscurrentassets',
#  'grossprofitloss',
#  'value-addedtaxpayable',
#  'nameproductionsoftware',
#  'totalinvestmentsfixedassets',
#  'totalfixedassetsdisposals',
#  'fixedassets',
#  'tradecreditorstradepayables',
#  'financeleasepaymentsowingminimumgross',
#  'numbernonequitysharesauthorised',
#  'tradepayablespolicy',
#  'parvalueordinaryshare',
#  'numberordinarysharesallotted',
#  'operatingprofitloss',
#  'depreciationrateusedforpropertyplantequipment',
#  'turnoverrevenue',
#  'valuenonequitysharesauthorised',
#  'intangiblefixedassetsamortisationchargedinperiod',
#  'parvaluenonequityshare',
#  'instalmentdebtsfallingdueafter5years',
#  'descriptionwhyentitynotgoing-concernoruncertaintiesovergoing-concernstatus',
#  'creditorsdueafteroneyearfreetextnote',
#  'totalfixedassetscostorvaluation',
#  'modelusedtomeasureinvestmentproperty',
#  'descriptionbodyauthorisingfinancialstatements',
#  'fixturesfittingstoolsequipmentadditions',
#  'employeeinformationfree-textcomment',
#  'investmentsfixedassetsdepreciation',
#  'companieshousedocumentauthentication',
#  'accountsareinaccordancewithspecialprovisionscompaniesactrelatingtosmallcompanies',
#  'statementonrelatedpartydisclosure',
#  'otherinterestreceivablesimilarincomefinanceincome',
#  'contentotherspecificaccountingpolicy',
#  'statementonbasismeasurementpreparationaccounts',
#  'amountsowedtogroupundertakingsparticipatinginterests',
#  'controllingpartyultimatecontrollingpartytruefalse',
#  'intangiblefixedassetsaggregateamortisationimpairment',
#  'statementcompliancewithapplicablereportingframework',
#  'otherdebtors',
#  'descriptionortitleauthor',
#  'accruedliabilitiesnotexpressedwithincreditorssubtotal',
#  'netassetsliabilities',
#  'prepayments',
#  'ratedepreciation',
#  'othercreditors',
#  'landbuildingsadditions',
#  'incomestatementfree-textcomment',
#  'frsseversiondate',
#  'landbuildingsdisposals',
#  'principallocation-cityortown',
#  'finishedgoods',
#  'directorsreportconsistentwithaccountstruefalse',
#  'investmentsfixedassets',
#  'statementthatdirectorsreporthasbeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#  'accountstypefullorabbreviated',
#  'countryformationorincorporation',
#  'increasefromdepreciationchargeforyearpropertyplantequipment',
#  'entityhasclaimedexemptionfromreportingdisclosurerelatedpartytransactionsforgovernment-relatedentitiestruefalse',
#  'cashbankinhand',
#  'companyentitledtoexemptionundersection480companiesact2006',
#  'intangibleassetsfreetextnote',
#  'totalfixedassetsdepreciationdisposals',
#  'corporationtaxpayable',
#  'foreignexchangerate',
#  'cashbankonhand',
#  'nameordescriptionrelatedpartyifnotdefinedbyanothertag',
#  'fixturesfittingstoolsequipment',
#  'amountsowedtogroupundertakings',
#  'entityhasclaimedexemptionfromreportingdisclosurekeymanagementpersonnelcompensationtruefalse',
#  'fixturesfittingstoolsequipmentdepreciation',
#  'tangiblefixedassetsdepreciationchargeforperiod',
#  'landbuildingsdepreciationdisposals',
#  'membershavenotrequiredcompanytoobtainanaudit',
#  'dateapprovalaccounts',
#  'propertyplantequipment',
#  'equity',
#  'investmentsfixedassetsrevaluations',
#  'entityhasclaimedexemptionfrompresentingcashflowstatementnotesinlinewithfrs1021.12btruefalse',
#  'amountsowedtorelatedparties',
#  'namecontrollingparty',
#  'entityhasclaimedexemptionfromreportingdisclosurerelatedpartytransactionsforwholly-ownedentitiestruefalse',
#  'debtors',
#  'definedbenefitplanmulti-employerplantruefalse',
#  'totalconsideration',
#  'fixturesfittingstoolsequipmentdepreciationchargeforperiod',
#  'companieshouseregisterednumber',
#  'deferredincome',
#  'investmentsingroupundertakings',
#  'statementthatcompanyentitledtoexemptionfromauditundersection477companiesact2006relatingtosmallcompanies',
#  'merchandise',
#  'entitycurrentlegalname',
#  'companyhaspublishedcommitmenttoukeffectivestewardshipcodetruefalse',
#  'dateaccountantsreport',
#  'entitydormant',
#  'averagenumberemployeesduringperiod',
#  'accumulateddepreciationimpairmentpropertyplantequipment',
#  'tradereceivablespolicy',
#  'accountantsreportonfinancialstatements',
#  'provisionsforliabilitiescharges',
#  'definedcontributionpensionspolicy',
#  'amountsowedbygroupundertakings',
#  'nameorlocationaccountantsoffice',
#  'netcurrentassetsliabilities',
#  'accruedliabilities',
#  'profitlossonordinaryactivitiesbeforetax',
#  'impairmentnon-financialassetspolicy',
#  'borrowingcostspolicy',
#  'finaldividendspaid',
#  'sharecapitalfreetextnote',
#  'revaluationreserve',
#  'capitalemployed',
#  'taxationsocialsecuritypayable',
#  'contentaccountingpolicy',
#  'amountsowedtodirectors',
#  'companyentitledtoexemptionundersection480companiesact2006relatingtodormantcompanies',
#  'generaldescriptioneffectsfirsttimeadoptionreasonsforchangeotherfactorsrelevanttotransition',
#  'fixturesfittingstoolsequipmentdisposals',
#  'cashcashequivalentspolicy',
#  'administrationsupportaveragenumberemployees',
#  'tangibleassetsfreetextnote',
#  'taxpolicy',
#  'otherdisposalsdecreaseindepreciationimpairmentpropertyplantequipment',
#  'intangiblefixedassetsadditions',
#  'tangiblefixedassetsdepreciationdisposals',
#  'totalfixedassetsrevaluation',
#  'sharepremiumaccount',
#  'financeleaseliabilitiespresentvaluetotal',
#  'legalformentity',
#  'prepaymentsaccruedincomenotexpressedwithincurrentassetsubtotal',
#  'creditorsduewithinoneyear',
#  'financialinstrumentsrecognitionmeasurementpolicy',
#  'entitytrading',
#  'totaladditionsincludingfrombusinesscombinationsintangibleassets',
#  'principalcurrencyusedinbusinessreport',
#  'nameapprovingdirector',
#  'totalfixedassetsfreetextnote',
#  'titleadditionalnote',
#  'foreigncurrencytranslationoperationspolicy',
#  'datesigningdirectorsreport',
#  'amountspecificadvanceorcreditrepaidinperioddirectors',
#  'investmentproperty',
#  'financialstatementsarepreparedongoing-concernbasistruefalse',
#  'inventoriespolicy',
#  'tangiblefixedassetspolicy',
#  'nameadditionalapprovingperson',
#  'totalfixedassetinvestmentscostorvaluation',
#  'intangibleassetsgrosscost',
#  'accountsstatusauditedorunaudited',
#  'applicablelegislation',
#  'fixturesfittingstoolsequipmentdepreciationdisposals',
#  'directorsigningfinancialstatements',
#  'totalfixedassetsdepreciationchargeinperiod',
#  'totalfixedassetinvestmentsadditions',
#  'valuenonequitysharesallotted',
#  'totalassetslesscurrentliabilities',
#  'vatregistrationnumber',
#  'creditorsdueafteroneyear',
#  'totalinventories',
#  'intangibleassetspolicy',
#  'tangiblefixedassetsincreasedecreasefromtransfersbetweenitems',
#  'additionsotherthanthroughbusinesscombinationspropertyplantequipment',
#  'balancesheetdate',
#  'descriptionnaturepurposereserveswithinequity',
#  'deferredtaxpolicy',
#  'transactionswithdirectors']

# %%
print(len(list_of_tags))

print(len(list_of_tags_unique))

with open('D:\Project_3 - Image_Processing\list_of_tags.txt', 'w') as f:
    for item in list_of_tags_unique:
        f.write("%s\n" % item)
# Out:
# 22174
# 340
