# %% [markdown]
# <a id='section1'></a>
# <div style="
#     width: 100%;
#     height: 100px;
#     border:none;
#     background:linear-gradient(-45deg, #d84227, #ce3587);
#     text-align: center;
#     position: relative;
# ">
#   <span style="
#       font-size: 40px;
#       padding: 0 10px;
#       color: white;
#       margin: 0;
#       position: absolute;
#       top: 50%;
#       left: 50%;
#       -ms-transform: translate(-50%, -50%);
#       transform: translate(-50%, -50%);
#       font-weight: bold;
#   ">
#     XBRL PARSER <!--Padding is optional-->
#   </span>
# </div><a id='section1'></a>

# %%
"""
Martin Wood - Office for National Statistics
martin.wood@ons.gov.uk
23/07/2018
XBRL parser
Contains functions that scrape and clean an XBRL document's content
and variables, returning a dict ready for dumping into
MongoDB.
"""

import os
import re

import numpy as np
import pandas as pd

from datetime import datetime
from dateutil import parser
from bs4 import BeautifulSoup as BS  # Can parse xml or html docs

# Table of variables and values that indicate consolidated status
consolidation_var_table = {
    "includedinconsolidationsubsidiary": True,
    "investmententityrequiredtoapplyexceptionfromconsolidationtruefalse": True,
    "subsidiaryunconsolidatedtruefalse": False,
    "descriptionreasonwhyentityhasnotpreparedconsolidatedfinancialstatements": "exist",
    "consolidationpolicy": "exist"
}


def clean_value(string):
    """
    Take a value that's stored as a string,
    clean it and convert to numeric.

    If it's just a dash, it's taken to mean
    zero.
    """
    if string.strip() == "-":
        return (0.0)

    try:
        return float(string.strip().replace(",", "").replace(" ", ""))
    except:
        pass

    return (string)


def retrieve_from_context(soup, contextref):
    """
    Used where an element of the document contained no data, only a
    reference to a context element.
    Finds the relevant context element and retrieves the relevant data.

    Returns a text string

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    contextref -- the id of the context element to be raided
    """

    try:
        context = soup.find("xbrli:context", id=contextref)
        contents = context.find("xbrldi:explicitmember").get_text().split(":")[-1].strip()

    except:
        contents = ""

    return (contents)


def retrieve_accounting_standard(soup):
    """
    Gets the account reporting standard in use in a document by hunting
    down the link to the schema reference sheet that always appears to
    be in the document, and extracting the format and standard date from
    the string of the url itself.
    WARNING - That means that there's a lot of implicity hardcoded info
    on the way these links are formated and referenced, within this
    function.  Might need changing someday.

    Returns a 3-tuple (standard, date, original url)

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    """

    # Find the relevant link by its unique attribute
    link_obj = soup.find("link:schemaref")

    # If we didn't find anything it's an xml doc using a different
    # element name:
    if link_obj == None:
        link_obj = soup.find("schemaref")

    # extract the name of the .xsd schema file, which contains format
    # and date information
    text = link_obj['xlink:href'].split("/")[-1].split(".")[0]

    # Split the extracted text into format and date, return values
    return (text[:-10].strip("-"), text[-10:], link_obj['xlink:href'])


def retrieve_unit(soup, each):
    """
    Gets the reporting unit by trying to chase a unitref to
    its source, alternatively uses element attribute unitref
    if it's not a reference to another element.

    Returns the unit

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    each -- element of BeautifulSoup souped object
    """

    # If not, try to discover the unit string in the
    # soup object
    try:
        unit_str = soup.find(id=each['unitref']).get_text()

    except:
        # Or if not, in the attributes of the element
        try:
            unit_str = each.attrs['unitref']

        except:
            return ("NA")

    return (unit_str.strip())


def retrieve_date(soup, each):
    """
    Gets the reporting date by trying to chase a contextref
    to its source and extract its period, alternatively uses
    element attribute contextref if it's not a reference
    to another element.
    Returns the date

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    each -- element of BeautifulSoup souped object
    """

    # Try to find a date tag within the contextref element,
    # starting with the most specific tags, and starting with
    # those for ixbrl docs as it's the most common file.
    date_tag_list = ["xbrli:enddate",
                     "xbrli:instant",
                     "xbrli:period",
                     "enddate",
                     "instant",
                     "period"]

    for tag in date_tag_list:
        try:
            date_str = each['contextref']
            date_val = parser.parse(soup.find(id=each['contextref']).find(tag).get_text()). \
                date(). \
                isoformat()
            return (date_val)
        except:
            pass

    try:
        date_str = each.attrs['contextref']
        date_val = parser.parse(each.attrs['contextref']). \
            date(). \
            isoformat()
        return (date_val)
    except:
        pass

    return ("NA")


def parse_element(soup, element):
    """
    For a discovered XBRL tagged element, go through, retrieve its name
    and value and associated metadata.

    Keyword arguments:
    soup -- BeautifulSoup object of accounts document
    element -- soup object of discovered tagged element
    """

    if "contextref" not in element.attrs:
        return ({})

    element_dict = {}

    # Basic name and value
    try:
        # Method for XBRLi docs first
        element_dict['name'] = element.attrs['name'].lower().split(":")[-1]
    except:
        # Method for XBRL docs second
        element_dict['name'] = element.name.lower().split(":")[-1]

    element_dict['value'] = element.get_text()
    element_dict['unit'] = retrieve_unit(soup, element)
    element_dict['date'] = retrieve_date(soup, element)

    # If there's no value retrieved, try raiding the associated context data
    if element_dict['value'] == "":
        element_dict['value'] = retrieve_from_context(soup, element.attrs['contextref'])

    # If the value has a defined unit (eg a currency) convert to numeric	
    if element_dict['unit'] != "NA":
        element_dict['value'] = clean_value(element_dict['value'])

    # Retrieve sign of element if exists
    try:
        element_dict['sign'] = element.attrs['sign']

        # if it's negative, convert the value then and there
        if element_dict['sign'].strip() == "-":
            element_dict['value'] = 0.0 - element_dict['value']
    except:
        pass

    return (element_dict)


def parse_elements(element_set, soup):
    """
    For a set of discovered elements within a document, try to parse
    them.  Only keep valid results (test is whether field "name"
    exists).

    Keyword arguments:
    element_set -- BeautifulSoup iterable search result object
    soup -- BeautifulSoup object of accounts document
    """
    elements = []
    for each in element_set:
        element_dict = parse_element(soup, each)
        if 'name' in element_dict:
            elements.append(element_dict)
    return (elements)


def summarise_by_sum(doc, variable_names):
    """
    Takes a document (dict) after extraction, and tries to extract
    a summary variable relating to the financial state of the enterprise
    by summing all those named that exist.  Returns dict.

    Keyword arguments:
    doc -- an extracted document dict, with "elements" entry as created
           by the 'scrape_clean_elements' functions.
    variable_names - variables to find and sum if they exist
    """

    # Convert elements to pandas df
    df = pd.DataFrame(doc['elements'])

    # Subset to most recent (latest dated)
    df = df[df['date'] == doc['doc_balancesheetdate']]

    total_assets = 0.0
    unit = "NA"

    # Find the total assets by summing components
    for each in variable_names:

        # Fault-tolerant, will skip whatever isn't numeric
        try:
            total_assets = total_assets + df[df['name'] == each].iloc[0]['value']

            # Retrieve reporting unit if exists
            unit = df[df['name'] == each].iloc[0]['unit']

        except:
            pass

    return ({"total_assets": total_assets, "unit": unit})


def summarise_by_priority(doc, variable_names):
    """
    Takes a document (dict) after extraction, and tries to extract
    a summary variable relating to the financial state of the enterprise
    by looking for each named, in order.  Returns dict.

    Keyword arguments:
    doc -- an extracted document dict, with "elements" entry as created
           by the 'scrape_clean_elements' functions.
    variable_names - variables to find and check if they exist.
    """

    # Convert elements to pandas df
    df = pd.DataFrame(doc['elements'])

    # Subset to most recent (latest dated)
    df = df[df['date'] == doc['doc_balancesheetdate']]

    primary_assets = 0.0
    unit = "NA"

    # Find the net asset/liability variable by hunting names in order
    for each in variable_names:
        try:

            # Fault tolerant, will skip whatever isn't numeric
            primary_assets = df[df['name'] == each].iloc[0]['value']

            # Retrieve reporting unit if it exists
            unit = df[df['name'] == each].iloc[0]['unit']
            break

        except:
            pass

    return ({"primary_assets": primary_assets, "unit": unit})


def summarise_set(doc, variable_names):
    """
    Takes a document (dict) after extraction, and tries to extract
    summary variables relating to the financial state of the enterprise
    by returning all those named that exist.  Returns dict.

    Keyword arguments:
    doc -- an extracted document dict, with "elements" entry as created
           by the 'scrape_clean_elements' functions.
    variable_names - variables to find and return if they exist.
    """
    results = {}

    # Convert elements to pandas df
    df = pd.DataFrame(doc['elements'])

    # Subset to most recent (latest dated)
    df = df[df['date'] == doc['doc_balancesheetdate']]

    # Find all the variables of interest should they exist
    for each in variable_names:
        try:
            results[each] = df[df['name'] == each].iloc[0]['value']

        except:
            pass

    # Send the variables back to be appended
    return (results)


def scrape_elements(soup, filepath):
    """
    Parses an XBRL (xml) company accounts file
    for all labelled content and extracts the
    content (and metadata, eg; unitref) of each
    element found to a dictionary 

    params: filepath (str)
    output: list of dicts
    """

    # Try multiple methods of retrieving data, I think only the first is
    # now needed though.  The rest will be removed after testing this
    # but should not affect execution speed.
    try:
        element_set = soup.find_all()
        elements = parse_elements(element_set, soup)
        if len(elements) <= 5:
            raise Exception("Elements should be gte 5, was {}".format(len(elements)))
        return (elements)
    except:
        pass

    return (0)


def flatten_data(doc):
    """
    Takes the data returned by process account, with its tree-like
    structure and reorganises it into a long-thin format table structure
    suitable for SQL applications.
    """

    # Need to drop components later, so need copy in function
    doc2 = doc.copy()
    doc_df = pd.DataFrame()

    # Pandas should create series, then columns, from dicts when called
    # like this
    for element in doc2['elements']:
        doc_df = doc_df.append(element, ignore_index=True)

    # Dump the "elements" entry in the doc dict
    doc2.pop("elements")

    # Create uniform columns for all other properties
    for key in doc2:
        doc_df[key] = doc2[key]

    return (doc_df)


def process_account(filepath):
    """
    Scrape all of the relevant information from
    an iXBRL (html) file, upload the elements
    and some metadata to a mongodb.

    Named arguments:
    filepath -- complete filepath (string) from drive root
    """
    doc = {}

    # Some metadata, doc name, upload date/time, archive file it came from
    doc['doc_name'] = filepath.split("/")[-1]
    doc['doc_type'] = filepath.split(".")[-1].lower()
    doc['doc_upload_date'] = str(datetime.now())
    doc['arc_name'] = filepath.split("/")[-2]
    doc['parsed'] = True

    # Complicated ones
    sheet_date = filepath.split("/")[-1].split(".")[0].split("_")[-1]
    doc['doc_balancesheetdate'] = datetime.strptime(sheet_date, "%Y%m%d").date().isoformat()

    doc['doc_companieshouseregisterednumber'] = filepath.split("/")[-1].split(".")[0].split("_")[-2]

#     print(filepath)

    try:
        soup = BS(open(filepath, "rb"), "html.parser")
    except:
        print("Failed to open: " + filepath)
        return (1)

    # Get metadata about the accounting standard used
    try:
        doc['doc_standard_type'], doc['doc_standard_date'], doc['doc_standard_link'] = retrieve_accounting_standard(
            soup)
    except:
        doc['doc_standard_type'], doc['doc_standard_date'], doc['doc_standard_link'] = (0, 0, 0)

    # Fetch all the marked elements of the document
    try:
        doc['elements'] = scrape_elements(soup, filepath)
    except Exception as e:
        doc['parsed'] = False
        doc['Error'] = e

    try:
        return (doc)
    except Exception as e:
        return (e)

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br>
# <a id='section1'></a>
# <div style="
#     width: 100%;
#     height: 100px;
#     border:none;
#     background:linear-gradient(-45deg, #d84227, #ce3587);
#     text-align: center;
#     position: relative;
# ">
#   <span style="
#       font-size: 40px;
#       padding: 0 10px;
#       color: white;
#       margin: 0;
#       position: absolute;
#       top: 50%;
#       left: 50%;
#       -ms-transform: translate(-50%, -50%);
#       transform: translate(-50%, -50%);
#       font-weight: bold;
#   ">
#     EXTRACTION <!--Padding is optional-->
#   </span>
# </div><a id='section1'></a>

# %%
import os
import numpy as np
import pandas as pd
import importlib

def get_filepaths(directory):

    """ Helper function - 
    Get all of the filenames in a directory that
    end in htm* or xml.
    Under the assumption that all files within
    the folder are financial records. """

    files = [directory + "/" + filename
                for filename in os.listdir(directory)
                    if (("htm" in filename.lower()) or ("xml" in filename.lower()))]
    return(files)

# %%
# Get all the filenames from the example folder
files = get_filepaths("../data/for_testing/xbrl_decompressed_data")

print(len(files))

# There's 379 examples currently
files[0:3]
# Out:
# 24430
# ['../data/for_testing/xbrl_decompressed_data/Prod223_2623_07975900_20190331.html',
#  '../data/for_testing/xbrl_decompressed_data/Prod223_2623_10843698_20190630.html',
#  '../data/for_testing/xbrl_decompressed_data/Prod223_2623_10962545_20190630.html']

# %%
doc = process_account(files[0])

# display for fun
doc
# Out:
# {'doc_name': 'Prod223_2623_07975900_20190331.html',
#  'doc_type': 'html',
#  'doc_upload_date': '2020-06-10 15:23:32.716835',
#  'arc_name': 'xbrl_decompressed_data',
#  'parsed': True,
#  'doc_balancesheetdate': '2019-03-31',
#  'doc_companieshouseregisterednumber': '07975900',
#  'doc_standard_type': 'FRS-102',
#  'doc_standard_date': '2019-01-01',
#  'doc_standard_link': 'https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS-102-2019-01-01.xsd',
#  'elements': [{'name': 'startdateforperiodcoveredbyreport',
#    'value': '1 April 2018',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'reportperiod', 'value': '', 'unit': 'NA', 'date': '2019-03-31'},
#   {'name': 'nameproductionsoftware',
#    'value': ' 4.5.3 micro_entity_frs_105_v1_0_5 filing',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'versionproductionsoftware',
#    'value': 'Software',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'entitytradingstatus',
#    'value': '',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'entitydormanttruefalse',
#    'value': 'false',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'financialstatementsarepreparedongoing-concernbasistruefalse',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'directorsreportconsistentwithaccountstruefalse',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'controllingpartyultimatecontrollingpartytruefalse',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'descriptionprincipalactivities',
#    'value': 'No description of principal activity',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'countryformationorincorporation',
#    'value': 'EnglandWales',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'accountsstatusauditedorunaudited',
#    'value': 'AuditExemptWithAccountantsReport',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'legalformentity',
#    'value': 'PrivateLimitedCompanyLtd',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'accountingstandardsapplied',
#    'value': 'Micro-entities',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'accountstypefullorabbreviated',
#    'value': 'FullAccounts',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'directorsigningdirectorsreport',
#    'value': 'Director1',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'directorsigningfinancialstatements',
#    'value': 'Director1',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'principalcurrencyusedinbusinessreport',
#    'value': '',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'reportprincipallanguage',
#    'value': '',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'entityhastakenexemptionundercompaniesactinnotpublishingitsownprofitlossaccounttruefalse',
#    'value': 'true',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'ukcompanieshouseregisterednumber',
#    'value': '07975900',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'entitycurrentlegalorregisteredname',
#    'value': 'KPS Electrical Ltd',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'enddateforperiodcoveredbyreport',
#    'value': '31 March 2019',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'entitycurrentlegalorregisteredname',
#    'value': 'KPS Electrical Ltd',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'balancesheetdate',
#    'value': '31 March 2019',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'fixedassets',
#    'value': 3894.0,
#    'unit': 'iso4217:GBP',
#    'date': '2019-03-31'},
#   {'name': 'fixedassets',
#    'value': 5191.0,
#    'unit': 'iso4217:GBP',
#    'date': '2018-03-31'},
#   {'name': 'currentassets',
#    'value': 8894.0,
#    'unit': 'iso4217:GBP',
#    'date': '2019-03-31'},
#   {'name': 'currentassets',
#    'value': 10163.0,
#    'unit': 'iso4217:GBP',
#    'date': '2018-03-31'},
#   {'name': 'creditors',
#    'value': 6144.0,
#    'unit': 'iso4217:GBP',
#    'date': '2019-03-31'},
#   {'name': 'creditors',
#    'value': 6811.0,
#    'unit': 'iso4217:GBP',
#    'date': '2018-03-31'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': 2750.0,
#    'unit': 'iso4217:GBP',
#    'date': '2019-03-31'},
#   {'name': 'netcurrentassetsliabilities',
#    'value': 3352.0,
#    'unit': 'iso4217:GBP',
#    'date': '2018-03-31'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 6644.0,
#    'unit': 'iso4217:GBP',
#    'date': '2019-03-31'},
#   {'name': 'totalassetslesscurrentliabilities',
#    'value': 8543.0,
#    'unit': 'iso4217:GBP',
#    'date': '2018-03-31'},
#   {'name': 'accruedliabilitiesdeferredincome',
#    'value': 1357.0,
#    'unit': 'iso4217:GBP',
#    'date': '2019-03-31'},
#   {'name': 'accruedliabilitiesdeferredincome',
#    'value': 901.0,
#    'unit': 'iso4217:GBP',
#    'date': '2018-03-31'},
#   {'name': 'netassetsliabilities',
#    'value': 5287.0,
#    'unit': 'iso4217:GBP',
#    'date': '2019-03-31'},
#   {'name': 'netassetsliabilities',
#    'value': 7642.0,
#    'unit': 'iso4217:GBP',
#    'date': '2018-03-31'},
#   {'name': 'equity',
#    'value': 5287.0,
#    'unit': 'iso4217:GBP',
#    'date': '2019-03-31'},
#   {'name': 'equity',
#    'value': 7642.0,
#    'unit': 'iso4217:GBP',
#    'date': '2018-03-31'},
#   {'name': 'addressline1',
#    'value': '84 Manor Road',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'principallocation-cityortown',
#    'value': 'Lancing',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'countyregion',
#    'value': 'West Sussex',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'postalcodezip',
#    'value': 'BN15 0HD',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'averagenumberemployeesduringperiod',
#    'value': -1.0,
#    'unit': 'xbrli:pure',
#    'date': '2019-03-31',
#    'sign': '-'},
#   {'name': 'averagenumberemployeesduringperiod',
#    'value': -1.0,
#    'unit': 'xbrli:pure',
#    'date': '2018-03-31',
#    'sign': '-'},
#   {'name': 'statementthatcompanyentitledtoexemptionfromauditundersection477companiesact2006relatingtosmallcompanies',
#    'value': '\nFor the year ending 31 March 2019, the company was entitled to exemption from audit under section 477 of the Companies Act 2006 relating to small companies.\n',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'enddateforperiodcoveredbyreport',
#    'value': '31 March 2019',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'statementthatmembershavenotrequiredcompanytoobtainanaudit',
#    'value': 'The members have not required the company to obtain an audit of its financial statements for the year in question in accordance with section 476;',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'statementthatdirectorsacknowledgetheirresponsibilitiesundercompaniesact',
#    'value': 'The director acknowledges their responsibilities for complying with the requirements of the Act with respect to accounting records and the preparation of financial statements.',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'statementthataccountshavebeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#    'value': '\n    These financial statements have been prepared in accordance with the micro-entity provisions and have been delivered in accordance with the provisions applicable to companies subject to the small companies regime.\n  ',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'descriptionbodyauthorisingfinancialstatements',
#    'value': 'board of directors',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'dateauthorisationfinancialstatementsforissue',
#    'value': '30 March 2020',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'nameentityofficer',
#    'value': 'Mr W Dewhurst',
#    'unit': 'NA',
#    'date': '2019-03-31'},
#   {'name': 'ukcompanieshouseregisterednumber',
#    'value': '07975900',
#    'unit': 'NA',
#    'date': '2019-03-31'}]}

# %%
doc['elements']
# Out:
# [{'name': 'startdateforperiodcoveredbyreport',
#   'value': '1 April 2018',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'reportperiod', 'value': '', 'unit': 'NA', 'date': '2019-03-31'},
#  {'name': 'nameproductionsoftware',
#   'value': ' 4.5.3 micro_entity_frs_105_v1_0_5 filing',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'versionproductionsoftware',
#   'value': 'Software',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'entitytradingstatus',
#   'value': '',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'entitydormanttruefalse',
#   'value': 'false',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'financialstatementsarepreparedongoing-concernbasistruefalse',
#   'value': 'true',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'directorsreportconsistentwithaccountstruefalse',
#   'value': 'true',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'controllingpartyultimatecontrollingpartytruefalse',
#   'value': 'true',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'descriptionprincipalactivities',
#   'value': 'No description of principal activity',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'countryformationorincorporation',
#   'value': 'EnglandWales',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'accountsstatusauditedorunaudited',
#   'value': 'AuditExemptWithAccountantsReport',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'legalformentity',
#   'value': 'PrivateLimitedCompanyLtd',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'accountingstandardsapplied',
#   'value': 'Micro-entities',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'accountstypefullorabbreviated',
#   'value': 'FullAccounts',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'directorsigningdirectorsreport',
#   'value': 'Director1',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'directorsigningfinancialstatements',
#   'value': 'Director1',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'principalcurrencyusedinbusinessreport',
#   'value': '',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'reportprincipallanguage',
#   'value': '',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'entityhastakenexemptionundercompaniesactinnotpublishingitsownprofitlossaccounttruefalse',
#   'value': 'true',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'ukcompanieshouseregisterednumber',
#   'value': '07975900',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'entitycurrentlegalorregisteredname',
#   'value': 'KPS Electrical Ltd',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'enddateforperiodcoveredbyreport',
#   'value': '31 March 2019',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'entitycurrentlegalorregisteredname',
#   'value': 'KPS Electrical Ltd',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'balancesheetdate',
#   'value': '31 March 2019',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'fixedassets',
#   'value': 3894.0,
#   'unit': 'iso4217:GBP',
#   'date': '2019-03-31'},
#  {'name': 'fixedassets',
#   'value': 5191.0,
#   'unit': 'iso4217:GBP',
#   'date': '2018-03-31'},
#  {'name': 'currentassets',
#   'value': 8894.0,
#   'unit': 'iso4217:GBP',
#   'date': '2019-03-31'},
#  {'name': 'currentassets',
#   'value': 10163.0,
#   'unit': 'iso4217:GBP',
#   'date': '2018-03-31'},
#  {'name': 'creditors',
#   'value': 6144.0,
#   'unit': 'iso4217:GBP',
#   'date': '2019-03-31'},
#  {'name': 'creditors',
#   'value': 6811.0,
#   'unit': 'iso4217:GBP',
#   'date': '2018-03-31'},
#  {'name': 'netcurrentassetsliabilities',
#   'value': 2750.0,
#   'unit': 'iso4217:GBP',
#   'date': '2019-03-31'},
#  {'name': 'netcurrentassetsliabilities',
#   'value': 3352.0,
#   'unit': 'iso4217:GBP',
#   'date': '2018-03-31'},
#  {'name': 'totalassetslesscurrentliabilities',
#   'value': 6644.0,
#   'unit': 'iso4217:GBP',
#   'date': '2019-03-31'},
#  {'name': 'totalassetslesscurrentliabilities',
#   'value': 8543.0,
#   'unit': 'iso4217:GBP',
#   'date': '2018-03-31'},
#  {'name': 'accruedliabilitiesdeferredincome',
#   'value': 1357.0,
#   'unit': 'iso4217:GBP',
#   'date': '2019-03-31'},
#  {'name': 'accruedliabilitiesdeferredincome',
#   'value': 901.0,
#   'unit': 'iso4217:GBP',
#   'date': '2018-03-31'},
#  {'name': 'netassetsliabilities',
#   'value': 5287.0,
#   'unit': 'iso4217:GBP',
#   'date': '2019-03-31'},
#  {'name': 'netassetsliabilities',
#   'value': 7642.0,
#   'unit': 'iso4217:GBP',
#   'date': '2018-03-31'},
#  {'name': 'equity',
#   'value': 5287.0,
#   'unit': 'iso4217:GBP',
#   'date': '2019-03-31'},
#  {'name': 'equity',
#   'value': 7642.0,
#   'unit': 'iso4217:GBP',
#   'date': '2018-03-31'},
#  {'name': 'addressline1',
#   'value': '84 Manor Road',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'principallocation-cityortown',
#   'value': 'Lancing',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'countyregion',
#   'value': 'West Sussex',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'postalcodezip',
#   'value': 'BN15 0HD',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'averagenumberemployeesduringperiod',
#   'value': -1.0,
#   'unit': 'xbrli:pure',
#   'date': '2019-03-31',
#   'sign': '-'},
#  {'name': 'averagenumberemployeesduringperiod',
#   'value': -1.0,
#   'unit': 'xbrli:pure',
#   'date': '2018-03-31',
#   'sign': '-'},
#  {'name': 'statementthatcompanyentitledtoexemptionfromauditundersection477companiesact2006relatingtosmallcompanies',
#   'value': '\nFor the year ending 31 March 2019, the company was entitled to exemption from audit under section 477 of the Companies Act 2006 relating to small companies.\n',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'enddateforperiodcoveredbyreport',
#   'value': '31 March 2019',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'statementthatmembershavenotrequiredcompanytoobtainanaudit',
#   'value': 'The members have not required the company to obtain an audit of its financial statements for the year in question in accordance with section 476;',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'statementthatdirectorsacknowledgetheirresponsibilitiesundercompaniesact',
#   'value': 'The director acknowledges their responsibilities for complying with the requirements of the Act with respect to accounting records and the preparation of financial statements.',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'statementthataccountshavebeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#   'value': '\n    These financial statements have been prepared in accordance with the micro-entity provisions and have been delivered in accordance with the provisions applicable to companies subject to the small companies regime.\n  ',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'descriptionbodyauthorisingfinancialstatements',
#   'value': 'board of directors',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'dateauthorisationfinancialstatementsforissue',
#   'value': '30 March 2020',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'nameentityofficer',
#   'value': 'Mr W Dewhurst',
#   'unit': 'NA',
#   'date': '2019-03-31'},
#  {'name': 'ukcompanieshouseregisterednumber',
#   'value': '07975900',
#   'unit': 'NA',
#   'date': '2019-03-31'}]

# %%
# Loop through the document, retrieving any element with a matching name
for element in doc['elements']:
    if element['name'] == 'balancesheetdate':
        print(element)
# Out:
# {'name': 'balancesheetdate', 'value': '31 March 2019', 'unit': 'NA', 'date': '2019-03-31'}

# %%
# Extract the all the data to long-thin table format for use with SQL
# Note, tables from docs should be appendable to one another to create
# tables of all data
flatten_data(doc).head(15)
# Out:
#           date                                               name unit  \
# 0   2019-03-31                  startdateforperiodcoveredbyreport   NA
# 1   2019-03-31                                       reportperiod   NA
# 2   2019-03-31                             nameproductionsoftware   NA
# 3   2019-03-31                          versionproductionsoftware   NA
# 4   2019-03-31                                entitytradingstatus   NA
# 5   2019-03-31                             entitydormanttruefalse   NA
# 6   2019-03-31  financialstatementsarepreparedongoing-concernb...   NA
# 7   2019-03-31     directorsreportconsistentwithaccountstruefalse   NA
# 8   2019-03-31  controllingpartyultimatecontrollingpartytruefalse   NA
# 9   2019-03-31                     descriptionprincipalactivities   NA
# 10  2019-03-31                    countryformationorincorporation   NA
# 11  2019-03-31                   accountsstatusauditedorunaudited   NA
# 12  2019-03-31                                    legalformentity   NA
# 13  2019-03-31                         accountingstandardsapplied   NA
# 14  2019-03-31                      accountstypefullorabbreviated   NA
#
#                                         value sign  \
# 0                                1 April 2018  NaN
# 1                                              NaN
# 2    4.5.3 micro_entity_frs_105_v1_0_5 filing  NaN
# 3                                    Software  NaN
# 4                                              NaN
# 5                                       false  NaN
# 6                                        true  NaN
# 7                                        true  NaN
# 8                                        true  NaN
# 9        No description of principal activity  NaN
# 10                               EnglandWales  NaN
# 11           AuditExemptWithAccountantsReport  NaN
# 12                   PrivateLimitedCompanyLtd  NaN
# 13                             Micro-entities  NaN
# 14                               FullAccounts  NaN
#
#                                doc_name doc_type             doc_upload_date  \
# 0   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 1   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 2   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 3   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 4   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 5   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 6   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 7   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 8   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 9   Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 10  Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 11  Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 12  Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 13  Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
# 14  Prod223_2623_07975900_20190331.html     html  2020-06-10 15:23:32.716835
#
#                   arc_name  parsed doc_balancesheetdate  \
# 0   xbrl_decompressed_data    True           2019-03-31
# 1   xbrl_decompressed_data    True           2019-03-31
# 2   xbrl_decompressed_data    True           2019-03-31
# 3   xbrl_decompressed_data    True           2019-03-31
# 4   xbrl_decompressed_data    True           2019-03-31
# 5   xbrl_decompressed_data    True           2019-03-31
# 6   xbrl_decompressed_data    True           2019-03-31
# 7   xbrl_decompressed_data    True           2019-03-31
# 8   xbrl_decompressed_data    True           2019-03-31
# 9   xbrl_decompressed_data    True           2019-03-31
# 10  xbrl_decompressed_data    True           2019-03-31
# 11  xbrl_decompressed_data    True           2019-03-31
# 12  xbrl_decompressed_data    True           2019-03-31
# 13  xbrl_decompressed_data    True           2019-03-31
# 14  xbrl_decompressed_data    True           2019-03-31
#
#    doc_companieshouseregisterednumber doc_standard_type doc_standard_date  \
# 0                            07975900           FRS-102        2019-01-01
# 1                            07975900           FRS-102        2019-01-01
# 2                            07975900           FRS-102        2019-01-01
# 3                            07975900           FRS-102        2019-01-01
# 4                            07975900           FRS-102        2019-01-01
# 5                            07975900           FRS-102        2019-01-01
# 6                            07975900           FRS-102        2019-01-01
# 7                            07975900           FRS-102        2019-01-01
# 8                            07975900           FRS-102        2019-01-01
# 9                            07975900           FRS-102        2019-01-01
# 10                           07975900           FRS-102        2019-01-01
# 11                           07975900           FRS-102        2019-01-01
# 12                           07975900           FRS-102        2019-01-01
# 13                           07975900           FRS-102        2019-01-01
# 14                           07975900           FRS-102        2019-01-01
#
#                                     doc_standard_link
# 0   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 1   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 2   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 3   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 4   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 5   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 6   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 7   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 8   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 9   https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 10  https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 11  https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 12  https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 13  https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...
# 14  https://xbrl.frc.org.uk/FRS-102/2019-01-01/FRS...

# %%
import time
import sys

def progressBar(name, value, endvalue, bar_length = 50, width = 20):
    percent = float(value) / endvalue
    arrow = '-' * int(round(percent * bar_length) - 1) + '>'
    spaces = ' ' * (bar_length - len(arrow))
    sys.stdout.write(
        "\r{0: <{1}} : [{2}]{3}%   ({4} / {5})".format(
            name,
            width,
            arrow + spaces,
            int(round(percent * 100)),
            value,
            endvalue
        )
    )
    sys.stdout.flush()
    if value == endvalue:
        sys.stdout.write('\n\n')

# %%
41# Finally, build a table of all variables from all example (digital) documents
# This can take a while

process_start = time.time()

# Empty table awaiting results
results = pd.DataFrame()

COUNT = 0

# For every file
for file in files:
    
    COUNT += 1
    
    # Read the file
    doc = process_account(file)
    
    # tabulate the results
    doc_df = flatten_data(doc)
    
    # append to table
    results = results.append(doc_df)
    
    progressBar("XBRL accounts parsed", COUNT, len(files), bar_length = 50, width = 20)
    
print("Process Complete")
print("Average time to process an XBRL file: {}".format((time.time() - process_start) / 60, 2), " minutes")
# Out:
# XBRL accounts parsed : [------------------------------------------------->]100%   (24430 / 24430)
#
# Process Complete
# Average time to process an XBRL file: 551.9254761219024  minutes

# %% [markdown]
# results.head(50)

# %%
results.shape
# Out:
# (1569143, 15)

# %%
list_of_tags = results["name"].tolist()
list_of_tags_unique = list(set(list_of_tags))
list_of_tags_unique
# Out:
# ['increaseinloansowedbyrelatedpartiesduetoloansadvanced',
#  'generaldescriptionadvancescreditstodirectorsincludingtermsinterestrates',
#  'furtheritemcurrenttaxexpensecreditcomponenttotalcurrenttaxexpense',
#  'bankborrowings',
#  'otherdisposalsdecreaseinamortisationimpairmentintangibleassets',
#  'purchasefinancialinvestmentsotherthantradinginvestments',
#  'valueordinarysharesallotted',
#  'utilitiescosts',
#  'profitlossbeforetax',
#  'depreciationimpairmentexpensepropertyplantequipment',
#  'increasedecreaseinliabilitiesdefinedbenefitplanfrompastservicecostgainslossesarisingfromsettlements',
#  'gainlossondisposalspropertyplantequipment',
#  'additionsotherthanthroughbusinesscombinationsintangibleassets',
#  'loansfromgroupundertakings',
#  'datewhenceasedtobelegalorregisteredname',
#  'statementthattherewerenogainslossesinperiodotherthanthoseinprofitlossaccount',
#  'descriptionmeasurementbasisforbiologicalassetscostmodel',
#  'totalnumbersharesissued',
#  'descriptionextenttowhichfairvalueinvestmentpropertybasedonvaluationbyindependentvaluer',
#  'provisionsfree-textcomment',
#  'entitydormanttruefalse',
#  'debtorsacquired',
#  'rawmaterialsconsumables',
#  'othercomprehensiveincomeexpensebeforetax',
#  'comprehensiveincomeexpenseattributabletoownersparent',
#  'totalassetslesscurrentliabilities',
#  'totalincreasedecreaseinequity',
#  'pastservicecostdefinedbenefitplan',
#  'minimumleasepaymentsreceivableundernon-cancellableoperatingleaseslessor',
#  'purchaseintangibleassets',
#  'accruedliabilitiesdeferredincome',
#  'debtors',
#  'cumulativegainlossonremeasurementdefinedbenefitplanrecognisedinothercomprehensiveincome',
#  'governmentgrantincome',
#  'inventoriesfree-textcomment',
#  'exceptionalitemsfree-textcomment',
#  'dividendspaidonsharesfinal',
#  'oneormoretrusteeshasbeenpaidremunerationorreceivedotherbenefitstruefalse',
#  'increasedecreasefromotherchangesinvestmentpropertyfairvaluemodel',
#  'increasedecreaseinnetdeferredtaxliabilityfromamountrecognisedinothercomprehensiveincome',
#  'cashflowsusedinacquiringorobtainingcontrolsubsidiariesorotherbusinessesclassifiedasinvestingactivities',
#  'reservespolicy',
#  'liabilitiesdefinedbenefitplanpresentvalue',
#  'furtherdepartmentitemaveragenumberemployeescomponentaveragenumberlist',
#  'dateapproval',
#  'gainlossincashflowsfromchangeindeferreditems',
#  'legalformofentity',
#  'dividendspaidtoownersparentclassifiedasfinancingactivities',
#  'taxincreasedecreasearisingfromoverseastaxsufferedexpensed',
#  'abbreviatedaccountsareinaccordancewithspecialprovisionsinsection4453companiesactrelatingtomedium-sizedcompaniestruefalse',
#  'otherdisposalsintangibleassets',
#  'charityregistrationnumberenglandwales',
#  'gainslossesbeforetaxfree-textcomment',
#  'amountspecificbankloan',
#  'explanationcharitysorganisationalstructureincludingthoseanysubsidiaryundertakings',
#  'descriptionreasonswhydeferredtaxassetshouldberecognised',
#  'investmentsinassociatesfree-textcomment',
#  'operatingincomefree-textcomment',
#  'startdateforperiodcoveredbyreport',
#  'principledocumentauthor',
#  'gainlossonrevaluationpropertyplantequipmentnettaxinothercomprehensiveincome',
#  'addressentitycharityauditors',
#  'namedirectorsigningaccounts',
#  'legalformentity',
#  'interestpaidclassifiedasfinancingactivities',
#  'proceedsfromsalesintangibleassets',
#  'furtheritemdividendincomecomponenttotaldividendincome',
#  'furtherrentalleasingincomeitemcomponenttotalrentalleasingincome',
#  'descriptionmaterialoperatingleasingarrangements',
#  'furtheritemproceedsfromsalesotherlong-termassetsclassifiedasinvestingactivitiescomponentcorrespondingtotal',
#  'wagessalaries',
#  'amountsowedbygroupundertakingsparticipatinginterests',
#  'parvalueshare',
#  'summarymainachievements',
#  'generaldescriptionguaranteestheirtermsdirectors',
#  'entityhasclaimedexemptionfromreportingcomparativeinformationoncertainitemssharecapitalinlinewithfrs1021.12atruefalse',
#  'deferredtaxpolicy',
#  'otherpayables',
#  'entitytradingstatus',
#  'generaldescriptionfinancialinstrumentriskexposuremanagementincludinganyconcentrationsrisk',
#  'borrowingcostspolicy',
#  'otherremainingoperatingincome',
#  'profitloss',
#  'amountsowedtogroupundertakingsparticipatinginterests',
#  'taxdecreaseincreasefromeffectrevenueexemptfromtaxation',
#  'amountsowedtogroupundertakings',
#  'numbersharesissuedinperiod-gross',
#  'workinprogress',
#  'amountsowedtojointventures',
#  'addressline3',
#  'netfinanceincomecosts',
#  'xbrldocumentcreationdate',
#  'furtheritembankborrowingsoverdraftscomponenttotalbankborrowingsoverdrafts',
#  'cashreceiptsfromsalesinterestsinassociates',
#  'loanstorelatedparties',
#  'increasedecreaseinstocksinventoriesfinishedgoodsworkinprogress',
#  'otherremainingborrowings',
#  'productionaveragenumberemployees',
#  'addresscontrollingparty',
#  'carryingamountpropertyplantequipmentpledgedassecurityforliabilities',
#  'nameentityofficer',
#  'costinventoriesrecognisedasexpensenetwritedownsreversals',
#  'netinterestreceivedpaidclassifiedasinvestingactivities',
#  'investmentsingroupundertakings',
#  'operatingprofitloss',
#  'dividendsfree-textcomment',
#  'otherexternalcharges',
#  'expenditurematerialfund',
#  'loansadvancesgrantedclassifiedasinvestingactivities',
#  'intangibleassetspolicy',
#  'currentincometaxpolicy',
#  'furtheritemincreasedecreaseinppecomponenttotalchangeinppe',
#  'companieshouseregisterednumber',
#  'proceedsfromsalespropertyplantequipment',
#  'calledupsharecapitalnotpaid',
#  'balancesheetstatementfinancialpositionfree-textcomment',
#  'impairmentfinancialassetspolicy',
#  'donationslegacies',
#  'loansowedbyrelatedparties',
#  'amountspecificadvanceorcreditmadeinperioddirectors',
#  'othertaxationadvisoryservicesentitysubsidiariesfees',
#  'shareholderfunds',
#  'feestoauditorsfree-textcomment',
#  'transfersintooroutintangibleassetsincreasedecreaseinamortisationimpairment',
#  'generaldescriptionvaluationinvestmentsinotherfunds',
#  'salariesdirectors',
#  'financialinstrumentsnetgainslossesfree-textcomment',
#  'currentassetinvestments',
#  'cashflowsfromdisposalorreductionincontroloversubsidiariesorotherbusinesses',
#  'taxincreasedecreasefromothershort-termtimingdifferences',
#  'descriptionlineitemsinincomestatementinwhichamortisationimpairmentintangibleassetsincluded',
#  'biologicalassetscostmodel',
#  'entitydormant',
#  'statementthatdirectorsacknowledgetheirresponsibilitiesundercompaniesact',
#  'legacies',
#  'gainlossonnon-financingactivitiesduetoforeignexchangedifferencesrecognisedinprofitorloss',
#  'nameorlocationofficeperformingaudit',
#  'distributioncosts',
#  'rentalleasingincome',
#  'expensesrecognisedfordoubtfuldebtsowedbyrelatedparties',
#  'generaldescriptionmethodsfordeterminingchangeinfairvaluefinancialliabilitiesattributabletochangesincreditriskincludinglimitationsmethodsanyfeatureswhichmodifyvalues',
#  'creditorsassumed',
#  'totaldeferredtaxexpensecredit',
#  'otherexpenditure',
#  'derecognitionfinancialassetsfinancialliabilitiespolicy',
#  'foreignexchangedifferencesincreasedecreaseindepreciationimpairmentpropertyplantequipment',
#  'dateauthorisationfinancialstatementsforissue',
#  'accruedliabilities',
#  'finishedgoods',
#  'interestsimilarexpensepayable',
#  'gainlossonrevaluationotherassetsnettaxinothercomprehensiveincome',
#  'outstandingpre-paidcontributionstodefinedcontributionplanreportingdate',
#  'cashbankinhand',
#  'descriptionrestrictionsonrealisabilityorremittanceincomefrominvestmentproperty',
#  'dividendrecommendedbydirectors',
#  'balancesheetdate',
#  'trusteeshaveapprovedstrategicreporttruefalse',
#  'furtherinformationonparentlargestgroup',
#  'gainlossincashflowsfromchangeinaccrueditems',
#  'grouptaxreliefreceivedpaid',
#  'leasespolicy',
#  'netincreasedecreaseincharitablefunds',
#  'minimumleasepaymentsreceivableundernon-cancellableoperatingleases',
#  'explanationcontributionmadebyvolunteerstoactivities',
#  'furtheritemincreasedecreaseinequityfromsharecapitalchangesdividendpaymentscomponenttotalincreasedecreaseinequityfromsharecapitalchangesdividendpayments',
#  'interestincome',
#  'otherinterestexpense',
#  'futureminimumleasepaymentsundernon-cancellableoperatingleases',
#  'otherdisposalsdecreaseindepreciationimpairmentpropertyplantequipment',
#  'othernon-auditservicesfees',
#  'disposalspropertyplantequipment',
#  'paymentsreceivedonaccount',
#  'numbersharesauthorised',
#  'amountsowedtorelatedparties',
#  'taxationsocialsecurityduewithinoneyear',
#  'incomeexpenserecogniseddirectlyinequity',
#  'dividendsproposedbutnotpaid',
#  'othercashinflowoutflowclassifiedasoperatingactivities',
#  'companyhasactedasanagentduringperiodtruefalse',
#  'descriptionbasispreparationsummarisedfinancialinformationassociate',
#  'deferredincomeliability',
#  'statementonqualitycompletenessinformationprovidedtoauditors',
#  'accountsarepreparedinaccordancewithapplicablecharityandorcompanylawinjurisdictionsregistrationtruefalse',
#  'directorremunerationbenefitsexcludingpaymentstothirdparties',
#  'gainlossincashflowsfromchangeinprovisions',
#  'generaldescriptionloansowedtorelatedpartiesincludingtermsguaranteesgiven',
#  'amountsowedbyassociatesjointventuresparticipatinginterests',
#  'noestimatecanbemadefinancialeffecteventafterreportingdatetruefalse',
#  'entitytradingname',
#  'generaldescriptionimpactnewlyeffectivestandardsorinterpretations',
#  'gainlossondisposalassetsincomestatementsubtotal',
#  'increasedecreaseinpropertyplantequipment',
#  'acquiredthroughbusinesscombinationspropertyplantequipment',
#  'generaldescriptionassetsliabilitieswithsignificantriskmaterialadjustmentincludingvalues',
#  'accountantsreportonfinancialstatements',
#  'modelusedtomeasureinvestmentproperty',
#  'statementonmattersrequiredindirectorsreportbeingplacedinstrategicreport',
#  'taxincreasedecreasearisingfromgrouprelieftaxreconciliation',
#  'share-basedpaymentspolicy',
#  'taxincreasedecreasefromeffectcapitalallowancesdepreciation',
#  'accountsareinaccordancewithspecialprovisionscompaniesactrelatingtosmallcompanies',
#  'summaryplansstrategyformanagingrisks',
#  'descriptionrelatedentitywhichhaspreparedconsolidatedfinancialstatementstheiravailability',
#  'entityaccountstype',
#  'profitlossonordinaryactivitiesbeforetax',
#  'turnovergrossoperatingrevenue',
#  'definedbenefitplanmulti-employerplantruefalse',
#  'othertaxationsocialsecuritypayable',
#  'totalincreasedecreaseinprovisions',
#  'netassetsliabilitiesassociates',
#  'accountingstandardsapplied',
#  'contentotherspecificaccountingpolicy',
#  'advancescreditsmadeinperioddirectors',
#  'amountsowedbysubsidiaries',
#  'accountspreparedunderhistoricalcostconventioninaccordancewithfrsse',
#  'reportaninterimfinancialstatementfrompubliclylistedentitytruefalse',
#  'fundraisingsupportcosts',
#  'keymanagementpersonnelcompensationtotal',
#  'addressline2',
#  'tradereceivablespolicy',
#  'businessreportname',
#  'giftaid',
#  'entityhasclaimedexemptionfrompresentingcashflowstatementnotesinlinewithfrs1021.12btruefalse',
#  'investmentproperty',
#  'reportperiod',
#  'investmententitiespolicy',
#  'deferredtaxexpensecreditrelatingtochangesintaxratesorlaws',
#  'incomefromleasingplantequipment',
#  'impairmentlosspropertyplantequipment',
#  'assumedrateincreasepensionablesalaries',
#  'additionsotherthanthroughbusinesscombinationspropertyplantequipment',
#  'incomefromotherfixedassetinvestments',
#  'considerationreceivedforsharesissuedinperiod',
#  'dateapprovalaccounts',
#  'maximumliabilityunderspecificguaranteedirectors',
#  'amountsowedbygroupundertakings',
#  'descriptionorotherinformationonthirdpartyagent',
#  'gainlossincashflowsfromchangeinconstructioncontractworkinprogress',
#  'otherincreasedecreaseindepreciationimpairmentpropertyplantequipment',
#  'othergeneralgrants',
#  'deferredtaxassetdebtors',
#  'increasefromimpairmentlossrecognisedinothercomprehensiveincomeintangibleassets',
#  'debtsecuritiesheld',
#  'creditorsduewithinoneyear',
#  'emphasismatterstatement',
#  'reportprincipallanguage',
#  'doubletaxationrelief',
#  'policyforinductiontrainingtrustees',
#  'incomefromcharitableactivities',
#  'otheroperatingincomeformat1',
#  'netassetsliabilitiessubsidiaries',
#  'advancescreditsrepaidinperioddirectors',
#  'othercurrentassetinvestmentsbalancesheetsubtotal',
#  'basisforopinionauditorsonentity',
#  'numberdirectorsaccruingbenefitsundermoneypurchasescheme',
#  'calledupsharecapital',
#  'taxincreasedecreasefromeffectdifferenttaxratesonsomeearnings',
#  'usefullifeintangibleassetsyears',
#  'nameindividualsegment',
#  'furtheritemcashflowfromusedinfinancingactivitiescomponentnetcashflowsfromusedinfinancingactivities',
#  'investments',
#  'factoreddebtsoutstanding',
#  'othernon-auditservicesentitysubsidiariesfees',
#  'financialliabilities',
#  'furtheritemincreasedecreaseininvestmentpropertyfairvaluemodelcomponentcorrespondingtotal',
#  'generaldescriptioncontingentassetsincludingfinancialeffect',
#  'researchdevelopmentpolicy',
#  'nameseniorstatutoryauditor',
#  'enddateforperiodcoveredbyreport',
#  'netcashgeneratedfromoperations',
#  'profitlossonordinaryactivitiesaftertax',
#  'nameentityaccountants',
#  'descriptionnaturebusinesssubsidiary',
#  'incomematerialfund',
#  'othercashcashequivalents',
#  'otherincreasedecreaseinnetdeferredtaxliability',
#  'assetsacquired',
#  'furtheriteminterestexpensecomponenttotalinterestexpense',
#  'typeordinaryshare',
#  'consolidationpolicy',
#  'netassetsliabilities',
#  'netassetsliabilitiesincludingpensionassetliability',
#  'otherassuranceservicesentitysubsidiariesfees',
#  'descriptionlesseesmaterialfinanceleasingarrangements',
#  'netcurrentassetsliabilities',
#  'currentservicecostdefinedbenefitplan',
#  'descriptionothermaterialassumptionsrelatedtodefinedbenefitplan',
#  'generaldescriptionloanspayableindefaultorbreachincludingnaturedefaultorbreachamountsinvolved',
#  'incomefromcharitableactivity',
#  'investmentsfixedassets',
#  'titleotherspecificcriticalestimatejudgement',
#  'taxincreasedecreasefromeffectexpensesnotdeductibleindeterminingtaxableprofitorloss',
#  'descriptionnon-cashbenefitsforkeymanagementpersonnel',
#  'purchaseotherlong-termassetsclassifiedasinvestingactivities',
#  'acquiredthroughbusinesscombinationsintangibleassets',
#  'netassetsliabilityexcludingpensionassetliability',
#  'incometaxexpensecredit',
#  'capitalcommitments',
#  'grossamountduefromcustomersforconstructioncontractworkasasset',
#  'incomefromothertradingactivity',
#  'additionsfromacquisitionsinvestmentpropertycostmodel',
#  'amortisationimpairmentexpenseintangibleassets',
#  'increasedecreasefromrevaluationsrecognisedorreversedinprofitorlosspropertyplantequipment',
#  'redemptionsharesdecreaseinequity',
#  'reportincludeslistsubsidiariestruefalse',
#  'investmentpropertyfree-textcomment',
#  'deficitsurplusindefinedbenefitplan',
#  'lesseeoperatingleasepolicy',
#  'balanceswithbanks',
#  'additionsfromacquisitionsinvestmentpropertyfairvaluemodel',
#  'namecontrollingparty',
#  'gainlossonrevaluationinvestmentpropertiesnettaxinothercomprehensiveincome',
#  'noemployeesreceivedbenefitsexcludingemployerpensioncostsmorethan60000truefalse',
#  'taxincreasedecreasefromeffectdividendsfromukcompanies',
#  'profitlossfromcontinuingoperationsassociates',
#  'otherinvestmentsotherthanloans',
#  'revaluationsincreasedecreaseindepreciationimpairmentpropertyplantequipment',
#  'increasedecreasefromforeignexchangedifferencesintangibleassets',
#  'accountsarepreparedinaccordancewithfrs102orapplicablelegislationtruefalse',
#  'companyentitledtoexemptionundersection480companiesact2006',
#  'namesubsidiary',
#  'bankoverdrafts',
#  'operatingexpensesfree-textcomment',
#  'increasedecreaseduetotransfersintooroutpropertyplantequipment',
#  'dividendspaid',
#  'capitalemployed',
#  'amountsowedtoassociates',
#  'loansowedtorelatedparties',
#  'investmentsinjointventures',
#  'interestreceivedclassifiedasoperatingactivities',
#  'netinterestpaidreceivedclassifiedasoperatingactivities',
#  'dateformationorincorporation',
#  'financialinstrumentsclassificationpolicy',
#  'revenuerecognitionpolicy',
#  'otherinterestreceivablesimilarincomefinanceincome',
#  'directorsremunerationfree-textcomment',
#  'independentvaluerwasinvolvedinrevaluationpropertyplantequipmenttruefalse',
#  'versionproductionsoftware',
#  'descriptionfinancialcommitmentsotherthancapitalcommitments',
#  'amountsowedtootherrelatedpartiesotherthandirectors',
#  'decreaseinloansowedbyrelatedpartiesduetoloansrepaid',
#  'associatenotaccountedforusingequitymethodtruefalse',
#  'companydormant',
#  'accountshavedepartedfromfrs102orapplicablelegislationtoachievefairpresentationtruefalse',
#  'totalassets',
#  'descriptionnaturepurposereserveswithinequity',
#  'purchasesadditionsotherthanthroughbusinesscombinationsbiologicalassetscostmodel',
#  'profitlossattributabletoownersparent',
#  'creditors',
#  'directorsigningreport',
#  'increasefromimpairmentlossrecognisedinprofitorlosspropertyplantequipment',
#  'significantactivitiesundertakentoachievestatedaimsobjectives',
#  'dividenddeclaredpayable',
#  'totalconsiderationtransferredincludingsettlementpre-existingrelationship',
#  'recoverableamountspecificintangibleassetbasedvalueinusetruefalse',
#  'revenuefromrenderingservices',
#  'negativegoodwillarisingonacquisition',
#  'increasedecreaseincashcashequivalentsbeforeforeignexchangedifferenceschangesinconsolidation',
#  'furtheritemdebtorscomponenttotaldebtors',
#  'businesscombinationspolicy',
#  'socialsecuritycosts',
#  'administrationsupportaveragenumberemployees',
#  'lessoroperatingleasepolicy',
#  'increasedecreaseinamortisationimpairmentintangibleassets',
#  'descriptionbodyauthorisingfinancialstatements',
#  'opinionauditorsonentitythataccountsgivetruefairviewtruefalse',
#  'datecharityauditorsreport',
#  'administrativeexpenses',
#  'totalincreasedecreasefromrevaluationspropertyplantequipment',
#  'convertibledebtsecuritiesheld',
#  'carryingamountundercostmodelrevaluedassetspropertyplantequipment',
#  'furtheroperatingexpenseitemcomponenttotaloperatingexpenses',
#  'increasedecreaseincurrenttaxfromforeignexchangeadjustments',
#  'incomestatementfree-textcomment',
#  'billsexchangepayable',
#  'taxincreasedecreasefromothertaxeffectstaxreconciliation',
#  'reportaninitialfinancialstatementfrompubliclylistedentitytruefalse',
#  'share-basedpaymentexpenseequitysettled',
#  'finishedgoodsgoodsforresale',
#  'statementauditorsresponsibilitiesrelatingtootherinformation',
#  'amountsowedbydirectors',
#  'loansfromotherrelatedpartiesotherthandirectors',
#  'taxincreasedecreasefromeffectadjustmentforlongaccountingperiods',
#  'entitycurrentlegalname',
#  'othercomprehensiveincomeexpensenettax',
#  'totalcurrenttaxexpensecredit',
#  'unusedprovisionreversed',
#  'otherdisposalsbiologicalassetscostmodel',
#  'descriptionnaturetransactionsbalanceswithrelatedparties',
#  'nameparententity',
#  'valuationfinancialinstrumentspolicy',
#  'depreciationamortisationimpairmentexpense',
#  'descriptionfairvaluemeasurementequityinstrumentsinshare-basedpaymentarrangement',
#  'charitableobjective',
#  'descriptionmethodsusedtoaccountforinvestmentsinsubsidiariesassociatesjointventuresinseparatefinancialstatements',
#  'proceedsfromfinanceleasesclassifiedasfinancingactivities',
#  'descriptioninventorycostformulas',
#  'otherprovisionsbalancesheetsubtotal',
#  'decreaseinloansowedtorelatedpartiesduetoloansrepaid',
#  'biologicalassetspolicy',
#  'gainlossonrevaluationpropertyplantequipmentbeforetaxinothercomprehensiveincome',
#  'countryincorporationorresidencesubsidiary',
#  'propertyplantequipmentgrosscost',
#  'ownershipinterestinassociatepercent',
#  'namedefinedcontributionplan',
#  'currentliabilities',
#  'charityregistrationnumberscotland',
#  'otherdebtorsbalancesheetsubtotal',
#  'statementonpowertoamendfinancialstatementsafterissue',
#  'investmentsinassociates',
#  'amountsowedbyassociates',
#  'generaldescriptionchangesinaccountingpolicies',
#  'transferstofromretainedearningsincreasedecreaseinequity',
#  'balancesamountsowedbyrelatedparties',
#  'nameindividualauditor',
#  'applicablelegislation',
#  'revenuefromconstructioncontracts',
#  'incomeendowments',
#  'explanationrelationshipsbetweencharityrelatedparties',
#  'definedcontributionpensionspolicy',
#  'fixedassets',
#  'increaseinloansowedtorelatedpartiesduetoloansadvanced',
#  'descriptionwhyentitynotgoing-concernoruncertaintiesovergoing-concernstatus',
#  'grossprofitloss',
#  'entityhasclaimedexemptionfromreportingdisclosurekeymanagementpersonnelcompensationtruefalse',
#  'descriptionreasonsforspecificshareissue',
#  'averagenumberemployeesduringperiod',
#  'dividendsdeclaredafterreportingdate',
#  'loansfromdirectors',
#  'employeesgendernotdisclosed',
#  'deferredtaxexpensecreditfromunrecognisedtaxlossorcredit',
#  'generaldescriptioneffectsfirsttimeadoptionreasonsforchangeotherfactorsrelevanttotransition',
#  'issueequityinstruments',
#  'jointventuresaccountingconsolidationpolicy',
#  'amountsowedtodirectors',
#  'accumulatedamortisationimpairmentintangibleassets',
#  'descriptionrelationshipsbetweenentityparentsincludinganychanges',
#  'companyhaspublishedcommitmenttoukeffectivestewardshipcodetruefalse',
#  'namedefinedbenefitplan',
#  'generaldescriptionbasismeasurementusedinpreparingfinancialstatements',
#  'descriptionamortisationmethodforintangibleassets',
#  'countryincorporationorresidenceassociate',
#  'statementonqualifyingthirdpartyindemnityprovisions',
#  'statementcompliancewithapplicablereportingframework',
#  'numbersharesissuedfullypaid',
#  'interestexpenseonbankoverdrafts',
#  'propertyplantequipmentpolicyincludingright-of-use',
#  'considerationreceivedforsharesissuedspecificshareissue',
#  'decreaseincreaseinestimaterecoverabledeferredtaxasset',
#  'cashcashequivalentspolicy',
#  'interestexpenseonpreferencesharesclassifiedasdebt',
#  'subsidiariesaccountingconsolidationpolicy',
#  'nameultimateparentgroupifnotparententity',
#  'increasedecreaseduetotransfersintooroutintangibleassets',
#  'purchasepropertyplantequipment',
#  'loanstodirectors',
#  'norelatedpartytransactionsinreportingperiodrequiredisclosuretruefalse',
#  'recoverablevalue-addedtax',
#  'furtheritemincreasedecreaseinequitycomponenttotalincomeexpenserecogniseddirectlyinequity',
#  'financialstatementsarepreparedongoing-concernbasistruefalse',
#  'interestexpenseondebtsecuritiesinissueothersimilarloans',
#  'accruedincome',
#  'increasefromdepreciationchargeforyearpropertyplantequipment',
#  'cashbankonhand',
#  'creditorsfree-textcomment',
#  'increasedecreaseininvestmentpropertyfairvaluemodel',
#  'loanstojointventures',
#  'otherincome',
#  'generalderivativeshedgingpolicy',
#  'ownershipinterestinsubsidiarypercent',
#  'taxincreasedecreasefromeffectunrelievedtaxlossescarriedforward',
#  'propertyplantequipmentfree-textcomment',
#  'otherinventories',
#  'directorsigningdirectorsreport',
#  'calledupsharecapitalnotpaidnotexpressedascurrentasset',
#  'share-basedpaymentsfree-textcomment',
#  'amountsowedbyotherrelatedpartiesotherthandirectors',
#  'amountsowedtoparententities',
#  'rentalincomefrominvestmentproperty',
#  'constructionworkinprogresspolicy',
#  'contingentliabilities',
#  'descriptiondepreciationmethodforbiologicalassetscostmodel',
#  'descriptionmethodsassumptionsunderlyingfairvaluesestimatepropertyplantequipment',
#  'nameaccountantresponsible',
#  'propertyplantequipmentincludingright-of-useassets',
#  'otherloansclassifiedunderinvestments',
#  'gainlossincashflowsfromchangeininventories',
#  'otherdisposalsinvestmentpropertyfairvaluemodel',
#  'contentotherspecificcriticalestimatejudgement',
#  'generaldescriptionloansowedbyrelatedpartiesincludingtermsguaranteesreceived',
#  'reportanamendedrevisedversionpreviouslyfiledreporttruefalse',
#  'returnonassetsbenefitplan',
#  'sharecapitalallottedcalleduppaid',
#  'advancescreditsdirectors',
#  'descriptionmethodssignificantassumptionsappliedindeterminingfairvalueinvestmentproperty',
#  'furtheritemcreditorscomponenttotalcreditors',
#  'descriptionmethodsusedtoaccountforinvestmentsinjointventuresinseparatefinancialstatements',
#  'statementthataccountshavebeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#  'foreignexchangedifferencesincreasedecreaseinamortisationimpairmentintangibleassets',
#  'tradecreditorstradepayables',
#  'employmentdisabledpersonspolicy',
#  'statementthatultimatecontrollingpartynotknown',
#  'interestexpenseonfinancialliabilitiesfairvaluethroughprofitorloss',
#  'pensionschemesprepayments',
#  'percentageclassshareheldinsubsidiary',
#  'dividendspaidclassifiedasfinancingactivities',
#  'descriptioneventafterreportingdate',
#  'furtheritemincomefromothertradingactivitiescomponenttotalincomefromothertradingactivities',
#  'taxdecreasefromutilisationtaxlosses',
#  'totaladditionsincludingfrombusinesscombinationsintangibleassets',
#  'investmentpropertypolicy',
#  'transfertofrommaterialfund',
#  'investmentsinotherentitiesmeasuredfairvalue',
#  'nameordescriptionrelatedpartyifnotdefinedbyanothertag',
#  'investmentincomenetamountswrittenoffbacktoinvestments',
#  'loanstogroupundertakings',
#  'interestexpenseonbankloanssimilarborrowings',
#  'entitytrading',
#  'functionalpresentationcurrencypolicy',
#  'statementonapplicationmaterialitytoaudit',
#  'propertyplantequipmentpolicy',
#  'dividendpersharefinal',
#  'descriptionclassshareheldinsubsidiary',
#  'gainlossondisposalsothernon-currentassets',
#  'netcashinflowoutflowfromchangeinborrowingsclassifiedasfinancingactivities',
#  'governmentgrantspayable',
#  'otherinterestincome',
#  'companyhasactedasanagentduringperiod',
#  'keymanagementpersonnelcompensationshort-termemployeebenefits',
#  'investmentperformanceagainstinvestmentobjectivesset',
#  'bankingarrangementsclassifiedascashcashequivalents',
#  'directorsigningfinancialstatements',
#  'incomefromothertradingactivities',
#  'companycontributionstodefinedbenefitplansdirectors',
#  'prepaymentsaccruedincome',
#  'finaldividendspaid',
#  'sharecapitalpolicy',
#  'companycontributionstomoneypurchaseplansdirectors',
#  'entityhasclaimedexemptionfromreportingdisclosurerelatedpartytransactionsforgovernment-relatedentitiestruefalse',
#  'incomefromrelatedparties',
#  'revenuerecognitioncriticalestimatesjudgements',
#  'futurefinancechargesonfinanceleases',
#  'gainlossonfinancialassetsfairvaluethroughprofitorloss',
#  'morethan200subsidiariestruefalse',
#  'statementthatnocontrollingpartiesexist',
#  'furtheritemdonationslegaciescomponenttotaldonationslegacies',
#  'goingconcerncriticalestimatesjudgements',
#  'bankborrowingsoverdrafts',
#  'descriptionsharetype',
#  'accumulateddepreciationimpairmentpropertyplantequipment',
#  'explanationmainactivitiesundertakenforpublicbenefit',
#  'descriptionreasonwhyentityhasnotpreparedconsolidatedfinancialstatements',
#  'paymentstorelatedparties',
#  'opinionauditorsinrespectadditionalfinancialreportingframework',
#  'principalplacebusinesssubsidiary',
#  'otheroperatingincomeformat2',
#  'cancellationsubscribedcapitaldecreaseinequity',
#  'statementthatmembershaveagreedtopreparationabridgedaccountsundersection444companiesact2006',
#  'borrowingspolicy',
#  'carryingamountpropertyplantequipmentwithrestrictedtitle',
#  'short-termdepositsclassifiedascashequivalents',
#  'accumulateddepreciationnotincludingimpairmentpropertyplantequipment',
#  'amountsowedtoassociatesjointventuresparticipatinginterests',
#  'transfersfromtosharepremiumincreasedecreaseinequity',
#  'numberordinarysharesallotted',
#  'increasedecreaseinassetsdefinedbenefitplanfromremeasurement',
#  'directorstrusteesreportconsistentwithaccountstruefalse',
#  'descriptionortitleauthor',
#  'nameparentlargestgroupinwhichresultsareconsolidated',
#  'calledupsharecapitalnot-paidcurrentasset',
#  'descriptionspecificguaranteeitstermsdirectors',
#  'additionsotherthanthroughbusinesscombinationsinvestmentpropertyfairvaluemodel',
#  'increasedecreaseinexistingprovisionsrecognisedinprofitorloss',
#  'foreigncurrencytranslationoperationspolicy',
#  'researchdevelopmentexpenserecognisedinprofitorloss',
#  'directorsacknowledgetheirresponsibilitiesundercompaniesact',
#  'votingpowerinsubsidiaryifdifferentfromownershipinterestpercent',
#  'researchdevelopmentaveragenumberemployees',
#  'principalcurrencyusedinbusinessreport',
#  'generaldescriptioncriticalestimatesjudgements',
#  'dateauditorsreport',
#  'datesigningdirectorsreport',
#  'taxincreasedecreasefromchangesintaxprovisionsduetolegislation',
#  'accountshavebeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#  'significantcharitableactivitiesundertaken',
#  'taxincreasedecreasefromeffectunrelievedlossondisposaloperations',
#  'costinventoriesrecognisedasexpensegross',
#  'rentalincomefromsub-leases',
#  'nameapprovingdirector',
#  'subsidiaryunconsolidatedtruefalse',
#  'disposalsdecreaseindepreciationimpairmentpropertyplantequipment',
#  'advancesoninvoicediscountingfacilities',
#  'entitycurrentlegalorregisteredname',
#  'financialinstrumentsrecognitionmeasurementpolicy',
#  'propertyplantequipment',
#  'equitysecuritiesheld',
#  'taxationsocialsecuritypayable',
#  'financeleasepaymentsowingminimumgross',
#  'furtheritemoperatingexpenselossincomestatementitemcomponentoperatingprofitloss',
#  'interestincomeoncashcashequivalents',
#  'descriptiondepreciationmethodforpropertyplantequipmentincludingright-of-use',
#  'companieshousedocumentauthentication',
#  'descriptionrecognitionbasismeasurementintangibleassets',
#  'definedbenefitliabilitiesfromplansthatarewhollyunfundedpresentvalue',
#  'othertaxationpayable',
#  'descriptionprincipalactivities',
#  'cashtransferredtoacquireentity',
#  'proceedsfromissuingshares',
#  'interestexpenseonloancapital',
#  'auditablepartremunerationreporthasbeenproperlypreparedtruefalse',
#  'assumedrateincreasepensionsinpaymentdeferredpensions',
#  'transfertonon-currentassetsordisposalgroupsheldforsaledecreaseinamortisationimpairmentintangibleassets',
#  'netincomeexpenditurebeforetransfersbetweenfundsotherrecognisedgainslosses',
#  'othercreditorsduewithinoneyear',
#  'netcashflowsfromusedinfinancingactivities',
#  'advancespaidtosuppliers',
#  'furtheritemgainlossincashflowsfromchangeinoperatingliabilitiescomponenttotalgainlossincashflowsfromchangeinoperatingliabilities',
#  'tradeotherpayables',
#  'dateassumedposition',
#  'netidentifiableassetsliabilitiesacquired',
#  'statementonmattersonwhichauditorreportsbyexception',
#  'currentassets',
#  'purchaseinvestmentproperties',
#  'statementonbasismeasurementpreparationaccounts',
#  'biologicalassetsnon-current',
#  'nameentityauditors',
#  'lossonfinancingactivitiesduetoforeignexchangedifferences',
#  'dividendpolicy',
#  'informationoncontrollingpartyincludingdescriptionrelationship',
#  'relatedpartytransactionexemptionbeingclaimed',
#  'incomefromsharesingroupundertakings',
#  'transferstofrompropertyplantequipmentfairvaluemodel',
#  'discountrateuseddefinedbenefitplan',
#  'statementonrisksmaterialmisstatementidentifiedbyauditor',
#  'nameentitylawyersorlegaladvisers',
#  'proceedsfromsalesormaturityfinancialassetsotherthantradinginvestments',
#  'value-addedtaxpayable',
#  'nameentitybankers',
#  'namethirdpartyagent',
#  'employeebenefitspolicy',
#  'incometaxespaidrefundclassifiedasoperatingactivities',
#  'transferstofromnon-currentassetsordisposalgroupsheldforsalepropertyplantequipment',
#  'totalinventories',
#  'methodsusedtorecruitappointnewtrustees',
#  'provisionsused',
#  'transfersintooroutpropertyplantequipmentincreasedecreaseindepreciationimpairment',
#  'otherdistributionstoownersdecreaseincreaseinequity',
#  'titleotherspecificaccountingpolicy',
#  'furtheritemgainlossinothercomprehensiveincomebeforetaxcomponenttotalothercomprehensiveincomebeforetax',
#  'principallocation-cityortown',
#  'increaseinliabilitiesdefinedbenefitplanfrominterestexpense',
#  'salariesfeesdirectors',
#  'gainlossincashflowsfromchangeincreditorstradeotherpayables',
#  'cashonhand',
#  'membershavenotrequiredcompanytoobtainanaudit',
#  'deferredtaxliabilities',
#  'descriptionnaturebusinessassociate',
#  'definedbenefitliabilitiesfromplansthatarewhollyorpartlyfundedpresentvalue',
#  'minimumoperatingleasepaymentsrecognisedasexpense',
#  'otherfinancecosts',
#  'additionalprovisionsincreasefromnewprovisionsrecognised',
#  'deferredtaxexpensecreditrelatingtooriginationreversaltimingdifferences',
#  'increasedecreaseindepreciationimpairmentpropertyplantequipment',
#  'directorremunerationbenefitsincludingpaymentstothirdparties',
#  'dividendsreceivedclassifiedasinvestingactivities',
#  'otherreceivables',
#  'investmentincome',
#  'costsraisingfunds',
#  'interestincomeonbankdeposits',
#  'discontinuedoperationspolicy',
#  'companyexemptfrompreparingcashflowstatementunderfrs1',
#  'increasedecreaseduetotransfersbetweenclassespropertyplantequipment',
#  'furtheritemdeferredexpensecreditcomponenttotaldeferredtaxexpense',
#  'entityformerlegalorregisteredname',
#  'totalnominalvalue',
#  'amountsowedtosubsidiaries',
#  'taxincreasedecreasefromchangesinpensionfundprepayment',
#  'pensionotherpost-employmentbenefitcostsotherpensioncosts',
#  'statementonrespectiveresponsibilitiesdirectorsauditors',
#  'descriptionnaturebusinessjointventure',
#  'revaluationpropertyplantequipmentfree-textcomment',
#  'prepayments',
#  'nameorlocationaccountantsoffice',
#  'descriptionspecificbankloanincludingraterepaymentdate',
#  'financialliabilitiesassumed',
#  'loancapital',
#  'proceedsfromborrowingsclassifiedasfinancingactivities',
#  'numberordinarysharesauthorised',
#  'postalcodezip',
#  'increasedecreaseinloansowedbyrelatedpartiesattributabletointeresttransactions',
#  'decreaseinassetsdefinedbenefitplanfrombenefitspaid',
#  'descriptionbasisonwhichapplicabletaxratehasbeendetermined',
#  'generaldescriptionusecollateral',
#  'descriptionmethodsusedtoaccountforinvestmentsinsubsidiariesinseparatefinancialstatements',
#  'amortisationrateusedforintangibleassets',
#  'opinionauditorsonentity',
#  'statementresponsibilitiesmanagementthosechargedwithcorporategovernance',
#  'deferredincome',
#  'furtheritemtaxincreasedecreasecomponentadjustingitems',
#  'disposalsintangibleassets',
#  'othercreditorsincludingtaxationsocialsecuritybalancesheetsubtotal',
#  'unpaidcontributionstopensionschemes',
#  'descriptionmethodsusedtoaccountforinvestmentsinassociatesinseparatefinancialstatements',
#  'provisionsforamountsowedbyrelatedparties',
#  'equityinstrumentsrecognitionmeasurementpolicy',
#  'turnoverrevenuefree-textcomment',
#  'transferstofromnon-currentassetsordisposalgroupsheldforsaleintangibleassets',
#  'depreciationrateusedforpropertyplantequipment',
#  'turnoverrevenue',
#  'parvalueordinaryshare',
#  'increasedecreaseindeferredtaxliabilityfromamountrecognisedinprofitorloss',
#  'employeestotal',
#  'othertaxespolicy',
#  'charityfunds',
#  'turnoverpolicy',
#  'retirementbenefitobligationssurplus',
#  'financialassets',
#  'descriptionclassshareheldinjointventure',
#  'tradecreditorswithinoneyear',
#  'companyentitledtoexemptionundersection477companiesact2006',
#  'investmententityrequiredtoapplyexceptionfromconsolidationtruefalse',
#  'interestexpenseonbankoverdraftsbankloanssimilarborrowings',
#  'dividendspaidonshares',
#  'financeincomecostspolicy',
#  'furtheritemcashflowfromusedininvestingactivitiescomponentnetcashflowsfromusedininvestingactivities',
#  'interestreceivedclassifiedasinvestingactivities',
#  'increasedecreasefromforeignexchangedifferencespropertyplantequipment',
#  'increasedecreasefromtotalimpairmentlossrecognisedorreversedpropertyplantequipment',
#  'ukcurrentcorporationtax',
#  'interestexpense',
#  'taxincreasedecreasefromeffectexpensesnotdeductiblefortaxpurposesotherthangoodwillamortisationimpairment',
#  'decreaseincreaseinliabilitiesdefinedbenefitplanfromremeasurement',
#  'nominalvaluesharesissuedspecificshareissue',
#  'furtheritemcostsraisingfundscomponenttotalcostsraisingfunds',
#  'addressline1',
#  'companyentitledtodeliverabbreviatedaccountsaccountsproperlypreparedtruefalse',
#  'interestpayablesimilarchargesfinancecosts',
#  'tradepayablespolicy',
#  'countyregion',
#  'otherdeferredtaxexpensecredit',
#  'accountsstatusauditedorunaudited',
#  'amountspecificadvanceorcreditdirectors',
#  'nameassociate',
#  'explanationfundsmateriallyindeficit',
#  'feesfornon-auditservices',
#  'accruedliabilitiesnotexpressedwithincreditorssubtotal',
#  'financeleaseliabilitiespresentvaluetotal',
#  'operatingleasepaymentsowing',
#  'countryformationorincorporation',
#  'additionalprovisionsincreasefromnewprovisionsrecognisedinprofitorloss',
#  'nameentitycharityauditors',
#  'capitalreductiondecreaseinequity',
#  'generaldescriptionchangesinaccountingestimatesincludingtheirfutureimpact',
#  'taxincreasedecreasefromeffectadjustmentinresearchdevelopmenttaxcredit',
#  'otheroperatingexpensesformat2',
#  'debenturesinissue',
#  'accountshavebeendeliveredinaccordancewithprovisionssmallcompaniesregime',
#  'lesseepolicy',
#  'netcashflowsfromusedinoperatingactivities',
#  'profitlossaccountreserve',
#  'statementthatcompanyentitledtoexemptionfromauditundersection480companiesact2006relatingtodormantcompanies',
#  'costsales',
#  'financialcommitmentsotherthancapitalcommitments',
#  'associatesaccountingconsolidationpolicy',
#  'nominalvaluesharesissuedinperiod',
#  'gainlossincashflowsfromchangeindebtorstradeotherreceivables',
#  'nameproductionsoftware',
#  'jointventurenotaccountedforusingequitymethodtruefalse',
#  'comprehensiveincomeexpense',
#  'incometaxfree-textcomment',
#  'revenuefromsalegoods',
#  'furtheritemgainlossbeforetaxcomponentnetgainlossbeforetax',
#  'totalliabilities',
#  'intangibleassetsfree-textcomment',
#  'ownshares',
#  'applicabletaxrate',
#  'nominalvalueallottedsharecapital',
#  'derivativespolicy',
#  'depreciationimpairmentpropertyplantequipmentfree-textcomment',
#  'taxincreasedecreasefromeffectindexationallowanceoncapitalgains',
#  'accountstypefullorabbreviated',
#  'dateaccountsreceived',
#  'accountsarepreparedinaccordancewithcharitiesfrs102sorptruefalse',
#  'dividendpershareproposedbutnotpaid',
#  'nameultimatecontrollingpartyifnotultimateparent',
#  'interestpaidclassifiedasinvestmentactivities',
#  'provisionspolicy',
#  'biologicalassetscostmodelgross',
#  'descriptionmeasurementbasisforpropertyplantequipment',
#  'taxexpensecreditapplicabletaxrate',
#  'pensioncostsdefinedcontributionplan',
#  'amountsowedbyrelatedparties',
#  'non-currentassets',
#  'disposalsthroughbusinessdivestitureintangibleassets',
#  'furtheritemincreasedecreaseinintangibleassetscomponenttotalchangeinintangibleassets',
#  'rawmaterials',
#  'prepaymentsaccruedincomenotexpressedwithincurrentassetsubtotal',
#  'othercreditors',
#  'descriptionspecificadvanceorcredititsconditionsindicativeinterestratedirectors',
#  'inventoriespolicy',
#  'totaloperatingleasepayments',
#  'disposalsinvestmentpropertyfairvaluemodel',
#  'increasedecreaseduetotransfersbetweenclassesintangibleassets',
#  'otherrevenue',
#  'xbrldocumentfilename',
#  'ukcompanieshouseregisterednumber',
#  'politicaldonationsfree-textcomment',
#  'descriptionputtablefinancialinstrumentsclassifiedasequityinstrumentsincludingreclassificationsintooutfinancialliabilities',
#  'restructuringcosts',
#  'paymentstothirdpartiesfordirectorservices',
#  'accumulateddepreciationimpairmentbiologicalassetscostmodel',
#  'otherpayablesaccruedexpenses',
#  'scopeaccounts',
#  'entityhasclaimedexemptionfromreportingdisclosurerelatedpartytransactionsforwholly-ownedentitiestruefalse',
#  'namejointventure',
#  'gainlossduetoforeignexchangedifferencesrecognisedinprofitorloss',
#  'balancesamountsowedtorelatedparties',
#  'explanationcharitableaimsincludingdetailschangesitseekstomakethroughactivities',
#  'otheremployeebenefitspolicy',
#  'longtermcontractworkinprogress',
#  'liabilitiessecuredbyassets',
#  'dateendreportingperiodsubsidiaryifdifferentfromentity',
#  'tradedebtorstradereceivables',
#  'allocationcostspolicy',
#  'principalfundingsourcescharity',
#  'descriptionreasonsforanychangeinreportingperiodimpactoncomparability',
#  'impairmentlossreversaloninvestments',
#  'amountspecificadvanceorcreditrepaidinperioddirectors',
#  'statementthatmembershavenotrequiredcompanytoobtainanaudit',
#  'percentageclassshareheldinassociate',
#  'amountsrecoverableoncontracts',
#  'nonetrusteeshavebeenpaidanyremunerationorreceivedanyotherbenefitstruefalse',
#  'employeebenefitsfree-textcomment',
#  'interimdividendspaid',
#  'interestincomeonfinancialassetsthatarenotfairvaluethroughprofitorloss',
#  'capitalisedborrowingcostsrelatedtopropertyplantequipment',
#  'investmentsinsubsidiariesmeasuredfairvalue',
#  'repaymentsborrowingsclassifiedasfinancingactivities',
#  'notrusteeexpenseshavebeenincurredtruefalse',
#  'redeemablepreferencesharesliability',
#  'entityhasclaimedexemptionfromreportingcertaininformationonsharebasedpaymentsinlinewithfrs1021.12dtruefalse',
#  'deferredtaxationfree-textcomment',
#  'usefullifepropertyplantequipmentyears',
#  'paymentsonaccountinventories',
#  'employeeinformationfree-textcomment',
#  'generaldescriptioncontingentliabilitiesincludingfinancialeffectuncertaintiespossiblereimbursement',
#  'disposalsdecreaseinamortisationimpairmentintangibleassets',
#  'auditfeesexpenses',
#  'descriptioncapitalcommitments',
#  'transfersbetweenppeclassesincreasedecreaseindepreciationimpairment',
#  'increasedecreasefromfairvalueadjustmentinvestmentpropertyfairvaluemodel',
#  'salesmarketingdistributionaveragenumberemployees',
#  'assumedpercentageemployeesoptingforearlyretirement',
#  'deferredtaxassets',
#  'assumedrateincreaseinretirementhealthcarecosts',
#  'loanstoassociatesjointventuresparticipatinginterests',
#  'directorremuneration',
#  'furtheritemoperatingincomegainincomestatementitemcomponentoperatingprofitloss',
#  'dateendreportingperiodassociateifdifferentfromentity',
#  'investmentpropertypolicyincludingright-of-use',
#  'explanationaffiliationswithotherbodies',
#  'sharecapitalfree-textcomment',
#  'dateresignation',
#  'descriptionalternativeregistrationincludingnamebusinessregistrynumber',
#  'provisions',
#  'percentageclassshareheldinjointventure',
#  'depreciationamortisationexpense',
#  'nomatterhascometoattentionindependentexaminertruefalse',
#  'totaladditionsincludingfrombusinesscombinationspropertyplantequipment',
#  'descriptionperiodcoveredbyreport',
#  'numberequityinstrumentsoutstandingshare-basedpaymentarrangement',
#  'otheroperatingincome',
#  'generaldescriptionanyoff-balancesheetarrangementsincludingnaturepurposefinancialimpactonentity',
#  'cashcashequivalents',
#  'nameordescriptionbiologicalassetclass',
#  'investmentsinsubsidiaries',
#  'incomefromassociatesjointventuresparticipatinginterests',
#  'non-currentliabilities',
#  'otherremaininginvestments',
#  'deferredtaxexpensecreditfromunrecognisedtimingdifferencefrompriorperiod',
#  'interestpaidclassifiedasoperatingactivities',
#  'addressparentlargestgroup',
#  'corporationtaxrecoverable',
#  'loanstoassociates',
#  'otherincreasedecreaseinamortisationimpairmentintangibleassets',
#  'paymentsfinanceleaseliabilitiesclassifiedasfinancingactivities',
#  'cumulativepreferencesharedividendsunpaid',
#  'reportincludesstrategicreporttruefalse',
#  'statementcomprehensiveincomefree-textcomment',
#  'increasedecreaseinloansowedtorelatedpartiesattributabletointeresttransactions',
#  'lesseefinanceleasepolicy',
#  'merchandise',
#  'generaldescriptionnatureprovisionincludingtimingoutflowsmajorassumptionsaboutfutureevents',
#  'descriptionfinancialliabilitiesdesignatedfairvaluethroughprofitorlosssubjecttochangeinfairvalueduetochangesincreditrisk',
#  'nameseniorstatutorycharityauditor',
#  'totalborrowings',
#  'rawmaterialsconsumablesused',
#  'taxonprofitorlossonordinaryactivities',
#  'increasefromimpairmentlossrecognisedinprofitorlossintangibleassets',
#  'dividendspaidonsharesinterim',
#  'cashreceiptsfromrepaymentloansadvancesclassifiedasinvestingactivities',
#  'increasedecreaseincurrenttaxfromunrecognisedtimingdifferencefrompriorperiod',
#  'equity',
#  'reporttitle',
#  'incometaxexpensecreditoncomponentsothercomprehensiveincome',
#  'impairmentlossintangibleassets',
#  'statementthatcompanyentitledtoexemptionfromauditundersection477companiesact2006relatingtosmallcompanies',
#  'furtheritemnon-operatinggainlossbeforetaxincomestatementitemcomponentprofitorlossbeforetax',
#  'descriptioncontributionplan',
#  'furtheritemcashflowfromusedinoperatingactivitiescomponenttotalnetcashflowsfromusedinoperatingactivities',
#  'numbersharesissuedbutnotfullypaid',
#  'entityhastakenexemptionundercompaniesactinnotpublishingitsownprofitlossaccounttruefalse',
#  'descriptionrightspreferencesrestrictionsattachingtoclasssharecapital',
#  'countryincorporationorresidencejointventure',
#  'furtheritempurchaselong-termassetsclassifiedasinvestingactivitiescomponentcorrespondingtotal',
#  'netcashflowsfromusedininvestingactivities',
#  'amortisationexpenseintangibleassets',
#  'proceedsfromsalesinvestmentproperties',
#  'descriptiondepreciationmethodforpropertyplantequipment',
#  'performancematerialfundraisingactivitiesagainstfundraisingobjectivesset',
#  'interestpaidtogroupundertakings',
#  'provisionsforliabilitiesbalancesheetsubtotal',
#  'otherdebtors',
#  'calledupsharecapitalnotpaidcurrentasset',
#  'taxpolicy',
#  'investmentpropertycostmodelgross',
#  'taxationcomplianceservicesentitysubsidiariesfees',
#  'currenttaxforperiod',
#  'tradeotherreceivables',
#  'namemostseniorparententityproducingpubliclyavailablefinancialstatements',
#  'increaseinassetsdefinedbenefitplanfromcontributionsbyemployer',
#  'descriptionwhyanentitywithsubsidiarieshasnotpreparedgroupaccounts',
#  'increasefromdepreciationchargeforyearbiologicalassetscostmodel',
#  'disposalsdecreaseindepreciationimpairmentbiologicalassetscostmodel',
#  'directorsreportconsistentwithaccountstruefalse',
#  'fairvalueassetsindefinedbenefitplanslesspresentvaluefundedobligations',
#  'increasedecreasethroughotherchangesintangibleassets',
#  'increasedecreaseinexistingprovisions',
#  'interestexpenseonobligationsunderfinanceleaseshirepurchasecontracts',
#  'dividendpershareinterim',
#  'taxationincludingdeferredtaxationbalancesheetsubtotal',
#  'profitlosssubsidiaries',
#  'statementtrusteesresponsibilities',
#  'gainlossbeforetaxonsalediscontinuedoperations',
#  'investmentsinassociatesjointventuresparticipatinginterests',
#  'statementonscopeaccountantsreport',
#  'taxationcomplianceservicesfees',
#  'depreciationexpensepropertyplantequipment',
#  'amountsowedbyparententities',
#  'cashcashequivalentscashflowvalue',
#  'debtorsfree-textcomment',
#  'numberdirectorsaccruingbenefitsunderdefinedbenefitscheme',
#  'impairmentnon-financialassetspolicy',
#  'increasedecreaseinnetdeferredtaxliabilityfromamountrecognisedinprofitorloss',
#  'costcharitableactivity',
#  'increasefromamortisationchargeforyearintangibleassets',
#  'totalincreasedecreasefromrevaluationsintangibleassets',
#  'corporationtaxpayable',
#  'amountsowedbyjointventures',
#  'otheremployeeexpense',
#  'cashreceiptsfromgovernmentgrants',
#  'statementthatdirectorsreporthasbeenpreparedinaccordancewithprovisionssmallcompaniesregime',
#  'descriptionmattersgivingrisetoanymodifiedauditopinion',
#  'taxincreasedecreasefromtransferpricingadjustments',
#  'nameauthor',
#  'audit-relatedassuranceservicesfees',
#  'descriptionactivity',
#  'issuebonussharesdecreaseincreaseinequity',
#  'sorpsapplied',
#  'definedbenefitpensionspolicy',
#  'generaldescriptioncapitalrequirementsincludingexternalimpositionmanagementchangesconsequencesnon-compliance',
#  'netdeferredtaxliabilityasset',
#  'distributionaveragenumberemployees',
#  'amortisationgovernmentgrants',
#  'governmentgrantsothergovernmentassistancepolicy',
#  'companyentitledtoexemptionundersection480companiesact2006relatingtodormantcompanies',
#  'increasedecreaseincurrenttaxfromadjustmentforpriorperiods',
#  'descriptionclassshareheldinassociate',
#  'effectivedaterevaluationpropertyplantequipment',
#  'profitlossforperiod',
#  'numbersharesallotted',
#  'expenditure',
#  'otherdepartmentsaveragenumberemployees',
#  'furtheritemgainlossinothercomprehensiveincomenettaxcomponenttotalothercomprehensiveincomenettax',
#  'grossamountduetocustomersforconstructioncontractworkasliability',
#  'countryinwhichparentlargestgroupincorporated',
#  'dateaccountantsreport',
#  'investmentpropertyfairvaluemodel',
#  'intangibleassetsgrosscost',
#  'descriptionunfulfilledconditionsothercontingenciesattachingtogovernmentassistance',
#  'descriptionpropertyplantequipmentwithrestrictedtitleorpledgedassecurity',
#  'investmentsinsubsidiariesfree-textcomment',
#  'loansfromparententities',
#  'increasedecreasefromrevaluationsrecognisedorreversedinothercomprehensiveincomepropertyplantequipment',
#  'controllingpartyultimatecontrollingpartytruefalse',
#  'intangibleassets',
#  'investmentpropertyincludingright-of-useassets',
#  'transfertonon-currentassetsordisposalgroupsheldforsaledecreaseindepreciationimpairmentpropertyplantequipment',
#  'staffcostsemployeebenefitsexpense',
#  'totalconsideration',
#  ...]

# %%
print(len(max(list_of_tags_unique, key = len)))
# Out:
# 164

# %%
def retrieve_list_of_tags(dataframe, column, output_folder):
    list_of_tags = dataframe[column].tolist()
    list_of_tags_unique = list(set(list_of_tags))
    
    print(
        "Number of tags in total: {} \nOf which are unique: {}".format(len(list_of_tags), len(list_of_tags_unique))
    )
    
    with open(output_folder + "/" + "list-of_tags.txt", "w") as f:
        for item in list_of_tags_unique:
            f.write("%s\n" % item)
            
retrieve_list_of_tags(results, "name", "/shares/data/20200519_companies_house_accounts/logs/")
# Out:
# Number of tags in total: 1569143
# Of which are unique: 1013

# %%
# Out:
# equity                                                                                                                             90000
# creditors                                                                                                                          66842
# entitycurrentlegalorregisteredname                                                                                                 59117
# ukcompanieshouseregisterednumber                                                                                                   46675
# nameentityofficer                                                                                                                  44337
#                                                                                                                                    ...
# numberequityinstrumentsoutstandingshare-basedpaymentarrangement                                                                        1
# oneormoretrusteeshasbeenpaidremunerationorreceivedotherbenefitstruefalse                                                               1
# financialliabilitiesassumed                                                                                                            1
# accountshavebeendeliveredinaccordancewithprovisionssmallcompaniesregime                                                                1
# furtheritemgainlossincashflowsfromchangeinoperatingliabilitiescomponenttotalgainlossincashflowsfromchangeinoperatingliabilities        1
# Name: name, Length: 1013, dtype: int64

# %% [markdown]
# ```python
# def get_tag_counts(dataframe, column):
#     dataframe['count'] = dataframe.groupby(by = column)[column].transform('count')
#     dataframe.sort_values('count', inplace = True, ascending = False)
#     dataframe.drop_duplicates(subset = [column, 'count'], keep = 'first', inplace = True)
#     dataframe = dataframe[[column, 'count']]
#
# tag_counts = get_tag_counts(results, 'name')
#
# tag_counts.head(10)
# ```

# %%
get_tag_counts.sort_values('count', inplace = True, ascending = False)

get_tag_counts.drop_duplicates(subset = ['name', 'count'], keep = 'first', inplace = True)

get_tag_counts = get_tag_counts[['name', 'count']]

print(get_tag_counts.shape)

get_tag_counts.head(50)
# Out:
# (1013, 2)
#                                                   name  count
# 42                                              equity  90000
# 10                                           creditors  66842
# 45                  entitycurrentlegalorregisteredname  59117
# 28                    ukcompanieshouseregisterednumber  46675
# 67                                   nameentityofficer  44337
# 3                      enddateforperiodcoveredbyreport  43798
# 70                              propertyplantequipment  41475
# 18                         netcurrentassetsliabilities  40747
# 33                   totalassetslesscurrentliabilities  38386
# 10                                       currentassets  38384
# 51                                netassetsliabilities  38126
# 5                   directorsigningfinancialstatements  32837
# 11                                    balancesheetdate  31851
# 5                        accountstypefullorabbreviated  29868
# 7                    startdateforperiodcoveredbyreport  27742
# 64   accumulateddepreciationimpairmentpropertyplant...  26826
# 85                     propertyplantequipmentgrosscost  26400
# 8                                              debtors  25443
# 45        dateauthorisationfinancialstatementsforissue  24559
# 22                              entitydormanttruefalse  24292
# 2                                  entitytradingstatus  24273
# 6                           accountingstandardsapplied  24263
# 36                    accountsstatusauditedorunaudited  24263
# 29   statementthataccountshavebeenpreparedinaccorda...  24185
# 26   statementthatdirectorsacknowledgetheirresponsi...  23981
# 27   statementthatmembershavenotrequiredcompanytoob...  23834
# 11                                     legalformentity  21635
# 7                                          fixedassets  21208
# 65   statementthatcompanyentitledtoexemptionfromaud...  21029
# 45                                      cashbankonhand  20023
# 80                  averagenumberemployeesduringperiod  16228
# 0                               nameproductionsoftware  16127
# 3                                          reporttitle  14984
# 39                           versionproductionsoftware  14707
# 128                                     othercreditors  13500
# 87   increasefromdepreciationchargeforyearpropertyp...  13258
# 3                      countryformationorincorporation  12210
# 55                               applicablelegislation  11912
# 22                                        addressline1   9897
# 6        descriptionbodyauthorisingfinancialstatements   9875
# 21                                       postalcodezip   9870
# 51                                        otherdebtors   9838
# 9                       descriptionprincipalactivities   9384
# 22                        principallocation-cityortown   9359
# 109                        tradecreditorstradepayables   9287
# 52   descriptiondepreciationmethodforpropertyplante...   9127
# 61   statementcompliancewithapplicablereportingfram...   8851
# 96                        tradedebtorstradereceivables   8818
# 83                  othertaxationsocialsecuritypayable   7740
# 10                                       scopeaccounts   7231
