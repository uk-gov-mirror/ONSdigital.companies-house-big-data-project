# %% [markdown]
# <a id='section1'></a>
# <div style="
#     width: 100%;
#     height: 100px;
#     border:none;
#     background:linear-gradient(-45deg, #d84227, #ce3587);
#     text-align: center;
#     position: relative;
# ">
#   <span style="
#       font-size: 40px;
#       padding: 0 10px;
#       color: white;
#       margin: 0;
#       position: absolute;
#       top: 50%;
#       left: 50%;
#       -ms-transform: translate(-50%, -50%);
#       transform: translate(-50%, -50%);
#       font-weight: bold;
#   ">
#     XBRL PARSER <!--Padding is optional-->
#   </span>
# </div><a id='section1'></a>

# %%
"""
Martin Wood - Office for National Statistics
martin.wood@ons.gov.uk
23/07/2018
XBRL parser
Contains functions that scrape and clean an XBRL document's content
and variables, returning a dict ready for dumping into
MongoDB.
"""

import os
import re

import numpy as np
import pandas as pd

from datetime import datetime
from dateutil import parser
from bs4 import BeautifulSoup as BS  # Can parse xml or html docs

# Table of variables and values that indicate consolidated status
consolidation_var_table = {
    "includedinconsolidationsubsidiary": True,
    "investmententityrequiredtoapplyexceptionfromconsolidationtruefalse": True,
    "subsidiaryunconsolidatedtruefalse": False,
    "descriptionreasonwhyentityhasnotpreparedconsolidatedfinancialstatements": "exist",
    "consolidationpolicy": "exist"
}


def clean_value(string):
    """
    Take a value that's stored as a string,
    clean it and convert to numeric.

    If it's just a dash, it's taken to mean
    zero.
    """
    if string.strip() == "-":
        return (0.0)

    try:
        return float(string.strip().replace(",", "").replace(" ", ""))
    except:
        pass

    return (string)


def retrieve_from_context(soup, contextref):
    """
    Used where an element of the document contained no data, only a
    reference to a context element.
    Finds the relevant context element and retrieves the relevant data.

    Returns a text string

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    contextref -- the id of the context element to be raided
    """

    try:
        context = soup.find("xbrli:context", id=contextref)
        contents = context.find("xbrldi:explicitmember").get_text().split(":")[-1].strip()

    except:
        contents = ""

    return (contents)


def retrieve_accounting_standard(soup):
    """
    Gets the account reporting standard in use in a document by hunting
    down the link to the schema reference sheet that always appears to
    be in the document, and extracting the format and standard date from
    the string of the url itself.
    WARNING - That means that there's a lot of implicity hardcoded info
    on the way these links are formated and referenced, within this
    function.  Might need changing someday.

    Returns a 3-tuple (standard, date, original url)

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    """

    # Find the relevant link by its unique attribute
    link_obj = soup.find("link:schemaref")

    # If we didn't find anything it's an xml doc using a different
    # element name:
    if link_obj == None:
        link_obj = soup.find("schemaref")

    # extract the name of the .xsd schema file, which contains format
    # and date information
    text = link_obj['xlink:href'].split("/")[-1].split(".")[0]

    # Split the extracted text into format and date, return values
    return (text[:-10].strip("-"), text[-10:], link_obj['xlink:href'])


def retrieve_unit(soup, each):
    """
    Gets the reporting unit by trying to chase a unitref to
    its source, alternatively uses element attribute unitref
    if it's not a reference to another element.

    Returns the unit

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    each -- element of BeautifulSoup souped object
    """

    # If not, try to discover the unit string in the
    # soup object
    try:
        unit_str = soup.find(id=each['unitref']).get_text()

    except:
        # Or if not, in the attributes of the element
        try:
            unit_str = each.attrs['unitref']

        except:
            return ("NA")

    return (unit_str.strip())


def retrieve_date(soup, each):
    """
    Gets the reporting date by trying to chase a contextref
    to its source and extract its period, alternatively uses
    element attribute contextref if it's not a reference
    to another element.
    Returns the date

    Keyword arguments:
    soup -- BeautifulSoup souped html/xml object
    each -- element of BeautifulSoup souped object
    """

    # Try to find a date tag within the contextref element,
    # starting with the most specific tags, and starting with
    # those for ixbrl docs as it's the most common file.
    date_tag_list = ["xbrli:enddate",
                     "xbrli:instant",
                     "xbrli:period",
                     "enddate",
                     "instant",
                     "period"]

    for tag in date_tag_list:
        try:
            date_str = each['contextref']
            date_val = parser.parse(soup.find(id=each['contextref']).find(tag).get_text()). \
                date(). \
                isoformat()
            return (date_val)
        except:
            pass

    try:
        date_str = each.attrs['contextref']
        date_val = parser.parse(each.attrs['contextref']). \
            date(). \
            isoformat()
        return (date_val)
    except:
        pass

    return ("NA")


def parse_element(soup, element):
    """
    For a discovered XBRL tagged element, go through, retrieve its name
    and value and associated metadata.

    Keyword arguments:
    soup -- BeautifulSoup object of accounts document
    element -- soup object of discovered tagged element
    """

    if "contextref" not in element.attrs:
        return ({})

    element_dict = {}

    # Basic name and value
    try:
        # Method for XBRLi docs first
        element_dict['name'] = element.attrs['name'].lower().split(":")[-1]
    except:
        # Method for XBRL docs second
        element_dict['name'] = element.name.lower().split(":")[-1]

    element_dict['value'] = element.get_text()
    element_dict['unit'] = retrieve_unit(soup, element)
    element_dict['date'] = retrieve_date(soup, element)

    # If there's no value retrieved, try raiding the associated context data
    if element_dict['value'] == "":
        element_dict['value'] = retrieve_from_context(soup, element.attrs['contextref'])

    # If the value has a defined unit (eg a currency) convert to numeric	
    if element_dict['unit'] != "NA":
        element_dict['value'] = clean_value(element_dict['value'])

    # Retrieve sign of element if exists
    try:
        element_dict['sign'] = element.attrs['sign']

        # if it's negative, convert the value then and there
        if element_dict['sign'].strip() == "-":
            element_dict['value'] = 0.0 - element_dict['value']
    except:
        pass

    return (element_dict)


def parse_elements(element_set, soup):
    """
    For a set of discovered elements within a document, try to parse
    them.  Only keep valid results (test is whether field "name"
    exists).

    Keyword arguments:
    element_set -- BeautifulSoup iterable search result object
    soup -- BeautifulSoup object of accounts document
    """
    elements = []
    for each in element_set:
        element_dict = parse_element(soup, each)
        if 'name' in element_dict:
            elements.append(element_dict)
    return (elements)


def summarise_by_sum(doc, variable_names):
    """
    Takes a document (dict) after extraction, and tries to extract
    a summary variable relating to the financial state of the enterprise
    by summing all those named that exist.  Returns dict.

    Keyword arguments:
    doc -- an extracted document dict, with "elements" entry as created
           by the 'scrape_clean_elements' functions.
    variable_names - variables to find and sum if they exist
    """

    # Convert elements to pandas df
    df = pd.DataFrame(doc['elements'])

    # Subset to most recent (latest dated)
    df = df[df['date'] == doc['doc_balancesheetdate']]

    total_assets = 0.0
    unit = "NA"

    # Find the total assets by summing components
    for each in variable_names:

        # Fault-tolerant, will skip whatever isn't numeric
        try:
            total_assets = total_assets + df[df['name'] == each].iloc[0]['value']

            # Retrieve reporting unit if exists
            unit = df[df['name'] == each].iloc[0]['unit']

        except:
            pass

    return ({"total_assets": total_assets, "unit": unit})


def summarise_by_priority(doc, variable_names):
    """
    Takes a document (dict) after extraction, and tries to extract
    a summary variable relating to the financial state of the enterprise
    by looking for each named, in order.  Returns dict.

    Keyword arguments:
    doc -- an extracted document dict, with "elements" entry as created
           by the 'scrape_clean_elements' functions.
    variable_names - variables to find and check if they exist.
    """

    # Convert elements to pandas df
    df = pd.DataFrame(doc['elements'])

    # Subset to most recent (latest dated)
    df = df[df['date'] == doc['doc_balancesheetdate']]

    primary_assets = 0.0
    unit = "NA"

    # Find the net asset/liability variable by hunting names in order
    for each in variable_names:
        try:

            # Fault tolerant, will skip whatever isn't numeric
            primary_assets = df[df['name'] == each].iloc[0]['value']

            # Retrieve reporting unit if it exists
            unit = df[df['name'] == each].iloc[0]['unit']
            break

        except:
            pass

    return ({"primary_assets": primary_assets, "unit": unit})


def summarise_set(doc, variable_names):
    """
    Takes a document (dict) after extraction, and tries to extract
    summary variables relating to the financial state of the enterprise
    by returning all those named that exist.  Returns dict.

    Keyword arguments:
    doc -- an extracted document dict, with "elements" entry as created
           by the 'scrape_clean_elements' functions.
    variable_names - variables to find and return if they exist.
    """
    results = {}

    # Convert elements to pandas df
    df = pd.DataFrame(doc['elements'])

    # Subset to most recent (latest dated)
    df = df[df['date'] == doc['doc_balancesheetdate']]

    # Find all the variables of interest should they exist
    for each in variable_names:
        try:
            results[each] = df[df['name'] == each].iloc[0]['value']

        except:
            pass

    # Send the variables back to be appended
    return (results)


def scrape_elements(soup, filepath):
    """
    Parses an XBRL (xml) company accounts file
    for all labelled content and extracts the
    content (and metadata, eg; unitref) of each
    element found to a dictionary 

    params: filepath (str)
    output: list of dicts
    """

    # Try multiple methods of retrieving data, I think only the first is
    # now needed though.  The rest will be removed after testing this
    # but should not affect execution speed.
    try:
        element_set = soup.find_all()
        elements = parse_elements(element_set, soup)
        if len(elements) <= 5:
            raise Exception("Elements should be gte 5, was {}".format(len(elements)))
        return (elements)
    except:
        pass

    return (0)


def flatten_data(doc):
    """
    Takes the data returned by process account, with its tree-like
    structure and reorganises it into a long-thin format table structure
    suitable for SQL applications.
    """

    # Need to drop components later, so need copy in function
    doc2 = doc.copy()
    doc_df = pd.DataFrame()

    # Pandas should create series, then columns, from dicts when called
    # like this
    for element in doc2['elements']:
        doc_df = doc_df.append(element, ignore_index=True)

    # Dump the "elements" entry in the doc dict
    doc2.pop("elements")

    # Create uniform columns for all other properties
    for key in doc2:
        doc_df[key] = doc2[key]

    return (doc_df)


def process_account(filepath):
    """
    Scrape all of the relevant information from
    an iXBRL (html) file, upload the elements
    and some metadata to a mongodb.

    Named arguments:
    filepath -- complete filepath (string) from drive root
    """
    doc = {}

    # Some metadata, doc name, upload date/time, archive file it came from
    doc['doc_name'] = filepath.split("/")[-1]
    doc['doc_type'] = filepath.split(".")[-1].lower()
    doc['doc_upload_date'] = str(datetime.now())
    doc['arc_name'] = filepath.split("/")[-2]
    doc['parsed'] = True

    # Complicated ones
    sheet_date = filepath.split("/")[-1].split(".")[0].split("_")[-1]
    doc['doc_balancesheetdate'] = datetime.strptime(sheet_date, "%Y%m%d").date().isoformat()

    doc['doc_companieshouseregisterednumber'] = filepath.split("/")[-1].split(".")[0].split("_")[-2]

    print(filepath)

    try:
        soup = BS(open(filepath, "rb"), "html.parser")
    except:
        print("Failed to open: " + filepath)
        return (1)

    # Get metadata about the accounting standard used
    try:
        doc['doc_standard_type'], doc['doc_standard_date'], doc['doc_standard_link'] = retrieve_accounting_standard(
            soup)
    except:
        doc['doc_standard_type'], doc['doc_standard_date'], doc['doc_standard_link'] = (0, 0, 0)

    # Fetch all the marked elements of the document
    try:
        doc['elements'] = scrape_elements(soup, filepath)
    except Exception as e:
        doc['parsed'] = False
        doc['Error'] = e

    try:
        return (doc)
    except Exception as e:
        return (e)

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br>
# <a id='section1'></a>
# <div style="
#     width: 100%;
#     height: 100px;
#     border:none;
#     background:linear-gradient(-45deg, #d84227, #ce3587);
#     text-align: center;
#     position: relative;
# ">
#   <span style="
#       font-size: 40px;
#       padding: 0 10px;
#       color: white;
#       margin: 0;
#       position: absolute;
#       top: 50%;
#       left: 50%;
#       -ms-transform: translate(-50%, -50%);
#       transform: translate(-50%, -50%);
#       font-weight: bold;
#   ">
#     EXTRACTION <!--Padding is optional-->
#   </span>
# </div><a id='section1'></a>

# %%
import os
import numpy as np
import pandas as pd
import importlib

def get_filepaths(directory):

    """ Helper function - 
    Get all of the filenames in a directory that
    end in htm* or xml.
    Under the assumption that all files within
    the folder are financial records. """

    files = [directory + "/" + filename
                for filename in os.listdir(directory)
                    if (("htm" in filename.lower()) or ("xml" in filename.lower()))]
    return(files)

# %%
# Get all the filenames from the example folder
files = get_filepaths("D:\Project_3 - Image_Processing\cha_pipeline\data")

# There's 379 examples currently
files[0:3]
# Out:
# ['D:\\Project_3 - Image_Processing\\cha_pipeline\\data/Prod223_2623_00192996_20190331.html',
#  'D:\\Project_3 - Image_Processing\\cha_pipeline\\data/Prod223_2623_00455009_20190630.html',
#  'D:\\Project_3 - Image_Processing\\cha_pipeline\\data/Prod223_2623_00685645_20190630.html']

# %%
doc = process_account(files[0])

# display for fun
doc
# Out:
# D:\Project_3 - Image_Processing\cha_pipeline\data/Prod223_2623_00192996_20190331.html
# {'arc_name': 'D:\\Project_3 - Image_Processing\\cha_pipeline\\data',
#  'doc_balancesheetdate': '2019-03-31',
#  'doc_companieshouseregisterednumber': '00192996',
#  'doc_name': 'Prod223_2623_00192996_20190331.html',
#  'doc_standard_date': '2014-09-01',
#  'doc_standard_link': 'https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS-102-2014-09-01.xsd',
#  'doc_standard_type': 'FRS-102',
#  'doc_type': 'html',
#  'doc_upload_date': '2020-06-01 09:27:07.117622',
#  'elements': [{'date': '2019-03-31',
#    'name': 'nameproductionsoftware',
#    'unit': 'NA',
#    'value': 'IRIS Accounts Production'},
#   {'date': '2019-03-31',
#    'name': 'versionproductionsoftware',
#    'unit': 'NA',
#    'value': 'v19.3.2.199'},
#   {'date': '2019-03-31',
#    'name': 'ukcompanieshouseregisterednumber',
#    'unit': 'NA',
#    'value': '00192996'},
#   {'date': '2019-03-31',
#    'name': 'countryformationorincorporation',
#    'unit': 'NA',
#    'value': 'EnglandWales'},
#   {'date': '2019-03-31',
#    'name': 'principalcurrencyusedinbusinessreport',
#    'unit': 'NA',
#    'value': 'PoundSterling'},
#   {'date': '2019-03-31',
#    'name': 'directorsigningfinancialstatements',
#    'unit': 'NA',
#    'value': 'Director1'},
#   {'date': '2019-03-31',
#    'name': 'descriptionbodyauthorisingfinancialstatements',
#    'unit': 'NA',
#    'value': 'Board of Directors'},
#   {'date': '2019-03-31',
#    'name': 'directorsigningdirectorsreport',
#    'unit': 'NA',
#    'value': 'Director1'},
#   {'date': '2019-03-31',
#    'name': 'balancesheetdate',
#    'unit': 'NA',
#    'value': '31.3.19'},
#   {'date': '2019-03-31',
#    'name': 'startdateforperiodcoveredbyreport',
#    'unit': 'NA',
#    'value': '1.4.18'},
#   {'date': '2019-03-31',
#    'name': 'enddateforperiodcoveredbyreport',
#    'unit': 'NA',
#    'value': '31.3.19'},
#   {'date': '2019-03-31',
#    'name': 'balancesheetdate',
#    'unit': 'NA',
#    'value': '31.3.19'},
#   {'date': '2019-03-31',
#    'name': 'scopeaccounts',
#    'unit': 'NA',
#    'value': 'ConsolidatedGroupCompanyAccounts'},
#   {'date': '2019-03-31',
#    'name': 'legalformentity',
#    'unit': 'NA',
#    'value': 'PrivateLimitedCompanyLtd'},
#   {'date': '2019-03-31', 'name': 'reportperiod', 'unit': 'NA', 'value': ''},
#   {'date': '2019-03-31',
#    'name': 'accountingstandardsapplied',
#    'unit': 'NA',
#    'value': 'Consolidated'},
#   {'date': '2019-03-31',
#    'name': 'accountsstatusauditedorunaudited',
#    'unit': 'NA',
#    'value': 'Consolidated'},
#   {'date': '2019-03-31',
#    'name': 'applicablelegislation',
#    'unit': 'NA',
#    'value': 'LargeMedium-sizedCompaniesRegimeForDirectorsReport'},
#   {'date': '2019-03-31',
#    'name': 'applicablelegislation',
#    'unit': 'NA',
#    'value': 'LargeMedium-sizedCompaniesRegimeForAccounts'},
#   {'date': '2019-03-31',
#    'name': 'applicablelegislation',
#    'unit': 'NA',
#    'value': 'Consolidated'},
#   {'date': '2019-03-31',
#    'name': 'applicablelegislation',
#    'unit': 'NA',
#    'value': 'Consolidated'},
#   {'date': '2019-03-31',
#    'name': 'accountstypefullorabbreviated',
#    'unit': 'NA',
#    'value': 'FullAccounts'},
#   {'date': '2019-03-31',
#    'name': 'accountstypefullorabbreviated',
#    'unit': 'NA',
#    'value': 'FullAccounts'},
#   {'date': '2019-03-31',
#    'name': 'reportincludeslistsubsidiariestruefalse',
#    'unit': 'NA',
#    'value': 'true'},
#   {'date': '2019-03-31',
#    'name': 'entityhastakenexemptionundercompaniesactinnotpublishingitsownprofitlossaccounttruefalse',
#    'unit': 'NA',
#    'value': 'true'},
#   {'date': '2019-03-31',
#    'name': 'companyhaspublishedcommitmenttoukeffectivestewardshipcodetruefalse',
#    'unit': 'NA',
#    'value': 'false'},
#   {'date': '2019-03-31',
#    'name': 'directorsreportconsistentwithaccountstruefalse',
#    'unit': 'NA',
#    'value': 'true'},
#   {'date': '2019-03-31',
#    'name': 'financialstatementsarepreparedongoing-concernbasistruefalse',
#    'unit': 'NA',
#    'value': 'true'},
#   {'date': '2019-03-31',
#    'name': 'subsidiaryunconsolidatedtruefalse',
#    'unit': 'NA',
#    'value': 'false'},
#   {'date': '2019-03-31',
#    'name': 'definedbenefitplanmulti-employerplantruefalse',
#    'unit': 'NA',
#    'value': 'false'},
#   {'date': '2019-03-31',
#    'name': 'recoverableamountspecificintangibleassetbasedvalueinusetruefalse',
#    'unit': 'NA',
#    'value': 'false'},
#   {'date': '2019-03-31',
#    'name': 'investmententityrequiredtoapplyexceptionfromconsolidationtruefalse',
#    'unit': 'NA',
#    'value': 'false'},
#   {'date': '2019-03-31',
#    'name': 'entityhasclaimedexemptionfromreportingdisclosurerelatedpartytransactionsforwholly-ownedentitiestruefalse',
#    'unit': 'NA',
#    'value': 'true'},
#   {'date': '2019-03-31',
#    'name': 'entitytradingstatus',
#    'unit': 'NA',
#    'value': ''},
#   {'date': '2019-03-31',
#    'name': 'entitydormanttruefalse',
#    'unit': 'NA',
#    'value': 'false'},
#   {'date': '2019-03-31',
#    'name': 'modelusedtomeasureinvestmentproperty',
#    'unit': 'NA',
#    'value': 'Fair value model'},
#   {'date': '2019-03-31',
#    'name': 'descriptionsharetype',
#    'unit': 'NA',
#    'value': 'Ordinary'},
#   {'date': '2019-03-31',
#    'name': 'parvalueshare',
#    'unit': 'xbrli:pure',
#    'value': 1.0},
#   {'date': '2019-03-31',
#    'name': 'reporttitle',
#    'unit': 'NA',
#    'value': 'GROUP STRATEGIC REPORT, REPORT OF THE DIRECTORS AND CONSOLIDATED FINANCIAL STATEMENTS FOR THE YEAR ENDED 31 MARCH 2019'},
#   {'date': '2019-03-31',
#    'name': 'entitycurrentlegalorregisteredname',
#    'unit': 'NA',
#    'value': 'GAWITH HOGGARTH & CO.,LIMITED'},
#   {'date': '2019-03-31',
#    'name': 'nameentityofficer',
#    'unit': 'NA',
#    'value': 'Mrs I M Gawith'},
#   {'date': '2019-03-31',
#    'name': 'nameentityofficer',
#    'unit': 'NA',
#    'value': 'Mr C S Gawith'},
#   {'date': '2019-03-31',
#    'name': 'addressline1',
#    'unit': 'NA',
#    'value': 'Unit 16/22'},
#   {'date': '2019-03-31',
#    'name': 'addressline2',
#    'unit': 'NA',
#    'value': 'Lake District Business Park'},
#   {'date': '2019-03-31',
#    'name': 'addressline3',
#    'unit': 'NA',
#    'value': 'Mint Bridge Road'},
#   {'date': '2019-03-31',
#    'name': 'principallocation-cityortown',
#    'unit': 'NA',
#    'value': 'Kendal'},
#   {'date': '2019-03-31',
#    'name': 'countyregion',
#    'unit': 'NA',
#    'value': 'Cumbria'},
#   {'date': '2019-03-31',
#    'name': 'postalcodezip',
#    'unit': 'NA',
#    'value': 'LA9 6NH'},
#   {'date': '2019-03-31',
#    'name': 'ukcompanieshouseregisterednumber',
#    'unit': 'NA',
#    'value': '00192996'},
#   {'date': '2019-03-31',
#    'name': 'nameentityauditors',
#    'unit': 'NA',
#    'value': 'RfM Preston Ltd'},
#   {'date': '2019-03-31',
#    'name': 'nameentityofficer',
#    'unit': 'NA',
#    'value': 'Mr C S Gawith'},
#   {'date': '2019-03-31',
#    'name': 'descriptionprincipalactivities',
#    'unit': 'NA',
#    'value': 'The principal activity of the group in the year under review was that of the manufacture and sale of tobaccoproducts. '},
#   {'date': '2019-03-31',
#    'name': 'nameentityofficer',
#    'unit': 'NA',
#    'value': 'Mrs I M Gawith'},
#   {'date': '2019-03-31',
#    'name': 'nameentityofficer',
#    'unit': 'NA',
#    'value': 'Mr R W Young'},
#   {'date': '2019-03-31',
#    'name': 'nameentityofficer',
#    'unit': 'NA',
#    'value': 'Mr C S Gawith'},
#   {'date': '2019-03-31',
#    'name': 'nameentityofficer',
#    'unit': 'NA',
#    'value': 'Mr C S Gawith'},
#   {'date': '2019-03-31',
#    'name': 'datesigningdirectorsreport',
#    'unit': 'NA',
#    'value': '30 March 2020'},
#   {'date': '2019-03-31',
#    'name': 'opinionauditorsonentity',
#    'unit': 'NA',
#    'value': "We have audited the financial statements of Gawith Hoggarth & Co.,Limited (the 'parent company') and itssubsidiaries (the 'group') for the year ended 31 March 2019 which comprise the Consolidated Statement ofIncome and Retained Earnings, Consolidated Statement of Financial Position, Company Statement ofFinancial Position, Consolidated Statement of Cash Flows and Notes to the Consolidated Statement ofCash Flows, Notes to the Financial Statements, including a summary of significant accounting policies. Thefinancial reporting framework that has been applied in their preparation is applicable law and UnitedKingdom Accounting Standards, including Financial Reporting Standard 102 'The Financial ReportingStandard applicable in the UK and Republic of Ireland' (United Kingdom Generally Accepted AccountingPractice). In our opinion the financial statements:-give a true and fair view of the state of the group's and of the parent company affairs as at 31 March 2019 and of the group's profit for the year then ended; -have been properly prepared in accordance with United Kingdom Generally Accepted Accounting Practice; and -have been prepared in accordance with the requirements of the Companies Act 2006. "},
#   {'date': '2019-03-31',
#    'name': 'nameseniorstatutoryauditor',
#    'unit': 'NA',
#    'value': 'Alan Meikle FCA'},
#   {'date': '2019-03-31',
#    'name': 'nameentityauditors',
#    'unit': 'NA',
#    'value': 'RfM Preston Ltd'},
#   {'date': '2019-03-31',
#    'name': 'dateauditorsreport',
#    'unit': 'NA',
#    'value': '30 March 2020'},
#   {'date': '2019-03-31',
#    'name': 'profitloss',
#    'unit': 'iso4217:GBP',
#    'value': 744523.0},
#   {'date': '2018-03-31',
#    'name': 'profitloss',
#    'unit': 'iso4217:GBP',
#    'value': 740950.0},
#   {'date': '2019-03-31',
#    'name': 'propertyplantequipment',
#    'unit': 'iso4217:GBP',
#    'value': 138653.0},
#   {'date': '2018-03-31',
#    'name': 'propertyplantequipment',
#    'unit': 'iso4217:GBP',
#    'value': 152951.0},
#   {'date': '2019-03-31',
#    'name': 'investmentsfixedassets',
#    'unit': 'iso4217:GBP',
#    'value': 1188400.0},
#   {'date': '2018-03-31',
#    'name': 'investmentsfixedassets',
#    'unit': 'iso4217:GBP',
#    'value': 1140452.0},
#   {'date': '2019-03-31',
#    'name': 'investmentproperty',
#    'unit': 'iso4217:GBP',
#    'value': 150000.0},
#   {'date': '2018-03-31',
#    'name': 'investmentproperty',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2019-03-31',
#    'name': 'fixedassets',
#    'unit': 'iso4217:GBP',
#    'value': 1765053.0},
#   {'date': '2018-03-31',
#    'name': 'fixedassets',
#    'unit': 'iso4217:GBP',
#    'value': 1629403.0},
#   {'date': '2019-03-31',
#    'name': 'totalinventories',
#    'unit': 'iso4217:GBP',
#    'value': 1227231.0},
#   {'date': '2018-03-31',
#    'name': 'totalinventories',
#    'unit': 'iso4217:GBP',
#    'value': 1272885.0},
#   {'date': '2019-03-31',
#    'name': 'debtors',
#    'unit': 'iso4217:GBP',
#    'value': 1136931.0},
#   {'date': '2018-03-31',
#    'name': 'debtors',
#    'unit': 'iso4217:GBP',
#    'value': 1537643.0},
#   {'date': '2019-03-31',
#    'name': 'cashbankonhand',
#    'unit': 'iso4217:GBP',
#    'value': 2927902.0},
#   {'date': '2018-03-31',
#    'name': 'cashbankonhand',
#    'unit': 'iso4217:GBP',
#    'value': 2142348.0},
#   {'date': '2019-03-31',
#    'name': 'currentassets',
#    'unit': 'iso4217:GBP',
#    'value': 5292064.0},
#   {'date': '2018-03-31',
#    'name': 'currentassets',
#    'unit': 'iso4217:GBP',
#    'value': 4952876.0},
#   {'date': '2019-03-31',
#    'name': 'creditors',
#    'unit': 'iso4217:GBP',
#    'value': 984237.0},
#   {'date': '2018-03-31',
#    'name': 'creditors',
#    'unit': 'iso4217:GBP',
#    'value': 1188257.0},
#   {'date': '2019-03-31',
#    'name': 'netcurrentassetsliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 4307827.0},
#   {'date': '2018-03-31',
#    'name': 'netcurrentassetsliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 3764619.0},
#   {'date': '2019-03-31',
#    'name': 'totalassetslesscurrentliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 6072880.0},
#   {'date': '2018-03-31',
#    'name': 'totalassetslesscurrentliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 5394022.0},
#   {'date': '2019-03-31',
#    'name': 'provisionsforliabilitiesbalancesheetsubtotal',
#    'unit': 'iso4217:GBP',
#    'value': 47114.0},
#   {'date': '2018-03-31',
#    'name': 'provisionsforliabilitiesbalancesheetsubtotal',
#    'unit': 'iso4217:GBP',
#    'value': 27960.0},
#   {'date': '2019-03-31',
#    'name': 'netassetsliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 6025766.0},
#   {'date': '2018-03-31',
#    'name': 'netassetsliabilities',
#    'unit': 'iso4217:GBP',
#    'value': 5366062.0},
#   {'date': '2019-03-31',
#    'name': 'equity',
#    'unit': 'iso4217:GBP',
#    'value': 10000.0},
#   {'date': '2018-03-31',
#    'name': 'equity',
#    'unit': 'iso4217:GBP',
#    'value': 10000.0},
#   {'date': '2019-03-31',
#    'name': 'equity',
#    'unit': 'iso4217:GBP',
#    'value': 6015766.0},
#   {'date': '2018-03-31',
#    'name': 'equity',
#    'unit': 'iso4217:GBP',
#    'value': 5356062.0},
#   {'date': '2019-03-31',
#    'name': 'equity',
#    'unit': 'iso4217:GBP',
#    'value': 6025766.0},
#   {'date': '2018-03-31',
#    'name': 'equity',
#    'unit': 'iso4217:GBP',
#    'value': 5366062.0},
#   {'date': '2019-03-31',
#    'name': 'dateauthorisationfinancialstatementsforissue',
#    'unit': 'NA',
#    'value': '30 March 2020'},
#   {'date': '2019-03-31',
#    'name': 'nameentityofficer',
#    'unit': 'NA',
#    'value': 'Mr C S Gawith'},
#   {'date': '2019-03-31',
#    'name': 'legalformentity',
#    'unit': 'NA',
#    'value': 'private company, limited by shares'},
#   {'date': '2019-03-31',
#    'name': 'statementcompliancewithapplicablereportingframework',
#    'unit': 'NA',
#    'value': 'These financial statements have been prepared in accordance with Financial Reporting Standard 102 "The Financial Reporting Standard applicable in the UK and Republic of Ireland" and the Companies Act 2006. The financial statements have been prepared under the historical cost convention as modified by the revaluation of certain assets.'},
#   {'date': '2019-03-31',
#    'name': 'generaldescriptioncriticalestimatesjudgements',
#    'unit': 'NA',
#    'value': 'Significant judgements and estimates made by management in preparing these financial statementswhich also have a significant risk of causing a material adjustment to the carrying amounts of assetsand liabilities within the next financial year include:- Depreciation and impairment of fixed assets- Accrued Income'},
#   {'date': '2019-03-31',
#    'name': 'intangibleassetspolicy',
#    'unit': 'NA',
#    'value': 'Goodwill arises on business acquisitions and represents the excess of the cost of the acquisition overthe company’s interest in the net amount of the identifiable assets, liabilities and contingent liabilitiesof the acquired business.Goodwill recognised at acquisition is measured at cost less accumulated amortisation andaccumulated impairment losses. Goodwill is amortised on a straight-line basis over its useful life,which is estimated to be ten years.Goodwill amortisation is charged on a straight line basis so as to write off the cost of the asset, lessits residual value assumed to be zero, over its useful economic life, which is estimated to be tenyears.Goodwill amortisation is included in administrative expenses in the statement of comprehensiveincome.'},
#   {'date': '2019-03-31',
#    'name': 'intangibleassetspolicy',
#    'unit': 'NA',
#    'value': 'Intangible assets acquired separately from a business are capitalised at cost.  Intangible assetsacquired on business combinations are capitalised separately from goodwill if the fair value can bemeasured reliably on initial recognition.Intangible assets are amortised on a straight line basis over their useful lives.  The useful lives ofintangible assets are as follows:Trade mark-10% on costProvision is made for any impairment.'},
#   {'date': '2019-03-31',
#    'name': 'propertyplantequipmentpolicy',
#    'unit': 'NA',
#    'value': 'Tangible fixed assets are stated at cost less accumulated depreciation and accumulated impairmentlosses.  Cost includes costs directly attributable to making the asset capable of operating as intended.Depreciation is provided on all other tangible fixed assets, at rates calculated to write off the cost,less estimated residual value, of each asset on a systematic basis over its expected useful life asfollows:Plant and machinery-10% on costMotor vehicles - 25% on costComputer equipment-33% on costOTHER INVESTMENTSOther investments are recognised at cost less impairment.'},
#   {'date': '2019-03-31',
#    'name': 'investmentpropertypolicy',
#    'unit': 'NA',
#    'value': 'Investment property is shown at most recent valuation.  Any aggregate surplus or deficit arising fromchanges in fair value is recognised in profit or loss. Freehold investment properties are measured at fair value at each reporting date with changes in fairvalue recognised in profit or loss.  No depreciation is provided in respect of investment propertyunder the fair value model.The freehold investment properties have been subject to valuations by independent, professionalvaluers.'},
#   {'date': '2019-03-31',
#    'name': 'financialinstrumentsrecognitionmeasurementpolicy',
#    'unit': 'NA',
#    'value': "The group has chosen to adopt Sections 11 and 12 of FRS 102 in respect of financial instruments.Financial assetsBasic financial assets, including trade and other receivables, cash and bank balances are initiallyrecognised at transaction price, unless the arrangement constitutes a financing transaction, where thetransaction is measured at the present value of the future receipts discounted at a market rate ofinterest.Such assets are subsequently carried at amortised cost using the effective interest method. At theend of each reporting period financial assets measured at amortised cost are assessed for objectiveevidence of impairment. If an asset is impaired the impairment loss is the difference between thecarrying amount and the present value of the estimated cash flows discounted at the asset's originaleffective interest rate. The impairment loss is recognised in profit or loss.If there is decrease in the impairment loss arising from an event occurring after the impairment wasrecognised, the impairment is reversed. The reversal is such that the current carrying amount doesnot exceed what the carrying amount would have been had the impairment not previously beenrecognised. The impairment reversal is recognised in profit or loss.Financial assets are derecognised when (a) the contractual rights to the cash flows from the assetexpire or are settled, or (b) substantially all the risks and rewards of the ownership of the asset aretransferred to another party or (c) despite having retained some significant risks and rewards ofownership, control of the asset has been transferred to another party who has the practical ability tounilaterally sell the asset to an unrelated third party without imposing additional restrictions.Financial liabilitiesBasic financial liabilities, including trade and other payables, bank loans, loans from fellow groupcompanies and preference shares that are classified as debt, are initially recognised at transactionprice, unless the arrangement constitutes a financing transaction, where the debt instrument ismeasured at the present value of the future receipts discounted at a market rate of interest.Debt instruments are subsequently carried at amortised cost, using the effective interest rate method.Fees paid on the establishment of loan facilities are recognised as transaction costs of the loan to theextent that it is probable that some or all of the facility will be drawn down. In this case, the fee isdeferred until the draw-down occurs. To the extent there is no evidence that it is probable that someor all of the facility will be drawn down, the fee is capitalised as a pre-payment for liquidity servicesand amortised over the period of the facility to which it relates.Trade payables are obligations to pay for goods or services that have been acquired in the ordinarycourse of business from suppliers. Accounts payable are classified as current liabilities if payment isdue within one year or less. If not, they are presented as non-current liabilities. Trade payables arerecognised initially at transaction price and subsequently measured at amortised cost using theeffective interest method."},
#   {'date': '2019-03-31',
#    'name': 'taxpolicy',
#    'unit': 'NA',
#    'value': 'Taxation for the year comprises current and deferred tax. Tax is recognised in the ConsolidatedStatement of Comprehensive Income, except to the extent that it relates to items recognised in othercomprehensive income or directly in equity.Current or deferred taxation assets and liabilities are not discounted.Current tax is recognised at the amount of tax payable using the tax rates and laws that have beenenacted or substantively enacted by the statement of financial position date.'},
#   {'date': '2019-03-31',
#    'name': 'deferredtaxpolicy',
#    'unit': 'NA',
#    'value': 'Deferred tax is recognised in respect of all timing differences that have originated but not reversed atthe statement of financial position date.Timing differences arise from the inclusion of income and expenses in tax assessments in periodsdifferent from those in which they are recognised in financial statements. Deferred tax is measuredusing tax rates and laws that have been enacted or substantively enacted by the year end and thatare expected to apply to the reversal of the timing difference.Unrelieved tax losses and other deferred tax assets are recognised only to the extent that it isprobable that they will be recovered against the reversal of deferred tax liabilities or other futuretaxable profits.'},
#   {'date': '2019-03-31',
#    'name': 'foreigncurrencytranslationoperationspolicy',
#    'unit': 'NA',
#    'value': 'Assets and liabilities in foreign currencies are translated into sterling at the rates of exchange rulingat the statement of financial position date.  Transactions in foreign currencies are translated intosterling at the rate of exchange ruling at the date of transaction. Exchange differences are taken intoaccount in arriving at the operating result.'},
#   {'date': '2019-03-31',
#    'name': 'nameindividualsegment',
#    'unit': 'NA',
#    'value': 'Sale of goods'},
#   {'date': '2019-03-31',
#    'name': 'turnoverrevenue',
#    'unit': 'iso4217:GBP',
#    'value': 18083310.0},
#   {'date': '2018-03-31',
#    'name': 'turnoverrevenue',
#    'unit': 'iso4217:GBP',
#    'value': 18255912.0},
#   {'date': '2019-03-31',
#    'name': 'turnoverrevenue',
#    'unit': 'iso4217:GBP',
#    'value': 18083310.0},
#   {'date': '2018-03-31',
#    'name': 'turnoverrevenue',
#    'unit': 'iso4217:GBP',
#    'value': 18255912.0},
#   {'date': '2019-03-31',
#    'name': 'wagessalaries',
#    'unit': 'iso4217:GBP',
#    'value': 1154059.0},
#   {'date': '2018-03-31',
#    'name': 'wagessalaries',
#    'unit': 'iso4217:GBP',
#    'value': 1176993.0},
#   {'date': '2019-03-31',
#    'name': 'socialsecuritycosts',
#    'unit': 'iso4217:GBP',
#    'value': 114138.0},
#   {'date': '2018-03-31',
#    'name': 'socialsecuritycosts',
#    'unit': 'iso4217:GBP',
#    'value': 126363.0},
#   {'date': '2019-03-31',
#    'name': 'pensionotherpost-employmentbenefitcostsotherpensioncosts',
#    'unit': 'iso4217:GBP',
#    'value': 87713.0},
#   {'date': '2018-03-31',
#    'name': 'pensionotherpost-employmentbenefitcostsotherpensioncosts',
#    'unit': 'iso4217:GBP',
#    'value': 85176.0},
#   {'date': '2019-03-31',
#    'name': 'staffcostsemployeebenefitsexpense',
#    'unit': 'iso4217:GBP',
#    'value': 1355910.0},
#   {'date': '2018-03-31',
#    'name': 'staffcostsemployeebenefitsexpense',
#    'unit': 'iso4217:GBP',
#    'value': 1388532.0},
#   {'date': '2019-03-31',
#    'name': 'averagenumberemployeesduringperiod',
#    'unit': 'xbrli:pure',
#    'value': 37.0},
#   {'date': '2018-03-31',
#    'name': 'averagenumberemployeesduringperiod',
#    'unit': 'xbrli:pure',
#    'value': 37.0},
#   {'date': '2019-03-31',
#    'name': 'directorremuneration',
#    'unit': 'iso4217:GBP',
#    'value': 119224.0},
#   {'date': '2018-03-31',
#    'name': 'directorremuneration',
#    'unit': 'iso4217:GBP',
#    'value': 184592.0},
#   {'date': '2019-03-31',
#    'name': 'companycontributionstomoneypurchaseplansdirectors',
#    'unit': 'iso4217:GBP',
#    'value': 22000.0},
#   {'date': '2018-03-31',
#    'name': 'companycontributionstomoneypurchaseplansdirectors',
#    'unit': 'iso4217:GBP',
#    'value': 22000.0},
#   {'date': '2019-03-31',
#    'name': 'numberdirectorsaccruingbenefitsundermoneypurchasescheme',
#    'unit': 'xbrli:pure',
#    'value': 1.0},
#   {'date': '2018-03-31',
#    'name': 'numberdirectorsaccruingbenefitsundermoneypurchasescheme',
#    'unit': 'xbrli:pure',
#    'value': 1.0},
#   {'date': '2019-03-31',
#    'name': 'totaloperatingleasepayments',
#    'unit': 'iso4217:GBP',
#    'value': 108832.0},
#   {'date': '2018-03-31',
#    'name': 'totaloperatingleasepayments',
#    'unit': 'iso4217:GBP',
#    'value': 108832.0},
#   {'date': '2019-03-31',
#    'name': 'depreciationexpensepropertyplantequipment',
#    'unit': 'iso4217:GBP',
#    'value': 46040.0},
#   {'date': '2018-03-31',
#    'name': 'depreciationexpensepropertyplantequipment',
#    'unit': 'iso4217:GBP',
#    'value': 52343.0},
#   {'date': '2019-03-31',
#    'name': 'gainlossondisposalspropertyplantequipment',
#    'unit': 'iso4217:GBP',
#    'value': 3000.0},
#   {'date': '2018-03-31',
#    'name': 'gainlossondisposalspropertyplantequipment',
#    'unit': 'iso4217:GBP',
#    'value': 6500.0},
#   {'date': '2019-03-31',
#    'name': 'amortisationexpenseintangibleassets',
#    'unit': 'iso4217:GBP',
#    'value': 48000.0},
#   {'date': '2018-03-31',
#    'name': 'amortisationexpenseintangibleassets',
#    'unit': 'iso4217:GBP',
#    'value': 48000.0},
#   {'date': '2019-03-31',
#    'name': 'amortisationexpenseintangibleassets',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2018-03-31',
#    'name': 'amortisationexpenseintangibleassets',
#    'unit': 'iso4217:GBP',
#    'value': 132.0},
#   {'date': '2019-03-31',
#    'name': 'auditfeesexpenses',
#    'unit': 'iso4217:GBP',
#    'value': 11350.0},
#   {'date': '2018-03-31',
#    'name': 'auditfeesexpenses',
#    'unit': 'iso4217:GBP',
#    'value': 16918.0},
#   {'date': '2019-03-31',
#    'name': 'audit-relatedassuranceservicesfees',
#    'unit': 'iso4217:GBP',
#    'value': 11371.0},
#   {'date': '2018-03-31',
#    'name': 'audit-relatedassuranceservicesfees',
#    'unit': 'iso4217:GBP',
#    'value': 4455.0},
#   {'date': '2019-03-31',
#    'name': 'gainlossduetoforeignexchangedifferencesrecognisedinprofitorloss',
#    'unit': 'iso4217:GBP',
#    'value': 14291.0},
#   {'date': '2018-03-31',
#    'name': 'gainlossduetoforeignexchangedifferencesrecognisedinprofitorloss',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2019-03-31',
#    'name': 'currenttaxforperiod',
#    'unit': 'iso4217:GBP',
#    'value': 52950.0},
#   {'date': '2018-03-31',
#    'name': 'currenttaxforperiod',
#    'unit': 'iso4217:GBP',
#    'value': 195531.0},
#   {'date': '2019-03-31',
#    'name': 'totalcurrenttaxexpensecredit',
#    'unit': 'iso4217:GBP',
#    'value': 7016.0},
#   {'date': '2018-03-31',
#    'name': 'totalcurrenttaxexpensecredit',
#    'unit': 'iso4217:GBP',
#    'value': 195531.0},
#   {'date': '2019-03-31',
#    'name': 'otherdeferredtaxexpensecredit',
#    'unit': 'iso4217:GBP',
#    'value': 18647.0},
#   {'date': '2018-03-31',
#    'name': 'otherdeferredtaxexpensecredit',
#    'sign': '-',
#    'unit': 'iso4217:GBP',
#    'value': -5114.0},
#   {'date': '2019-03-31',
#    'name': 'taxtaxcreditonprofitorlossonordinaryactivities',
#    'unit': 'iso4217:GBP',
#    'value': 25663.0},
#   {'date': '2018-03-31',
#    'name': 'taxtaxcreditonprofitorlossonordinaryactivities',
#    'unit': 'iso4217:GBP',
#    'value': 190417.0},
#   {'date': '2019-03-31',
#    'name': 'profitlossonordinaryactivitiesbeforetax',
#    'unit': 'iso4217:GBP',
#    'value': 770186.0},
#   {'date': '2018-03-31',
#    'name': 'profitlossonordinaryactivitiesbeforetax',
#    'unit': 'iso4217:GBP',
#    'value': 931367.0},
#   {'date': '2019-03-31',
#    'name': 'applicabletaxrate',
#    'unit': 'xbrli:pure',
#    'value': 19.0},
#   {'date': '2018-03-31',
#    'name': 'applicabletaxrate',
#    'unit': 'xbrli:pure',
#    'value': 19.0},
#   {'date': '2019-03-31',
#    'name': 'taxexpensecreditapplicabletaxrate',
#    'unit': 'iso4217:GBP',
#    'value': 146335.0},
#   {'date': '2018-03-31',
#    'name': 'taxexpensecreditapplicabletaxrate',
#    'unit': 'iso4217:GBP',
#    'value': 176960.0},
#   {'date': '2019-03-31',
#    'name': 'taxincreasedecreasefromeffectexpensesnotdeductibleindeterminingtaxableprofitorloss',
#    'unit': 'iso4217:GBP',
#    'value': 439.0},
#   {'date': '2018-03-31',
#    'name': 'taxincreasedecreasefromeffectexpensesnotdeductibleindeterminingtaxableprofitorloss',
#    'unit': 'iso4217:GBP',
#    'value': 14708.0},
#   {'date': '2019-03-31',
#    'name': 'taxdecreaseincreasefromeffectrevenueexemptfromtaxation',
#    'unit': 'iso4217:GBP',
#    'value': 7780.0},
#   {'date': '2018-03-31',
#    'name': 'taxdecreaseincreasefromeffectrevenueexemptfromtaxation',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2019-03-31',
#    'name': 'increasedecreaseincurrenttaxfromadjustmentforpriorperiods',
#    'sign': '-',
#    'unit': 'iso4217:GBP',
#    'value': -46000.0},
#   {'date': '2018-03-31',
#    'name': 'increasedecreaseincurrenttaxfromadjustmentforpriorperiods',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2019-03-31',
#    'name': 'dividendspaidonsharesinterim',
#    'unit': 'iso4217:GBP',
#    'value': 0.0},
#   {'date': '2018-03-31',
#    'name': 'dividendspaidonsharesinterim',
#    'unit': 'iso4217:GBP',
#    'value': 605400.0},
#   {'date': '2018-03-31',
#    'name': 'intangibleassetsgrosscost',
#    'unit': 'iso4217:GBP',
#    'value': 480000.0},
#   {'date': '2019-03-31',
#    'name': 'accumulatedamortisationimpairmentintangibleassets',
#    'unit': 'iso4217:GBP',
#    'value': 192000.0},
#   {'date': '2018-03-31',
#    'name': 'intangibleassetsgrosscost',
#    'unit': 'iso4217:GBP',
#    'value': 480000.0}],
#  'parsed': True}

# %%
doc['elements']
# Out:
# [{'date': '2019-03-31',
#   'name': 'nameproductionsoftware',
#   'unit': 'NA',
#   'value': 'IRIS Accounts Production'},
#  {'date': '2019-03-31',
#   'name': 'versionproductionsoftware',
#   'unit': 'NA',
#   'value': 'v19.3.2.199'},
#  {'date': '2019-03-31',
#   'name': 'ukcompanieshouseregisterednumber',
#   'unit': 'NA',
#   'value': '00192996'},
#  {'date': '2019-03-31',
#   'name': 'countryformationorincorporation',
#   'unit': 'NA',
#   'value': 'EnglandWales'},
#  {'date': '2019-03-31',
#   'name': 'principalcurrencyusedinbusinessreport',
#   'unit': 'NA',
#   'value': 'PoundSterling'},
#  {'date': '2019-03-31',
#   'name': 'directorsigningfinancialstatements',
#   'unit': 'NA',
#   'value': 'Director1'},
#  {'date': '2019-03-31',
#   'name': 'descriptionbodyauthorisingfinancialstatements',
#   'unit': 'NA',
#   'value': 'Board of Directors'},
#  {'date': '2019-03-31',
#   'name': 'directorsigningdirectorsreport',
#   'unit': 'NA',
#   'value': 'Director1'},
#  {'date': '2019-03-31',
#   'name': 'balancesheetdate',
#   'unit': 'NA',
#   'value': '31.3.19'},
#  {'date': '2019-03-31',
#   'name': 'startdateforperiodcoveredbyreport',
#   'unit': 'NA',
#   'value': '1.4.18'},
#  {'date': '2019-03-31',
#   'name': 'enddateforperiodcoveredbyreport',
#   'unit': 'NA',
#   'value': '31.3.19'},
#  {'date': '2019-03-31',
#   'name': 'balancesheetdate',
#   'unit': 'NA',
#   'value': '31.3.19'},
#  {'date': '2019-03-31',
#   'name': 'scopeaccounts',
#   'unit': 'NA',
#   'value': 'ConsolidatedGroupCompanyAccounts'},
#  {'date': '2019-03-31',
#   'name': 'legalformentity',
#   'unit': 'NA',
#   'value': 'PrivateLimitedCompanyLtd'},
#  {'date': '2019-03-31', 'name': 'reportperiod', 'unit': 'NA', 'value': ''},
#  {'date': '2019-03-31',
#   'name': 'accountingstandardsapplied',
#   'unit': 'NA',
#   'value': 'Consolidated'},
#  {'date': '2019-03-31',
#   'name': 'accountsstatusauditedorunaudited',
#   'unit': 'NA',
#   'value': 'Consolidated'},
#  {'date': '2019-03-31',
#   'name': 'applicablelegislation',
#   'unit': 'NA',
#   'value': 'LargeMedium-sizedCompaniesRegimeForDirectorsReport'},
#  {'date': '2019-03-31',
#   'name': 'applicablelegislation',
#   'unit': 'NA',
#   'value': 'LargeMedium-sizedCompaniesRegimeForAccounts'},
#  {'date': '2019-03-31',
#   'name': 'applicablelegislation',
#   'unit': 'NA',
#   'value': 'Consolidated'},
#  {'date': '2019-03-31',
#   'name': 'applicablelegislation',
#   'unit': 'NA',
#   'value': 'Consolidated'},
#  {'date': '2019-03-31',
#   'name': 'accountstypefullorabbreviated',
#   'unit': 'NA',
#   'value': 'FullAccounts'},
#  {'date': '2019-03-31',
#   'name': 'accountstypefullorabbreviated',
#   'unit': 'NA',
#   'value': 'FullAccounts'},
#  {'date': '2019-03-31',
#   'name': 'reportincludeslistsubsidiariestruefalse',
#   'unit': 'NA',
#   'value': 'true'},
#  {'date': '2019-03-31',
#   'name': 'entityhastakenexemptionundercompaniesactinnotpublishingitsownprofitlossaccounttruefalse',
#   'unit': 'NA',
#   'value': 'true'},
#  {'date': '2019-03-31',
#   'name': 'companyhaspublishedcommitmenttoukeffectivestewardshipcodetruefalse',
#   'unit': 'NA',
#   'value': 'false'},
#  {'date': '2019-03-31',
#   'name': 'directorsreportconsistentwithaccountstruefalse',
#   'unit': 'NA',
#   'value': 'true'},
#  {'date': '2019-03-31',
#   'name': 'financialstatementsarepreparedongoing-concernbasistruefalse',
#   'unit': 'NA',
#   'value': 'true'},
#  {'date': '2019-03-31',
#   'name': 'subsidiaryunconsolidatedtruefalse',
#   'unit': 'NA',
#   'value': 'false'},
#  {'date': '2019-03-31',
#   'name': 'definedbenefitplanmulti-employerplantruefalse',
#   'unit': 'NA',
#   'value': 'false'},
#  {'date': '2019-03-31',
#   'name': 'recoverableamountspecificintangibleassetbasedvalueinusetruefalse',
#   'unit': 'NA',
#   'value': 'false'},
#  {'date': '2019-03-31',
#   'name': 'investmententityrequiredtoapplyexceptionfromconsolidationtruefalse',
#   'unit': 'NA',
#   'value': 'false'},
#  {'date': '2019-03-31',
#   'name': 'entityhasclaimedexemptionfromreportingdisclosurerelatedpartytransactionsforwholly-ownedentitiestruefalse',
#   'unit': 'NA',
#   'value': 'true'},
#  {'date': '2019-03-31',
#   'name': 'entitytradingstatus',
#   'unit': 'NA',
#   'value': ''},
#  {'date': '2019-03-31',
#   'name': 'entitydormanttruefalse',
#   'unit': 'NA',
#   'value': 'false'},
#  {'date': '2019-03-31',
#   'name': 'modelusedtomeasureinvestmentproperty',
#   'unit': 'NA',
#   'value': 'Fair value model'},
#  {'date': '2019-03-31',
#   'name': 'descriptionsharetype',
#   'unit': 'NA',
#   'value': 'Ordinary'},
#  {'date': '2019-03-31',
#   'name': 'parvalueshare',
#   'unit': 'xbrli:pure',
#   'value': 1.0},
#  {'date': '2019-03-31',
#   'name': 'reporttitle',
#   'unit': 'NA',
#   'value': 'GROUP STRATEGIC REPORT, REPORT OF THE DIRECTORS AND CONSOLIDATED FINANCIAL STATEMENTS FOR THE YEAR ENDED 31 MARCH 2019'},
#  {'date': '2019-03-31',
#   'name': 'entitycurrentlegalorregisteredname',
#   'unit': 'NA',
#   'value': 'GAWITH HOGGARTH & CO.,LIMITED'},
#  {'date': '2019-03-31',
#   'name': 'nameentityofficer',
#   'unit': 'NA',
#   'value': 'Mrs I M Gawith'},
#  {'date': '2019-03-31',
#   'name': 'nameentityofficer',
#   'unit': 'NA',
#   'value': 'Mr C S Gawith'},
#  {'date': '2019-03-31',
#   'name': 'addressline1',
#   'unit': 'NA',
#   'value': 'Unit 16/22'},
#  {'date': '2019-03-31',
#   'name': 'addressline2',
#   'unit': 'NA',
#   'value': 'Lake District Business Park'},
#  {'date': '2019-03-31',
#   'name': 'addressline3',
#   'unit': 'NA',
#   'value': 'Mint Bridge Road'},
#  {'date': '2019-03-31',
#   'name': 'principallocation-cityortown',
#   'unit': 'NA',
#   'value': 'Kendal'},
#  {'date': '2019-03-31',
#   'name': 'countyregion',
#   'unit': 'NA',
#   'value': 'Cumbria'},
#  {'date': '2019-03-31',
#   'name': 'postalcodezip',
#   'unit': 'NA',
#   'value': 'LA9 6NH'},
#  {'date': '2019-03-31',
#   'name': 'ukcompanieshouseregisterednumber',
#   'unit': 'NA',
#   'value': '00192996'},
#  {'date': '2019-03-31',
#   'name': 'nameentityauditors',
#   'unit': 'NA',
#   'value': 'RfM Preston Ltd'},
#  {'date': '2019-03-31',
#   'name': 'nameentityofficer',
#   'unit': 'NA',
#   'value': 'Mr C S Gawith'},
#  {'date': '2019-03-31',
#   'name': 'descriptionprincipalactivities',
#   'unit': 'NA',
#   'value': 'The principal activity of the group in the year under review was that of the manufacture and sale of tobaccoproducts. '},
#  {'date': '2019-03-31',
#   'name': 'nameentityofficer',
#   'unit': 'NA',
#   'value': 'Mrs I M Gawith'},
#  {'date': '2019-03-31',
#   'name': 'nameentityofficer',
#   'unit': 'NA',
#   'value': 'Mr R W Young'},
#  {'date': '2019-03-31',
#   'name': 'nameentityofficer',
#   'unit': 'NA',
#   'value': 'Mr C S Gawith'},
#  {'date': '2019-03-31',
#   'name': 'nameentityofficer',
#   'unit': 'NA',
#   'value': 'Mr C S Gawith'},
#  {'date': '2019-03-31',
#   'name': 'datesigningdirectorsreport',
#   'unit': 'NA',
#   'value': '30 March 2020'},
#  {'date': '2019-03-31',
#   'name': 'opinionauditorsonentity',
#   'unit': 'NA',
#   'value': "We have audited the financial statements of Gawith Hoggarth & Co.,Limited (the 'parent company') and itssubsidiaries (the 'group') for the year ended 31 March 2019 which comprise the Consolidated Statement ofIncome and Retained Earnings, Consolidated Statement of Financial Position, Company Statement ofFinancial Position, Consolidated Statement of Cash Flows and Notes to the Consolidated Statement ofCash Flows, Notes to the Financial Statements, including a summary of significant accounting policies. Thefinancial reporting framework that has been applied in their preparation is applicable law and UnitedKingdom Accounting Standards, including Financial Reporting Standard 102 'The Financial ReportingStandard applicable in the UK and Republic of Ireland' (United Kingdom Generally Accepted AccountingPractice). In our opinion the financial statements:-give a true and fair view of the state of the group's and of the parent company affairs as at 31 March 2019 and of the group's profit for the year then ended; -have been properly prepared in accordance with United Kingdom Generally Accepted Accounting Practice; and -have been prepared in accordance with the requirements of the Companies Act 2006. "},
#  {'date': '2019-03-31',
#   'name': 'nameseniorstatutoryauditor',
#   'unit': 'NA',
#   'value': 'Alan Meikle FCA'},
#  {'date': '2019-03-31',
#   'name': 'nameentityauditors',
#   'unit': 'NA',
#   'value': 'RfM Preston Ltd'},
#  {'date': '2019-03-31',
#   'name': 'dateauditorsreport',
#   'unit': 'NA',
#   'value': '30 March 2020'},
#  {'date': '2019-03-31',
#   'name': 'profitloss',
#   'unit': 'iso4217:GBP',
#   'value': 744523.0},
#  {'date': '2018-03-31',
#   'name': 'profitloss',
#   'unit': 'iso4217:GBP',
#   'value': 740950.0},
#  {'date': '2019-03-31',
#   'name': 'propertyplantequipment',
#   'unit': 'iso4217:GBP',
#   'value': 138653.0},
#  {'date': '2018-03-31',
#   'name': 'propertyplantequipment',
#   'unit': 'iso4217:GBP',
#   'value': 152951.0},
#  {'date': '2019-03-31',
#   'name': 'investmentsfixedassets',
#   'unit': 'iso4217:GBP',
#   'value': 1188400.0},
#  {'date': '2018-03-31',
#   'name': 'investmentsfixedassets',
#   'unit': 'iso4217:GBP',
#   'value': 1140452.0},
#  {'date': '2019-03-31',
#   'name': 'investmentproperty',
#   'unit': 'iso4217:GBP',
#   'value': 150000.0},
#  {'date': '2018-03-31',
#   'name': 'investmentproperty',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2019-03-31',
#   'name': 'fixedassets',
#   'unit': 'iso4217:GBP',
#   'value': 1765053.0},
#  {'date': '2018-03-31',
#   'name': 'fixedassets',
#   'unit': 'iso4217:GBP',
#   'value': 1629403.0},
#  {'date': '2019-03-31',
#   'name': 'totalinventories',
#   'unit': 'iso4217:GBP',
#   'value': 1227231.0},
#  {'date': '2018-03-31',
#   'name': 'totalinventories',
#   'unit': 'iso4217:GBP',
#   'value': 1272885.0},
#  {'date': '2019-03-31',
#   'name': 'debtors',
#   'unit': 'iso4217:GBP',
#   'value': 1136931.0},
#  {'date': '2018-03-31',
#   'name': 'debtors',
#   'unit': 'iso4217:GBP',
#   'value': 1537643.0},
#  {'date': '2019-03-31',
#   'name': 'cashbankonhand',
#   'unit': 'iso4217:GBP',
#   'value': 2927902.0},
#  {'date': '2018-03-31',
#   'name': 'cashbankonhand',
#   'unit': 'iso4217:GBP',
#   'value': 2142348.0},
#  {'date': '2019-03-31',
#   'name': 'currentassets',
#   'unit': 'iso4217:GBP',
#   'value': 5292064.0},
#  {'date': '2018-03-31',
#   'name': 'currentassets',
#   'unit': 'iso4217:GBP',
#   'value': 4952876.0},
#  {'date': '2019-03-31',
#   'name': 'creditors',
#   'unit': 'iso4217:GBP',
#   'value': 984237.0},
#  {'date': '2018-03-31',
#   'name': 'creditors',
#   'unit': 'iso4217:GBP',
#   'value': 1188257.0},
#  {'date': '2019-03-31',
#   'name': 'netcurrentassetsliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 4307827.0},
#  {'date': '2018-03-31',
#   'name': 'netcurrentassetsliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 3764619.0},
#  {'date': '2019-03-31',
#   'name': 'totalassetslesscurrentliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 6072880.0},
#  {'date': '2018-03-31',
#   'name': 'totalassetslesscurrentliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 5394022.0},
#  {'date': '2019-03-31',
#   'name': 'provisionsforliabilitiesbalancesheetsubtotal',
#   'unit': 'iso4217:GBP',
#   'value': 47114.0},
#  {'date': '2018-03-31',
#   'name': 'provisionsforliabilitiesbalancesheetsubtotal',
#   'unit': 'iso4217:GBP',
#   'value': 27960.0},
#  {'date': '2019-03-31',
#   'name': 'netassetsliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 6025766.0},
#  {'date': '2018-03-31',
#   'name': 'netassetsliabilities',
#   'unit': 'iso4217:GBP',
#   'value': 5366062.0},
#  {'date': '2019-03-31',
#   'name': 'equity',
#   'unit': 'iso4217:GBP',
#   'value': 10000.0},
#  {'date': '2018-03-31',
#   'name': 'equity',
#   'unit': 'iso4217:GBP',
#   'value': 10000.0},
#  {'date': '2019-03-31',
#   'name': 'equity',
#   'unit': 'iso4217:GBP',
#   'value': 6015766.0},
#  {'date': '2018-03-31',
#   'name': 'equity',
#   'unit': 'iso4217:GBP',
#   'value': 5356062.0},
#  {'date': '2019-03-31',
#   'name': 'equity',
#   'unit': 'iso4217:GBP',
#   'value': 6025766.0},
#  {'date': '2018-03-31',
#   'name': 'equity',
#   'unit': 'iso4217:GBP',
#   'value': 5366062.0},
#  {'date': '2019-03-31',
#   'name': 'dateauthorisationfinancialstatementsforissue',
#   'unit': 'NA',
#   'value': '30 March 2020'},
#  {'date': '2019-03-31',
#   'name': 'nameentityofficer',
#   'unit': 'NA',
#   'value': 'Mr C S Gawith'},
#  {'date': '2019-03-31',
#   'name': 'legalformentity',
#   'unit': 'NA',
#   'value': 'private company, limited by shares'},
#  {'date': '2019-03-31',
#   'name': 'statementcompliancewithapplicablereportingframework',
#   'unit': 'NA',
#   'value': 'These financial statements have been prepared in accordance with Financial Reporting Standard 102 "The Financial Reporting Standard applicable in the UK and Republic of Ireland" and the Companies Act 2006. The financial statements have been prepared under the historical cost convention as modified by the revaluation of certain assets.'},
#  {'date': '2019-03-31',
#   'name': 'generaldescriptioncriticalestimatesjudgements',
#   'unit': 'NA',
#   'value': 'Significant judgements and estimates made by management in preparing these financial statementswhich also have a significant risk of causing a material adjustment to the carrying amounts of assetsand liabilities within the next financial year include:- Depreciation and impairment of fixed assets- Accrued Income'},
#  {'date': '2019-03-31',
#   'name': 'intangibleassetspolicy',
#   'unit': 'NA',
#   'value': 'Goodwill arises on business acquisitions and represents the excess of the cost of the acquisition overthe company’s interest in the net amount of the identifiable assets, liabilities and contingent liabilitiesof the acquired business.Goodwill recognised at acquisition is measured at cost less accumulated amortisation andaccumulated impairment losses. Goodwill is amortised on a straight-line basis over its useful life,which is estimated to be ten years.Goodwill amortisation is charged on a straight line basis so as to write off the cost of the asset, lessits residual value assumed to be zero, over its useful economic life, which is estimated to be tenyears.Goodwill amortisation is included in administrative expenses in the statement of comprehensiveincome.'},
#  {'date': '2019-03-31',
#   'name': 'intangibleassetspolicy',
#   'unit': 'NA',
#   'value': 'Intangible assets acquired separately from a business are capitalised at cost.  Intangible assetsacquired on business combinations are capitalised separately from goodwill if the fair value can bemeasured reliably on initial recognition.Intangible assets are amortised on a straight line basis over their useful lives.  The useful lives ofintangible assets are as follows:Trade mark-10% on costProvision is made for any impairment.'},
#  {'date': '2019-03-31',
#   'name': 'propertyplantequipmentpolicy',
#   'unit': 'NA',
#   'value': 'Tangible fixed assets are stated at cost less accumulated depreciation and accumulated impairmentlosses.  Cost includes costs directly attributable to making the asset capable of operating as intended.Depreciation is provided on all other tangible fixed assets, at rates calculated to write off the cost,less estimated residual value, of each asset on a systematic basis over its expected useful life asfollows:Plant and machinery-10% on costMotor vehicles - 25% on costComputer equipment-33% on costOTHER INVESTMENTSOther investments are recognised at cost less impairment.'},
#  {'date': '2019-03-31',
#   'name': 'investmentpropertypolicy',
#   'unit': 'NA',
#   'value': 'Investment property is shown at most recent valuation.  Any aggregate surplus or deficit arising fromchanges in fair value is recognised in profit or loss. Freehold investment properties are measured at fair value at each reporting date with changes in fairvalue recognised in profit or loss.  No depreciation is provided in respect of investment propertyunder the fair value model.The freehold investment properties have been subject to valuations by independent, professionalvaluers.'},
#  {'date': '2019-03-31',
#   'name': 'financialinstrumentsrecognitionmeasurementpolicy',
#   'unit': 'NA',
#   'value': "The group has chosen to adopt Sections 11 and 12 of FRS 102 in respect of financial instruments.Financial assetsBasic financial assets, including trade and other receivables, cash and bank balances are initiallyrecognised at transaction price, unless the arrangement constitutes a financing transaction, where thetransaction is measured at the present value of the future receipts discounted at a market rate ofinterest.Such assets are subsequently carried at amortised cost using the effective interest method. At theend of each reporting period financial assets measured at amortised cost are assessed for objectiveevidence of impairment. If an asset is impaired the impairment loss is the difference between thecarrying amount and the present value of the estimated cash flows discounted at the asset's originaleffective interest rate. The impairment loss is recognised in profit or loss.If there is decrease in the impairment loss arising from an event occurring after the impairment wasrecognised, the impairment is reversed. The reversal is such that the current carrying amount doesnot exceed what the carrying amount would have been had the impairment not previously beenrecognised. The impairment reversal is recognised in profit or loss.Financial assets are derecognised when (a) the contractual rights to the cash flows from the assetexpire or are settled, or (b) substantially all the risks and rewards of the ownership of the asset aretransferred to another party or (c) despite having retained some significant risks and rewards ofownership, control of the asset has been transferred to another party who has the practical ability tounilaterally sell the asset to an unrelated third party without imposing additional restrictions.Financial liabilitiesBasic financial liabilities, including trade and other payables, bank loans, loans from fellow groupcompanies and preference shares that are classified as debt, are initially recognised at transactionprice, unless the arrangement constitutes a financing transaction, where the debt instrument ismeasured at the present value of the future receipts discounted at a market rate of interest.Debt instruments are subsequently carried at amortised cost, using the effective interest rate method.Fees paid on the establishment of loan facilities are recognised as transaction costs of the loan to theextent that it is probable that some or all of the facility will be drawn down. In this case, the fee isdeferred until the draw-down occurs. To the extent there is no evidence that it is probable that someor all of the facility will be drawn down, the fee is capitalised as a pre-payment for liquidity servicesand amortised over the period of the facility to which it relates.Trade payables are obligations to pay for goods or services that have been acquired in the ordinarycourse of business from suppliers. Accounts payable are classified as current liabilities if payment isdue within one year or less. If not, they are presented as non-current liabilities. Trade payables arerecognised initially at transaction price and subsequently measured at amortised cost using theeffective interest method."},
#  {'date': '2019-03-31',
#   'name': 'taxpolicy',
#   'unit': 'NA',
#   'value': 'Taxation for the year comprises current and deferred tax. Tax is recognised in the ConsolidatedStatement of Comprehensive Income, except to the extent that it relates to items recognised in othercomprehensive income or directly in equity.Current or deferred taxation assets and liabilities are not discounted.Current tax is recognised at the amount of tax payable using the tax rates and laws that have beenenacted or substantively enacted by the statement of financial position date.'},
#  {'date': '2019-03-31',
#   'name': 'deferredtaxpolicy',
#   'unit': 'NA',
#   'value': 'Deferred tax is recognised in respect of all timing differences that have originated but not reversed atthe statement of financial position date.Timing differences arise from the inclusion of income and expenses in tax assessments in periodsdifferent from those in which they are recognised in financial statements. Deferred tax is measuredusing tax rates and laws that have been enacted or substantively enacted by the year end and thatare expected to apply to the reversal of the timing difference.Unrelieved tax losses and other deferred tax assets are recognised only to the extent that it isprobable that they will be recovered against the reversal of deferred tax liabilities or other futuretaxable profits.'},
#  {'date': '2019-03-31',
#   'name': 'foreigncurrencytranslationoperationspolicy',
#   'unit': 'NA',
#   'value': 'Assets and liabilities in foreign currencies are translated into sterling at the rates of exchange rulingat the statement of financial position date.  Transactions in foreign currencies are translated intosterling at the rate of exchange ruling at the date of transaction. Exchange differences are taken intoaccount in arriving at the operating result.'},
#  {'date': '2019-03-31',
#   'name': 'nameindividualsegment',
#   'unit': 'NA',
#   'value': 'Sale of goods'},
#  {'date': '2019-03-31',
#   'name': 'turnoverrevenue',
#   'unit': 'iso4217:GBP',
#   'value': 18083310.0},
#  {'date': '2018-03-31',
#   'name': 'turnoverrevenue',
#   'unit': 'iso4217:GBP',
#   'value': 18255912.0},
#  {'date': '2019-03-31',
#   'name': 'turnoverrevenue',
#   'unit': 'iso4217:GBP',
#   'value': 18083310.0},
#  {'date': '2018-03-31',
#   'name': 'turnoverrevenue',
#   'unit': 'iso4217:GBP',
#   'value': 18255912.0},
#  {'date': '2019-03-31',
#   'name': 'wagessalaries',
#   'unit': 'iso4217:GBP',
#   'value': 1154059.0},
#  {'date': '2018-03-31',
#   'name': 'wagessalaries',
#   'unit': 'iso4217:GBP',
#   'value': 1176993.0},
#  {'date': '2019-03-31',
#   'name': 'socialsecuritycosts',
#   'unit': 'iso4217:GBP',
#   'value': 114138.0},
#  {'date': '2018-03-31',
#   'name': 'socialsecuritycosts',
#   'unit': 'iso4217:GBP',
#   'value': 126363.0},
#  {'date': '2019-03-31',
#   'name': 'pensionotherpost-employmentbenefitcostsotherpensioncosts',
#   'unit': 'iso4217:GBP',
#   'value': 87713.0},
#  {'date': '2018-03-31',
#   'name': 'pensionotherpost-employmentbenefitcostsotherpensioncosts',
#   'unit': 'iso4217:GBP',
#   'value': 85176.0},
#  {'date': '2019-03-31',
#   'name': 'staffcostsemployeebenefitsexpense',
#   'unit': 'iso4217:GBP',
#   'value': 1355910.0},
#  {'date': '2018-03-31',
#   'name': 'staffcostsemployeebenefitsexpense',
#   'unit': 'iso4217:GBP',
#   'value': 1388532.0},
#  {'date': '2019-03-31',
#   'name': 'averagenumberemployeesduringperiod',
#   'unit': 'xbrli:pure',
#   'value': 37.0},
#  {'date': '2018-03-31',
#   'name': 'averagenumberemployeesduringperiod',
#   'unit': 'xbrli:pure',
#   'value': 37.0},
#  {'date': '2019-03-31',
#   'name': 'directorremuneration',
#   'unit': 'iso4217:GBP',
#   'value': 119224.0},
#  {'date': '2018-03-31',
#   'name': 'directorremuneration',
#   'unit': 'iso4217:GBP',
#   'value': 184592.0},
#  {'date': '2019-03-31',
#   'name': 'companycontributionstomoneypurchaseplansdirectors',
#   'unit': 'iso4217:GBP',
#   'value': 22000.0},
#  {'date': '2018-03-31',
#   'name': 'companycontributionstomoneypurchaseplansdirectors',
#   'unit': 'iso4217:GBP',
#   'value': 22000.0},
#  {'date': '2019-03-31',
#   'name': 'numberdirectorsaccruingbenefitsundermoneypurchasescheme',
#   'unit': 'xbrli:pure',
#   'value': 1.0},
#  {'date': '2018-03-31',
#   'name': 'numberdirectorsaccruingbenefitsundermoneypurchasescheme',
#   'unit': 'xbrli:pure',
#   'value': 1.0},
#  {'date': '2019-03-31',
#   'name': 'totaloperatingleasepayments',
#   'unit': 'iso4217:GBP',
#   'value': 108832.0},
#  {'date': '2018-03-31',
#   'name': 'totaloperatingleasepayments',
#   'unit': 'iso4217:GBP',
#   'value': 108832.0},
#  {'date': '2019-03-31',
#   'name': 'depreciationexpensepropertyplantequipment',
#   'unit': 'iso4217:GBP',
#   'value': 46040.0},
#  {'date': '2018-03-31',
#   'name': 'depreciationexpensepropertyplantequipment',
#   'unit': 'iso4217:GBP',
#   'value': 52343.0},
#  {'date': '2019-03-31',
#   'name': 'gainlossondisposalspropertyplantequipment',
#   'unit': 'iso4217:GBP',
#   'value': 3000.0},
#  {'date': '2018-03-31',
#   'name': 'gainlossondisposalspropertyplantequipment',
#   'unit': 'iso4217:GBP',
#   'value': 6500.0},
#  {'date': '2019-03-31',
#   'name': 'amortisationexpenseintangibleassets',
#   'unit': 'iso4217:GBP',
#   'value': 48000.0},
#  {'date': '2018-03-31',
#   'name': 'amortisationexpenseintangibleassets',
#   'unit': 'iso4217:GBP',
#   'value': 48000.0},
#  {'date': '2019-03-31',
#   'name': 'amortisationexpenseintangibleassets',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2018-03-31',
#   'name': 'amortisationexpenseintangibleassets',
#   'unit': 'iso4217:GBP',
#   'value': 132.0},
#  {'date': '2019-03-31',
#   'name': 'auditfeesexpenses',
#   'unit': 'iso4217:GBP',
#   'value': 11350.0},
#  {'date': '2018-03-31',
#   'name': 'auditfeesexpenses',
#   'unit': 'iso4217:GBP',
#   'value': 16918.0},
#  {'date': '2019-03-31',
#   'name': 'audit-relatedassuranceservicesfees',
#   'unit': 'iso4217:GBP',
#   'value': 11371.0},
#  {'date': '2018-03-31',
#   'name': 'audit-relatedassuranceservicesfees',
#   'unit': 'iso4217:GBP',
#   'value': 4455.0},
#  {'date': '2019-03-31',
#   'name': 'gainlossduetoforeignexchangedifferencesrecognisedinprofitorloss',
#   'unit': 'iso4217:GBP',
#   'value': 14291.0},
#  {'date': '2018-03-31',
#   'name': 'gainlossduetoforeignexchangedifferencesrecognisedinprofitorloss',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2019-03-31',
#   'name': 'currenttaxforperiod',
#   'unit': 'iso4217:GBP',
#   'value': 52950.0},
#  {'date': '2018-03-31',
#   'name': 'currenttaxforperiod',
#   'unit': 'iso4217:GBP',
#   'value': 195531.0},
#  {'date': '2019-03-31',
#   'name': 'totalcurrenttaxexpensecredit',
#   'unit': 'iso4217:GBP',
#   'value': 7016.0},
#  {'date': '2018-03-31',
#   'name': 'totalcurrenttaxexpensecredit',
#   'unit': 'iso4217:GBP',
#   'value': 195531.0},
#  {'date': '2019-03-31',
#   'name': 'otherdeferredtaxexpensecredit',
#   'unit': 'iso4217:GBP',
#   'value': 18647.0},
#  {'date': '2018-03-31',
#   'name': 'otherdeferredtaxexpensecredit',
#   'sign': '-',
#   'unit': 'iso4217:GBP',
#   'value': -5114.0},
#  {'date': '2019-03-31',
#   'name': 'taxtaxcreditonprofitorlossonordinaryactivities',
#   'unit': 'iso4217:GBP',
#   'value': 25663.0},
#  {'date': '2018-03-31',
#   'name': 'taxtaxcreditonprofitorlossonordinaryactivities',
#   'unit': 'iso4217:GBP',
#   'value': 190417.0},
#  {'date': '2019-03-31',
#   'name': 'profitlossonordinaryactivitiesbeforetax',
#   'unit': 'iso4217:GBP',
#   'value': 770186.0},
#  {'date': '2018-03-31',
#   'name': 'profitlossonordinaryactivitiesbeforetax',
#   'unit': 'iso4217:GBP',
#   'value': 931367.0},
#  {'date': '2019-03-31',
#   'name': 'applicabletaxrate',
#   'unit': 'xbrli:pure',
#   'value': 19.0},
#  {'date': '2018-03-31',
#   'name': 'applicabletaxrate',
#   'unit': 'xbrli:pure',
#   'value': 19.0},
#  {'date': '2019-03-31',
#   'name': 'taxexpensecreditapplicabletaxrate',
#   'unit': 'iso4217:GBP',
#   'value': 146335.0},
#  {'date': '2018-03-31',
#   'name': 'taxexpensecreditapplicabletaxrate',
#   'unit': 'iso4217:GBP',
#   'value': 176960.0},
#  {'date': '2019-03-31',
#   'name': 'taxincreasedecreasefromeffectexpensesnotdeductibleindeterminingtaxableprofitorloss',
#   'unit': 'iso4217:GBP',
#   'value': 439.0},
#  {'date': '2018-03-31',
#   'name': 'taxincreasedecreasefromeffectexpensesnotdeductibleindeterminingtaxableprofitorloss',
#   'unit': 'iso4217:GBP',
#   'value': 14708.0},
#  {'date': '2019-03-31',
#   'name': 'taxdecreaseincreasefromeffectrevenueexemptfromtaxation',
#   'unit': 'iso4217:GBP',
#   'value': 7780.0},
#  {'date': '2018-03-31',
#   'name': 'taxdecreaseincreasefromeffectrevenueexemptfromtaxation',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2019-03-31',
#   'name': 'increasedecreaseincurrenttaxfromadjustmentforpriorperiods',
#   'sign': '-',
#   'unit': 'iso4217:GBP',
#   'value': -46000.0},
#  {'date': '2018-03-31',
#   'name': 'increasedecreaseincurrenttaxfromadjustmentforpriorperiods',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2019-03-31',
#   'name': 'dividendspaidonsharesinterim',
#   'unit': 'iso4217:GBP',
#   'value': 0.0},
#  {'date': '2018-03-31',
#   'name': 'dividendspaidonsharesinterim',
#   'unit': 'iso4217:GBP',
#   'value': 605400.0},
#  {'date': '2018-03-31',
#   'name': 'intangibleassetsgrosscost',
#   'unit': 'iso4217:GBP',
#   'value': 480000.0},
#  {'date': '2019-03-31',
#   'name': 'accumulatedamortisationimpairmentintangibleassets',
#   'unit': 'iso4217:GBP',
#   'value': 192000.0},
#  {'date': '2018-03-31',
#   'name': 'intangibleassetsgrosscost',
#   'unit': 'iso4217:GBP',
#   'value': 480000.0}]

# %%
# Loop through the document, retrieving any element with a matching name
for element in doc['elements']:
    if element['name'] == 'balancesheetdate':
        print(element)
# Out:
# {'name': 'balancesheetdate', 'value': '31.3.19', 'unit': 'NA', 'date': '2019-03-31'}
# {'name': 'balancesheetdate', 'value': '31.3.19', 'unit': 'NA', 'date': '2019-03-31'}

# %%
# Extract the all the data to long-thin table format for use with SQL
# Note, tables from docs should be appendable to one another to create
# tables of all data
flatten_data(doc).head(15)
# Out:
#           date                                           name unit  \
# 0   2019-03-31                         nameproductionsoftware   NA
# 1   2019-03-31                      versionproductionsoftware   NA
# 2   2019-03-31               ukcompanieshouseregisterednumber   NA
# 3   2019-03-31                countryformationorincorporation   NA
# 4   2019-03-31          principalcurrencyusedinbusinessreport   NA
# 5   2019-03-31             directorsigningfinancialstatements   NA
# 6   2019-03-31  descriptionbodyauthorisingfinancialstatements   NA
# 7   2019-03-31                 directorsigningdirectorsreport   NA
# 8   2019-03-31                               balancesheetdate   NA
# 9   2019-03-31              startdateforperiodcoveredbyreport   NA
# 10  2019-03-31                enddateforperiodcoveredbyreport   NA
# 11  2019-03-31                               balancesheetdate   NA
# 12  2019-03-31                                  scopeaccounts   NA
# 13  2019-03-31                                legalformentity   NA
# 14  2019-03-31                                   reportperiod   NA
#
#                                value sign  \
# 0           IRIS Accounts Production  NaN
# 1                        v19.3.2.199  NaN
# 2                           00192996  NaN
# 3                       EnglandWales  NaN
# 4                      PoundSterling  NaN
# 5                          Director1  NaN
# 6                 Board of Directors  NaN
# 7                          Director1  NaN
# 8                            31.3.19  NaN
# 9                             1.4.18  NaN
# 10                           31.3.19  NaN
# 11                           31.3.19  NaN
# 12  ConsolidatedGroupCompanyAccounts  NaN
# 13          PrivateLimitedCompanyLtd  NaN
# 14                                    NaN
#
#                                doc_name doc_type             doc_upload_date  \
# 0   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 1   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 2   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 3   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 4   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 5   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 6   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 7   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 8   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 9   Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 10  Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 11  Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 12  Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 13  Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
# 14  Prod223_2623_00192996_20190331.html     html  2020-06-01 09:27:07.117622
#
#                                              arc_name  parsed  \
# 0   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 1   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 2   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 3   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 4   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 5   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 6   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 7   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 8   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 9   D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 10  D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 11  D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 12  D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 13  D:\Project_3 - Image_Processing\cha_pipeline\data    True
# 14  D:\Project_3 - Image_Processing\cha_pipeline\data    True
#
#    doc_balancesheetdate doc_companieshouseregisterednumber doc_standard_type  \
# 0            2019-03-31                           00192996           FRS-102
# 1            2019-03-31                           00192996           FRS-102
# 2            2019-03-31                           00192996           FRS-102
# 3            2019-03-31                           00192996           FRS-102
# 4            2019-03-31                           00192996           FRS-102
# 5            2019-03-31                           00192996           FRS-102
# 6            2019-03-31                           00192996           FRS-102
# 7            2019-03-31                           00192996           FRS-102
# 8            2019-03-31                           00192996           FRS-102
# 9            2019-03-31                           00192996           FRS-102
# 10           2019-03-31                           00192996           FRS-102
# 11           2019-03-31                           00192996           FRS-102
# 12           2019-03-31                           00192996           FRS-102
# 13           2019-03-31                           00192996           FRS-102
# 14           2019-03-31                           00192996           FRS-102
#
#    doc_standard_date                                  doc_standard_link
# 0         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 1         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 2         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 3         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 4         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 5         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 6         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 7         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 8         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 9         2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 10        2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 11        2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 12        2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 13        2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...
# 14        2014-09-01  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...

# %%
# Finally, build a table of all variables from all example (digital) documents
# This can take a while

# Empty table awaiting results
results = pd.DataFrame()

# For every file
for file in files:
    
    # Read the file
    doc = process_account(file)
    
    # tabulate the results
    doc_df = flatten_data(doc)
    
    # append to table
    results = results.append(doc_df)
# Out:
# D:\Project_3 - Image_Processing\cha_pipeline\data/Prod223_2623_00192996_20190331.html
# D:\Project_3 - Image_Processing\cha_pipeline\data/Prod223_2623_00455009_20190630.html
# D:\Project_3 - Image_Processing\cha_pipeline\data/Prod223_2623_00685645_20190630.html
# D:\Project_3 - Image_Processing\cha_pipeline\data/Prod223_2623_00928731_20190831.html
# D:\Project_3 - Image_Processing\cha_pipeline\data/Prod223_2623_02372414_20200331.html

# %%
results.head(50)
# Out:
#                                              arc_name        date  \
# 0   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 1   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 2   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 3   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 4   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 5   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 6   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 7   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 8   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 9   D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 10  D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 11  D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 12  D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 13  D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
# 14  D:\Project_3 - Image_Processing\cha_pipeline\data  2019-03-31
#
#    doc_balancesheetdate doc_companieshouseregisterednumber  \
# 0            2019-03-31                           00192996
# 1            2019-03-31                           00192996
# 2            2019-03-31                           00192996
# 3            2019-03-31                           00192996
# 4            2019-03-31                           00192996
# 5            2019-03-31                           00192996
# 6            2019-03-31                           00192996
# 7            2019-03-31                           00192996
# 8            2019-03-31                           00192996
# 9            2019-03-31                           00192996
# 10           2019-03-31                           00192996
# 11           2019-03-31                           00192996
# 12           2019-03-31                           00192996
# 13           2019-03-31                           00192996
# 14           2019-03-31                           00192996
#
#                                doc_name doc_standard_date  \
# 0   Prod223_2623_00192996_20190331.html        2014-09-01
# 1   Prod223_2623_00192996_20190331.html        2014-09-01
# 2   Prod223_2623_00192996_20190331.html        2014-09-01
# 3   Prod223_2623_00192996_20190331.html        2014-09-01
# 4   Prod223_2623_00192996_20190331.html        2014-09-01
# 5   Prod223_2623_00192996_20190331.html        2014-09-01
# 6   Prod223_2623_00192996_20190331.html        2014-09-01
# 7   Prod223_2623_00192996_20190331.html        2014-09-01
# 8   Prod223_2623_00192996_20190331.html        2014-09-01
# 9   Prod223_2623_00192996_20190331.html        2014-09-01
# 10  Prod223_2623_00192996_20190331.html        2014-09-01
# 11  Prod223_2623_00192996_20190331.html        2014-09-01
# 12  Prod223_2623_00192996_20190331.html        2014-09-01
# 13  Prod223_2623_00192996_20190331.html        2014-09-01
# 14  Prod223_2623_00192996_20190331.html        2014-09-01
#
#                                     doc_standard_link doc_standard_type  \
# 0   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 1   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 2   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 3   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 4   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 5   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 6   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 7   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 8   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 9   https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 10  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 11  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 12  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 13  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
# 14  https://xbrl.frc.org.uk/FRS-102/2014-09-01/FRS...           FRS-102
#
#    doc_type             doc_upload_date  \
# 0      html  2020-06-01 09:35:15.269597
# 1      html  2020-06-01 09:35:15.269597
# 2      html  2020-06-01 09:35:15.269597
# 3      html  2020-06-01 09:35:15.269597
# 4      html  2020-06-01 09:35:15.269597
# 5      html  2020-06-01 09:35:15.269597
# 6      html  2020-06-01 09:35:15.269597
# 7      html  2020-06-01 09:35:15.269597
# 8      html  2020-06-01 09:35:15.269597
# 9      html  2020-06-01 09:35:15.269597
# 10     html  2020-06-01 09:35:15.269597
# 11     html  2020-06-01 09:35:15.269597
# 12     html  2020-06-01 09:35:15.269597
# 13     html  2020-06-01 09:35:15.269597
# 14     html  2020-06-01 09:35:15.269597
#
#                                              name  parsed sign unit  \
# 0                          nameproductionsoftware    True  NaN   NA
# 1                       versionproductionsoftware    True  NaN   NA
# 2                ukcompanieshouseregisterednumber    True  NaN   NA
# 3                 countryformationorincorporation    True  NaN   NA
# 4           principalcurrencyusedinbusinessreport    True  NaN   NA
# 5              directorsigningfinancialstatements    True  NaN   NA
# 6   descriptionbodyauthorisingfinancialstatements    True  NaN   NA
# 7                  directorsigningdirectorsreport    True  NaN   NA
# 8                                balancesheetdate    True  NaN   NA
# 9               startdateforperiodcoveredbyreport    True  NaN   NA
# 10                enddateforperiodcoveredbyreport    True  NaN   NA
# 11                               balancesheetdate    True  NaN   NA
# 12                                  scopeaccounts    True  NaN   NA
# 13                                legalformentity    True  NaN   NA
# 14                                   reportperiod    True  NaN   NA
#
#                                value
# 0           IRIS Accounts Production
# 1                        v19.3.2.199
# 2                           00192996
# 3                       EnglandWales
# 4                      PoundSterling
# 5                          Director1
# 6                 Board of Directors
# 7                          Director1
# 8                            31.3.19
# 9                             1.4.18
# 10                           31.3.19
# 11                           31.3.19
# 12  ConsolidatedGroupCompanyAccounts
# 13          PrivateLimitedCompanyLtd
# 14
